# %% [markdown]
# # **Contours**
#
# ####**In this lesson we'll learn:**
# 1. Using findContours
# 2. Drawing Contours
# 3. Hierachy of Contours
# 4. Contouring Modes (Simple vs Approx)

# %%
# !pip install wget
# !pip install zipfile36
# !pip install opencv-python

# %%
# download our images
import os
import wget
from zipfile import ZipFile


def bar_custom(current, total, width=80):
    print("Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total))

URL = "https://raw.githubusercontent.com/rajeevratan84/ModernComputerVision/main/scan.jpeg"
if not os.path.exists("scan.jpeg"):
    wget.download(URL,bar=bar_custom)

# %%
# Our Setup, Import Libaries, Create our Imshow Function and Download our Images
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Define our imshow function 
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %% [markdown]
# ## **What are Contours?**
# Contours are continous lines or curves that bound or cover the full boundary of an object.

# %%
# Let's load a simple image license plate image
image = cv2.imread('images/LP.jpg')
imshow('Input Image', image,size = 30)

# %% [markdown]
# #### **Applying cv2.findContours()**
#
# ```cv2.findContours(image, Retrieval Mode, Approximation Method)```
#
# Official Doc - https://docs.opencv.org/master/d9/d8b/tutorial_py_contours_hierarchy.html
#
# **Retrieval Modes**
# - **RETR_LIST** - Retrieves all the contours, but doesn't create any parent-child relationship. Parents and kids are equal under this rule, and they are just contours. ie they all belongs to same hierarchy level.
# - **RETR_EXTERNAL** - eturns only extreme outer flags. All child contours are left behind.
# - **RETR_CCOMP** - This flag retrieves all the contours and arranges them to a 2-level hierarchy. ie external contours of the object (ie its boundary) are placed in hierarchy-1. And the contours of holes inside object (if any) is placed in hierarchy-2. If any object inside it, its contour is placed again in hierarchy-1 only. And its hole in hierarchy-2 and so on.
# - **RETR_TREE** -  It retrieves all the contours and creates a full family hierarchy list.
#
# **Approximation Method Options**
# - cv2.CHAIN_APPROX_NONE – Stores all the points along the line(inefficient!)
# - cv2.CHAIN_APPROX_SIMPLE – Stores the end points of each line

# %%
image = cv2.imread('images/LP.jpg')

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, th2 = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
imshow('After thresholding', th2,size = 30)

# %%
# Finding Contours
# Use a copy of your image e.g. edged.copy(), since findContours alters the image
contours, hierarchy = cv2.findContours(th2, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

print("Number of Contours found = " + str(len(contours)))
# Out:
# Number of Contours found = 38

# %%
# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
ximage = image.copy()
cv2.drawContours(ximage, contours, -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', ximage,size = 30)

# %%
# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
ximage = image.copy()
cv2.drawContours(ximage, [contours[-1]], -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', ximage,size = 30)

# %%
# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
ximage = image.copy()
cv2.drawContours(ximage, [contours[-2]], -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', ximage,size = 30)

# %%
len(contours[-1])
# Out:
# 272

# %%
contours[-1]
# Out:
# array([[[ 64,  10]],
#
#        [[ 63,  11]],
#
#        [[ 63,  12]],
#
#        [[ 62,  13]],
#
#        [[ 62,  14]],
#
#        [[ 62,  15]],
#
#        [[ 62,  16]],
#
#        [[ 62,  17]],
#
#        [[ 62,  18]],
#
#        [[ 62,  19]],
#
#        [[ 62,  20]],
#
#        [[ 62,  21]],
#
#        [[ 62,  22]],
#
#        [[ 62,  23]],
#
#        [[ 62,  24]],
#
#        [[ 62,  25]],
#
#        [[ 62,  26]],
#
#        [[ 62,  27]],
#
#        [[ 62,  28]],
#
#        [[ 62,  29]],
#
#        [[ 62,  30]],
#
#        [[ 62,  31]],
#
#        [[ 62,  32]],
#
#        [[ 62,  33]],
#
#        [[ 63,  34]],
#
#        [[ 63,  35]],
#
#        [[ 63,  36]],
#
#        [[ 63,  37]],
#
#        [[ 63,  38]],
#
#        [[ 63,  39]],
#
#        [[ 63,  40]],
#
#        [[ 63,  41]],
#
#        [[ 63,  42]],
#
#        [[ 63,  43]],
#
#        [[ 63,  44]],
#
#        [[ 63,  45]],
#
#        [[ 63,  46]],
#
#        [[ 63,  47]],
#
#        [[ 63,  48]],
#
#        [[ 63,  49]],
#
#        [[ 63,  50]],
#
#        [[ 63,  51]],
#
#        [[ 63,  52]],
#
#        [[ 63,  53]],
#
#        [[ 63,  54]],
#
#        [[ 63,  55]],
#
#        [[ 63,  56]],
#
#        [[ 63,  57]],
#
#        [[ 63,  58]],
#
#        [[ 63,  59]],
#
#        [[ 63,  60]],
#
#        [[ 63,  61]],
#
#        [[ 63,  62]],
#
#        [[ 63,  63]],
#
#        [[ 63,  64]],
#
#        [[ 63,  65]],
#
#        [[ 63,  66]],
#
#        [[ 63,  67]],
#
#        [[ 63,  68]],
#
#        [[ 63,  69]],
#
#        [[ 63,  70]],
#
#        [[ 63,  71]],
#
#        [[ 63,  72]],
#
#        [[ 63,  73]],
#
#        [[ 63,  74]],
#
#        [[ 63,  75]],
#
#        [[ 63,  76]],
#
#        [[ 63,  77]],
#
#        [[ 63,  78]],
#
#        [[ 63,  79]],
#
#        [[ 63,  80]],
#
#        [[ 63,  81]],
#
#        [[ 63,  82]],
#
#        [[ 63,  83]],
#
#        [[ 63,  84]],
#
#        [[ 63,  85]],
#
#        [[ 63,  86]],
#
#        [[ 63,  87]],
#
#        [[ 63,  88]],
#
#        [[ 63,  89]],
#
#        [[ 63,  90]],
#
#        [[ 63,  91]],
#
#        [[ 63,  92]],
#
#        [[ 63,  93]],
#
#        [[ 63,  94]],
#
#        [[ 63,  95]],
#
#        [[ 63,  96]],
#
#        [[ 63,  97]],
#
#        [[ 63,  98]],
#
#        [[ 63,  99]],
#
#        [[ 64, 100]],
#
#        [[ 65, 100]],
#
#        [[ 66, 100]],
#
#        [[ 67, 100]],
#
#        [[ 68, 100]],
#
#        [[ 69, 100]],
#
#        [[ 70, 100]],
#
#        [[ 71, 100]],
#
#        [[ 72, 100]],
#
#        [[ 73, 100]],
#
#        [[ 74, 100]],
#
#        [[ 75, 100]],
#
#        [[ 76, 100]],
#
#        [[ 77, 100]],
#
#        [[ 78, 100]],
#
#        [[ 78,  99]],
#
#        [[ 79,  98]],
#
#        [[ 79,  97]],
#
#        [[ 78,  96]],
#
#        [[ 78,  95]],
#
#        [[ 78,  94]],
#
#        [[ 78,  93]],
#
#        [[ 78,  92]],
#
#        [[ 78,  91]],
#
#        [[ 78,  90]],
#
#        [[ 78,  89]],
#
#        [[ 78,  88]],
#
#        [[ 79,  87]],
#
#        [[ 79,  86]],
#
#        [[ 78,  85]],
#
#        [[ 78,  84]],
#
#        [[ 78,  83]],
#
#        [[ 78,  82]],
#
#        [[ 78,  81]],
#
#        [[ 78,  80]],
#
#        [[ 78,  79]],
#
#        [[ 78,  78]],
#
#        [[ 78,  77]],
#
#        [[ 78,  76]],
#
#        [[ 78,  75]],
#
#        [[ 78,  74]],
#
#        [[ 78,  73]],
#
#        [[ 78,  72]],
#
#        [[ 78,  71]],
#
#        [[ 78,  70]],
#
#        [[ 78,  69]],
#
#        [[ 78,  68]],
#
#        [[ 79,  67]],
#
#        [[ 79,  66]],
#
#        [[ 80,  65]],
#
#        [[ 81,  64]],
#
#        [[ 82,  64]],
#
#        [[ 83,  64]],
#
#        [[ 84,  64]],
#
#        [[ 85,  64]],
#
#        [[ 86,  64]],
#
#        [[ 87,  64]],
#
#        [[ 88,  64]],
#
#        [[ 89,  64]],
#
#        [[ 90,  64]],
#
#        [[ 91,  65]],
#
#        [[ 92,  65]],
#
#        [[ 93,  65]],
#
#        [[ 94,  65]],
#
#        [[ 95,  65]],
#
#        [[ 96,  65]],
#
#        [[ 97,  65]],
#
#        [[ 98,  65]],
#
#        [[ 99,  65]],
#
#        [[100,  65]],
#
#        [[101,  65]],
#
#        [[102,  64]],
#
#        [[103,  64]],
#
#        [[104,  64]],
#
#        [[105,  64]],
#
#        [[106,  64]],
#
#        [[107,  64]],
#
#        [[108,  63]],
#
#        [[109,  63]],
#
#        [[110,  63]],
#
#        [[111,  62]],
#
#        [[112,  62]],
#
#        [[113,  61]],
#
#        [[114,  61]],
#
#        [[115,  60]],
#
#        [[116,  59]],
#
#        [[117,  59]],
#
#        [[118,  58]],
#
#        [[119,  57]],
#
#        [[120,  56]],
#
#        [[121,  55]],
#
#        [[122,  54]],
#
#        [[122,  53]],
#
#        [[123,  52]],
#
#        [[124,  51]],
#
#        [[124,  50]],
#
#        [[125,  49]],
#
#        [[125,  48]],
#
#        [[125,  47]],
#
#        [[126,  46]],
#
#        [[126,  45]],
#
#        [[126,  44]],
#
#        [[126,  43]],
#
#        [[127,  42]],
#
#        [[127,  41]],
#
#        [[127,  40]],
#
#        [[127,  39]],
#
#        [[127,  38]],
#
#        [[127,  37]],
#
#        [[127,  36]],
#
#        [[127,  35]],
#
#        [[127,  34]],
#
#        [[127,  33]],
#
#        [[126,  32]],
#
#        [[126,  31]],
#
#        [[126,  30]],
#
#        [[125,  29]],
#
#        [[125,  28]],
#
#        [[125,  27]],
#
#        [[124,  26]],
#
#        [[124,  25]],
#
#        [[123,  24]],
#
#        [[123,  23]],
#
#        [[122,  22]],
#
#        [[121,  21]],
#
#        [[120,  20]],
#
#        [[120,  19]],
#
#        [[119,  18]],
#
#        [[118,  18]],
#
#        [[117,  17]],
#
#        [[116,  16]],
#
#        [[115,  15]],
#
#        [[114,  15]],
#
#        [[113,  14]],
#
#        [[112,  14]],
#
#        [[111,  13]],
#
#        [[110,  12]],
#
#        [[109,  12]],
#
#        [[108,  12]],
#
#        [[107,  12]],
#
#        [[106,  11]],
#
#        [[105,  11]],
#
#        [[104,  11]],
#
#        [[103,  11]],
#
#        [[102,  10]],
#
#        [[101,  10]],
#
#        [[100,  10]],
#
#        [[ 99,  10]],
#
#        [[ 98,  10]],
#
#        [[ 97,  10]],
#
#        [[ 96,  10]],
#
#        [[ 95,  10]],
#
#        [[ 94,  10]],
#
#        [[ 93,  10]],
#
#        [[ 92,  10]],
#
#        [[ 91,  10]],
#
#        [[ 90,  10]],
#
#        [[ 89,  10]],
#
#        [[ 88,  10]],
#
#        [[ 87,  10]],
#
#        [[ 86,  10]],
#
#        [[ 85,  10]],
#
#        [[ 84,  10]],
#
#        [[ 83,  10]],
#
#        [[ 82,  10]],
#
#        [[ 81,  10]],
#
#        [[ 80,  10]],
#
#        [[ 79,  10]],
#
#        [[ 78,  10]],
#
#        [[ 77,  10]],
#
#        [[ 76,  10]],
#
#        [[ 75,  10]],
#
#        [[ 74,  10]],
#
#        [[ 73,  10]],
#
#        [[ 72,  10]],
#
#        [[ 71,  10]],
#
#        [[ 70,  10]],
#
#        [[ 69,  10]],
#
#        [[ 68,  10]],
#
#        [[ 67,  10]],
#
#        [[ 66,  10]],
#
#        [[ 65,  10]]], dtype=int32)

# %% [markdown]
# #### **What happens if we don't threshold? Bad things..**

# %%
image = cv2.imread('images/LP.jpg')

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
imshow('After Grayscaling', gray)

# Finding Contours
contours, hierarchy = cv2.findContours(gray, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
#cv2.drawContours(image, contours, -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', image,size = 30)

print("Number of Contours found = " + str(len(contours)))
# Out:
# Number of Contours found = 1

# %% [markdown]
# # **NOTE: For findContours to work, the background has to be black and foreground (i.e. the text or objects)**
#
# #### Otherwise you'll need to invert the image by using **cv2..bitwise_not(input_image)**

# %% [markdown]
# #### **We can use Canny Edges instead of Thresholding**

# %%
image = cv2.imread('images/LP.jpg')

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Canny Edges
edged = cv2.Canny(gray, 30, 200)
imshow('Canny Edges', edged,size = 30)

# Finding Contours
contours, hierarchy = cv2.findContours(edged, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
cv2.drawContours(image, contours, -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', image,size = 30)

print("Number of Contours found = " + str(len(contours)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/tuchsanai/Documents/GitHub/DL-FOR-COMPUTER-VISION-2565_1/week3/code/11. Contours - Drawing, Hierarchy and Modes.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/tuchsanai/Documents/GitHub/DL-FOR-COMPUTER-VISION-2565_1/week3/code/11.%20Contours%20-%20Drawing%2C%20Hierarchy%20and%20Modes.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> image = cv2.imread('images/LP.jpg')
#       <a href='vscode-notebook-cell:/Users/tuchsanai/Documents/GitHub/DL-FOR-COMPUTER-VISION-2565_1/week3/code/11.%20Contours%20-%20Drawing%2C%20Hierarchy%20and%20Modes.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> # Convert to Grayscale
#       <a href='vscode-notebook-cell:/Users/tuchsanai/Documents/GitHub/DL-FOR-COMPUTER-VISION-2565_1/week3/code/11.%20Contours%20-%20Drawing%2C%20Hierarchy%20and%20Modes.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# ## **Remember these Countouring Steps**
#
# 1. Grayscale
# 2. Threshold or Canny Edge Detection to Binarize image
#
# **Note:** Blurring before Step 2 is recommended to remove noisy contours

# %% [markdown]
# # **Retreival Modes**
#
# Official Doc - https://docs.opencv.org/master/d9/d8b/tutorial_py_contours_hierarchy.html
#
# **Hierachry**
#
# This array stores 4 values for each contour:
# - First term is the index of the Next contour
# - Second term is the index of the Previous contour
# - Third term is the index of the parent contour
# - Forth term is the index of the child contour

# %% [markdown]
# ### **RETR_LIST**
# Retrieves all the contours, but doesn't create any parent-child relationship. Parents and kids are equal under this rule, and they are just contours. ie they all belongs to same hierarchy level.

# %%
image = cv2.imread('images/LP.jpg')

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, th2 = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
imshow('After thresholding', th2,size = 30)

# Use a copy of your image e.g. edged.copy(), since findContours alters the image
contours, hierarchy = cv2.findContours(th2, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
cv2.drawContours(image, contours, -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', image,size = 30)

print("Number of Contours found = " + str(len(contours)))
print(hierarchy)
# Out:
# Number of Contours found = 38
# [[[ 1 -1 -1 -1]
#   [ 2  0 -1 -1]
#   [ 3  1 -1 -1]
#   [ 4  2 -1 -1]
#   [ 5  3 -1 -1]
#   [ 6  4 -1 -1]
#   [ 7  5 -1 -1]
#   [ 8  6 -1 -1]
#   [ 9  7 -1 -1]
#   [10  8 -1 -1]
#   [11  9 -1 -1]
#   [12 10 -1 -1]
#   [13 11 -1 -1]
#   [14 12 -1 -1]
#   [15 13 -1 -1]
#   [16 14 -1 -1]
#   [17 15 -1 -1]
#   [18 16 -1 -1]
#   [19 17 -1 -1]
#   [20 18 -1 -1]
#   [21 19 -1 -1]
#   [22 20 -1 -1]
#   [23 21 -1 -1]
#   [24 22 -1 -1]
#   [25 23 -1 -1]
#   [26 24 -1 -1]
#   [27 25 -1 -1]
#   [28 26 -1 -1]
#   [29 27 -1 -1]
#   [30 28 -1 -1]
#   [31 29 -1 -1]
#   [32 30 -1 -1]
#   [33 31 -1 -1]
#   [34 32 -1 -1]
#   [35 33 -1 -1]
#   [36 34 -1 -1]
#   [37 35 -1 -1]
#   [-1 36 -1 -1]]]

# %% [markdown]
# ### **RETR_EXTERNAL**
#
# Returns only extreme outer flags. All child contours are left behind.

# %%
image = cv2.imread('images/LP.jpg')

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, th2 = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
imshow('After thresholding', th2)

# Use a copy of your image e.g. edged.copy(), since findContours alters the image
contours, hierarchy = cv2.findContours(th2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
cv2.drawContours(image, contours, -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', image, size = 10)

print("Number of Contours found = " + str(len(contours)))
print(hierarchy)
# Out:
# Number of Contours found = 16
# [[[ 1 -1 -1 -1]
#   [ 2  0 -1 -1]
#   [ 3  1 -1 -1]
#   [ 4  2 -1 -1]
#   [ 5  3 -1 -1]
#   [ 6  4 -1 -1]
#   [ 7  5 -1 -1]
#   [ 8  6 -1 -1]
#   [ 9  7 -1 -1]
#   [10  8 -1 -1]
#   [11  9 -1 -1]
#   [12 10 -1 -1]
#   [13 11 -1 -1]
#   [14 12 -1 -1]
#   [15 13 -1 -1]
#   [-1 14 -1 -1]]]

# %% [markdown]
# ### **RETR_CCOMP**
#
# Retrieves all the contours and arranges them to a 2-level hierarchy. ie external contours of the object (ie its boundary) are placed in hierarchy-1. And the contours of holes inside object (if any) is placed in hierarchy-2. If any object inside it, its contour is placed again in hierarchy-1 only. And its hole in hierarchy-2 and so on.

# %%
image = cv2.imread('images/LP.jpg')

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, th2 = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
imshow('After thresholding', th2,size = 30)

# Use a copy of your image e.g. edged.copy(), since findContours alters the image
contours, hierarchy = cv2.findContours(th2, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_NONE)

# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
cv2.drawContours(image, contours, -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', image,size = 30)

print("Number of Contours found = " + str(len(contours)))
print(hierarchy)
# Out:
# Number of Contours found = 38
# [[[ 1 -1 -1 -1]
#   [ 2  0 -1 -1]
#   [ 3  1 -1 -1]
#   [ 4  2 -1 -1]
#   [ 5  3 -1 -1]
#   [ 6  4 -1 -1]
#   [ 7  5 -1 -1]
#   [ 8  6 -1 -1]
#   [ 9  7 -1 -1]
#   [10  8 -1 -1]
#   [17  9 11 -1]
#   [12 -1 -1 10]
#   [13 11 -1 10]
#   [14 12 -1 10]
#   [15 13 -1 10]
#   [16 14 -1 10]
#   [-1 15 -1 10]
#   [25 10 18 -1]
#   [19 -1 -1 17]
#   [20 18 -1 17]
#   [21 19 -1 17]
#   [22 20 -1 17]
#   [23 21 -1 17]
#   [24 22 -1 17]
#   [-1 23 -1 17]
#   [32 17 26 -1]
#   [27 -1 -1 25]
#   [28 26 -1 25]
#   [29 27 -1 25]
#   [30 28 -1 25]
#   [31 29 -1 25]
#   [-1 30 -1 25]
#   [35 25 33 -1]
#   [34 -1 -1 32]
#   [-1 33 -1 32]
#   [36 32 -1 -1]
#   [-1 35 37 -1]
#   [-1 -1 -1 36]]]

# %% [markdown]
# ### **RETR_TREE**
# It retrieves all the contours and creates a full family hierarchy list.

# %%
image = cv2.imread('images/LP.jpg')

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, th2 = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
imshow('After thresholding', th2,size = 30)

# Use a copy of your image e.g. edged.copy(), since findContours alters the image
contours, hierarchy = cv2.findContours(th2, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
cv2.drawContours(image, contours, -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', image,size = 30)

print("Number of Contours found = " + str(len(contours)))
print(hierarchy)
# Out:
# Number of Contours found = 38
# [[[ 1 -1 -1 -1]
#   [ 2  0 -1 -1]
#   [ 3  1 -1 -1]
#   [ 4  2 -1 -1]
#   [ 5  3 -1 -1]
#   [ 6  4 -1 -1]
#   [ 7  5 -1 -1]
#   [ 8  6 -1 -1]
#   [ 9  7 -1 -1]
#   [10  8 -1 -1]
#   [17  9 11 -1]
#   [12 -1 -1 10]
#   [13 11 -1 10]
#   [14 12 -1 10]
#   [15 13 -1 10]
#   [16 14 -1 10]
#   [-1 15 -1 10]
#   [25 10 18 -1]
#   [19 -1 -1 17]
#   [20 18 -1 17]
#   [21 19 -1 17]
#   [22 20 -1 17]
#   [23 21 -1 17]
#   [24 22 -1 17]
#   [-1 23 -1 17]
#   [32 17 26 -1]
#   [27 -1 -1 25]
#   [28 26 -1 25]
#   [29 27 -1 25]
#   [30 28 -1 25]
#   [31 29 -1 25]
#   [-1 30 -1 25]
#   [35 25 33 -1]
#   [34 -1 -1 32]
#   [-1 33 -1 32]
#   [36 32 -1 -1]
#   [-1 35 37 -1]
#   [-1 -1 -1 36]]]

# %% [markdown]
# ## **Contouring Modes**
#
# #### **CHAIN_APPROX_NONE**

# %%
image = cv2.imread('images/LP.jpg')

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, th2 = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
imshow('After thresholding', th2,size = 30)

# Use a copy of your image e.g. edged.copy(), since findContours alters the image
contours, hierarchy = cv2.findContours(th2, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
cv2.drawContours(image, contours, -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', image,size = 30)

print("Number of Contours found = " + str(len(contours)))
for c in contours:
  print(len(c))
# Out:
# Number of Contours found = 38
# 87
# 50
# 7
# 1
# 1
# 1
# 1
# 4
# 2
# 1
# 236
# 80
# 6
# 75
# 10
# 4
# 8
# 426
# 6
# 4
# 4
# 10
# 14
# 21
# 17
# 241
# 6
# 14
# 15
# 155
# 14
# 9
# 358
# 4
# 4
# 347
# 272
# 92

# %% [markdown]
# #### **CHAIN_APPROX_SIMPLE**

# %%
image = cv2.imread('images/LP.jpg')

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, th2 = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
imshow('After thresholding', th2)

# Use a copy of your image e.g. edged.copy(), since findContours alters the image
contours, hierarchy = cv2.findContours(th2, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
cv2.drawContours(image, contours, -1, (0,255,0), thickness = 2)
imshow('Contours overlaid on original image', image)

print("Number of Contours found = " + str(len(contours)))
for c in contours:
  print(len(c))
# Out:
# Number of Contours found = 38
# 8
# 10
# 7
# 1
# 1
# 1
# 1
# 4
# 2
# 1
# 114
# 40
# 6
# 37
# 6
# 4
# 8
# 172
# 6
# 4
# 4
# 6
# 6
# 15
# 11
# 121
# 6
# 6
# 8
# 57
# 8
# 7
# 170
# 4
# 4
# 164
# 65
# 27
