# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = '../.././images/cegg.jpg'  # Replace with your image path
image = cv2.imread(image_path)

# display the image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Homework ---> ให้ Segment cracked egg
