# %%
# !pip install facenet-pytorch
# Out:
# Collecting facenet-pytorch
#   Downloading facenet_pytorch-2.5.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 15.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from facenet-pytorch) (1.26.2)
# Requirement already satisfied: requests in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from facenet-pytorch) (2.31.0)
# Requirement already satisfied: torchvision in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from facenet-pytorch) (0.16.1)
# Requirement already satisfied: pillow in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from facenet-pytorch) (10.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from requests->facenet-pytorch) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from requests->facenet-pytorch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from requests->facenet-pytorch) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from requests->facenet-pytorch) (2023.11.17)
# Requirement already satisfied: torch in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from torchvision->facenet-pytorch) (2.1.1)
# Requirement already satisfied: filelock in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from torch->torchvision->facenet-pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from torch->torchvision->facenet-pytorch) (4.8.0)
# Requirement already satisfied: sympy in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from torch->torchvision->facenet-pytorch) (1.12)
# Requirement already satisfied: networkx in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from torch->torchvision->facenet-pytorch) (3.1)
# Requirement already satisfied: jinja2 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from torch->torchvision->facenet-pytorch) (3.1.2)
# Collecting fsspec (from torch->torchvision->facenet-pytorch)
#   Downloading fsspec-2023.12.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from jinja2->torch->torchvision->facenet-pytorch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from sympy->torch->torchvision->facenet-pytorch) (1.3.0)
# Downloading fsspec-2023.12.1-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.9/168.9 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: fsspec, facenet-pytorch
# Successfully installed facenet-pytorch-2.5.3 fsspec-2023.12.1

# %%
import torch
from facenet_pytorch import MTCNN
from PIL import Image
import matplotlib.pyplot as plt

# Initialize the MTCNN model
mtcnn = MTCNN(keep_all=True, device=torch.device('cuda:0' if torch.cuda.is_available() else 'cpu'))

# Load an image
image = Image.open('images/Trump.jpg')

# Detect faces
boxes, _ = mtcnn.detect(image)

# Draw boxes on the image
fig, ax = plt.subplots()
ax.imshow(image)
if boxes is not None:
    for box in boxes:
        rect = plt.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1], fill=False, color='red')
        ax.add_patch(rect)

plt.show()

# %%
boxes
# Out:
# array([[78.01778411865234, 71.86253356933594, 250.15879821777344,
#         293.8951110839844]], dtype=object)

# %%
boxes
# Out:
# array([[78.01778411865234, 71.86253356933594, 250.15879821777344,
#         293.8951110839844]], dtype=object)

# %%
import torch
from facenet_pytorch import MTCNN
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

def mosaic(img, bounds, pixelation_level=15):
    """
    Apply a mosaic (pixelation) effect to a bounded region of the image.

    Args:
    - img (PIL.Image): The original image.
    - bounds (tuple): The bounding box (x_min, y_min, x_max, y_max) for the face.
    - pixelation_level (int): The level of pixelation.

    Returns:
    - img (PIL.Image): The image with the mosaic effect applied.
    """
    x_min, y_min, x_max, y_max = bounds
    # Convert coordinates to integers
    x_min, y_min, x_max, y_max = map(int, [x_min, y_min, x_max, y_max])
    
    # Crop the region to apply mosaic
    cropped_img = img.crop((x_min, y_min, x_max, y_max))
    # Resize cropped region to pixelate
    cropped_img = cropped_img.resize((pixelation_level, pixelation_level), resample=Image.BILINEAR)
    # Scale back to original size
    cropped_img = cropped_img.resize((x_max - x_min, y_max - y_min), Image.NEAREST)
    # Paste the pixelated region back
    img.paste(cropped_img, (x_min, y_min, x_max, y_max))
    return img


# Initialize the MTCNN model
mtcnn = MTCNN(keep_all=True, device=torch.device('cuda:0' if torch.cuda.is_available() else 'cpu'))

# Load an image
image = Image.open('images/Trump.jpg')

# Detect faces
boxes, _ = mtcnn.detect(image)

# Apply mosaic to detected faces
if boxes is not None:
    for box in boxes:
        image = mosaic(image, box)

# Show the result
plt.imshow(image)
plt.axis('off')
plt.show()
