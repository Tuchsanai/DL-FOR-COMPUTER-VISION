# %%
import cv2  
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('./images/banana.jpg')

# plot the image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_yellow = np.array([20, 100, 100])
upper_yellow = np.array([30, 255, 255])


# Mask for yellow banana
mask_yellow = cv2.inRange(hsv_image, lower_yellow, upper_yellow)

# %%
# segmenting the yellow banana from mask_yellow
segmented_yellow = cv2.bitwise_and(image, image, mask = mask_yellow)

# plot image and segmented image
plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(segmented_yellow, cv2.COLOR_BGR2RGB))
plt.title('Segmented Image')
# Out:
# Text(0.5, 1.0, 'Segmented Image')
