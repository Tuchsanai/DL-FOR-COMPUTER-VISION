# %% [markdown]
# # OpenCV Basics: Reading & Displaying Images
#
# ## Introduction
# OpenCV (Open Source Computer Vision Library) is a powerful library for image processing and computer vision tasks in Python.
#
# ## Installation

# %%
# Install OpenCV using pip
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/envs/torch/lib/python3.12/site-packages (from opencv-python) (1.26.4)

# %% [markdown]
# # Importing OpenCV

# %%
import cv2
import numpy as np
print(cv2.__version__)
# Out:
# 4.11.0

# %% [markdown]
# ### **Loading Images**

# %%
# Load an image using 'imread' specifying the path to image
image = cv2.imread('.././images/Taj_Mahal.jpg')
image.shape
# Out:
# (712, 796, 3)

# %%
image[:,:,2]
# Out:
# array([[157, 157, 157, ..., 112, 112, 112],
#        [155, 156, 156, ..., 112, 112, 112],
#        [151, 152, 153, ..., 112, 112, 112],
#        ...,
#        [ 31,  28,  19, ...,  16,  16,  16],
#        [ 39,  29,  26, ...,  12,  12,  13],
#        [ 35,  36,  46, ...,  15,  15,  16]], shape=(712, 796), dtype=uint8)

# %% [markdown]
# ### **Displaying Images BGR**

# %%
from matplotlib import pyplot as plt

image = cv2.imread('.././images/Taj_Mahal.jpg')
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
from matplotlib import pyplot as plt

# Show the image with matplotlib without axis
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# Let's create a simple function to make displaying our images simpler and easier

# %% [markdown]
# ### **Saving Images**

# %%
cv2.imwrite('output.jpg', image)
# Out:
# True

# %%
cv2.imwrite('output.png', image)
# Out:
# True

# %% [markdown]
# ### **Displaying Image Dimensions**
#
# Remember Images are arrays:
#
# ![](https://raw.githubusercontent.com/rajeevratan84/ModernComputerVision/main/array.png?token=ADLZD2HNEL33JAKTYRM3B5C7WMIV4)

# %% [markdown]
# We need to use numpy to perform this operation. Don't worry, numpy will become one of your best friends if you're learning a Data Science and Computer Vision.

# %%
# Import numpy
import numpy as np

print(image.shape)
# Out:
# (712, 796, 3)

# %%
# To access a dimension, simply index it by using 0, 1 or 2.
image.shape[0]
# Out:
# 712

# %% [markdown]
# You can see the first dimension is the height and it's 960 pixels
#
# The second dimension is the width which is 1280 pixels.
#
# We can print them out nicely like this:

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 712 pixels
# Width of Image: 796 pixels
# Depth of Image: 3 colors components
