# %% [markdown]
# # 🧪 Lab: Prompt Engineering กับ MLflow
# ## เรียนรู้ 3 เทคนิค + Reflection Loop + การติดตามผลด้วย MLflow
#
# ---
#
# ## 🎯 เป้าหมายของ Lab นี้
#
# ในการพัฒนา AI Application จริง เราต้องการ:
# 1. **เทคนิคการเขียน Prompt ที่ดี** → ให้ AI ตอบถูกต้องและมีคุณภาพ
# 2. **ระบบติดตามผล** → รู้ว่า Prompt เวอร์ชันไหนดีที่สุด
# 3. **การปรับปรุงอัตโนมัติ** → ให้ AI ช่วยปรับ Prompt เอง
#
# Lab นี้จะสอน 3 เทคนิคหลัก + วิธีใช้ MLflow ติดตามทุกอย่าง
#
# ---
#
# # 🧪 Big Picture: Prompt Engineering + MLflow
#
# ---
#
# ## 🗺️ ภาพรวมทั้ง 3 เทคนิค
#
# ```
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║                                                                        ║
# ║   📝 Problem / Task                                                    ║
# ║   ─────────────────                                                    ║
# ║        │                                                               ║
# ║        ├──────────────────┬──────────────────┐                         ║
# ║        ▼                  ▼                  ▼                         ║
# ║   ┌─────────┐       ┌─────────┐       ┌─────────┐                     ║
# ║   │ 🎯 T1   │       │ 🔗 T2   │       │ ⚔️ T3   │                     ║
# ║   │  Self-   │       │ Prompt  │       │  Self-  │                     ║
# ║   │Consiste- │       │Chaining │       │Critique │                     ║
# ║   │  ncy     │       │         │       │         │                     ║
# ║   └────┬─────┘       └────┬────┘       └────┬────┘                     ║
# ║        │                  │                  │                         ║
# ║        ▼                  ▼                  ▼                         ║
# ║   ┌─────────┐       ┌─────────┐       ┌─────────┐                     ║
# ║   │ Answer  │       │ Answer  │       │ Answer  │                     ║
# ║   └────┬────┘       └────┬────┘       └────┬────┘                     ║
# ║        │                  │                  │                         ║
# ║        └──────────────────┼──────────────────┘                         ║
# ║                           ▼                                            ║
# ║                  ┌─────────────────┐                                   ║
# ║                  │  🔁 Reflection  │                                   ║
# ║                  │     Loop        │                                   ║
# ║                  └────────┬────────┘                                   ║
# ║                           ▼                                            ║
# ║                  ┌─────────────────┐                                   ║
# ║                  │  📊 MLflow      │                                   ║
# ║                  │  Track & Compare│                                   ║
# ║                  └─────────────────┘                                   ║
# ║                                                                        ║
# ╚══════════════════════════════════════════════════════════════════════════╝
# ```
#
# ---
#
# ## 🎯 Technique 1 — Self-Consistency
#
# > ถามคำถามเดิมซ้ำ N ครั้ง → รวบรวมคำตอบ → โหวตเสียงข้างมาก
#
# ```
#                         ╭───────────╮
#                         │  🧮 โจทย์  │
#                         ╰─────┬─────╯
#                               │
#               ┌───────────────┼───────────────┐
#               ▼               ▼               ▼
#         ╭───────────╮  ╭───────────╮  ╭───────────╮
#         │  🧠 Path 1 │  │  🧠 Path 2 │  │  🧠 Path 3 │
#         │  temp=0.7  │  │  temp=0.7  │  │  temp=0.7  │
#         ╰─────┬─────╯  ╰─────┬─────╯  ╰─────┬─────╯
#               │               │               │
#               ▼               ▼               ▼
#           ╭──────╮       ╭──────╮       ╭──────╮
#           │  42  │       │  42  │       │  38  │
#           ╰──┬───╯       ╰──┬───╯       ╰──┬───╯
#               │               │               │
#               └───────────────┼───────────────┘
#                               ▼
#                      ╭────────────────╮
#                      │  🗳️ Majority   │
#                      │     Vote       │
#                      ╰───────┬────────╯
#                               ▼
#                      ╭────────────────╮
#                      │  ✅ Answer: 42 │
#                      │  Confidence 67%│
#                      ╰────────────────╯
# ```
#
# **เมื่อไหร่ควรใช้:** คณิตศาสตร์ · Logic · คำถามที่มีคำตอบเดียว
#
# ---
#
# ## 🔗 Technique 2 — Prompt Chaining
#
# > แบ่งงานเป็นขั้นตอนย่อย → ส่ง output ต่อกันเป็นทอด ๆ
#
# ```
#    ╭──────────╮
#    │  💬 Review │
#    ╰─────┬────╯
#          │
#          ▼
#    ╔═══════════════════════════════╗
#    ║  Step 1: 🔍 Extract          ║
#    ║  สกัดข้อมูลจาก Review        ║
#    ║  → positive, negative, tone  ║
#    ╚═════════════╤═════════════════╝
#                  │  JSON output
#                  ▼
#    ╔═══════════════════════════════╗
#    ║  Step 2: 📊 Analyze          ║
#    ║  วิเคราะห์ Sentiment & Risk  ║
#    ║  → score, urgent fixes       ║
#    ╚═════════════╤═════════════════╝
#                  │  JSON output
#                  ▼
#    ╔═══════════════════════════════╗
#    ║  Step 3: 📋 Report           ║
#    ║  สรุป Executive Summary      ║
#    ║  → headline, actions, risk   ║
#    ╚═══════════════════════════════╝
#                  │
#                  ▼
#           ╭──────────────╮
#           │ 📄 รายงานสรุป │
#           ╰──────────────╯
# ```
#
# **เมื่อไหร่ควรใช้:** งานซับซ้อนหลายขั้น · Document Processing · ต้องการ Debug แยกขั้น
#
# ---
#
# ## ⚔️ Technique 3 — Self-Critique
#
# > ให้ AI ตรวจงานตัวเอง → ชี้จุดอ่อน → แก้ไข → วนซ้ำ
#
# ```
#    ╭──────────╮
#    │  ❓ คำถาม │
#    ╰─────┬────╯
#          │
#          ▼
#    ╔════════════════╗
#    ║  📝 Generate   ║──────────╮
#    ║  สร้างคำตอบ    ║          │
#    ╚═══════╤════════╝          │
#            │                   │
#            ▼                   │ วนซ้ำได้
#    ╔════════════════╗          │ N รอบ
#    ║  ⚔️ Critique    ║          │
#    ║  วิพากษ์จุดอ่อน ║          │
#    ║  ─────────────  ║          │
#    ║  □ Logic Error? ║          │
#    ║  □ Missing View?║          │
#    ║  □ Bias?        ║          │
#    ╚═══════╤════════╝          │
#            │                   │
#            ▼                   │
#    ╔════════════════╗          │
#    ║  ✏️ Revise      ║──────────╯
#    ║  แก้ไขตามคำวิจ. ║
#    ╚═══════╤════════╝
#            │
#            ▼
#    ╭────────────────╮
#    │ ✅ คำตอบสุดท้าย │
#    │ (รอบด้านขึ้น)   │
#    ╰────────────────╯
# ```
#
# **เมื่อไหร่ควรใช้:** หัวข้อ Controversial · ต้องการ Unbiased · ต้องการความถูกต้องสูง
#
# ---
#
# ## 🔁 Reflection Loop — ปรับปรุง Prompt อัตโนมัติ
#
# > ทดสอบ Prompt → วิเคราะห์ข้อผิด → สร้าง Prompt ใหม่ → วนจนถึงเป้า
#
# ```
#    ╭─────────────────╮
#    │ 📝 Prompt v1     │
#    ╰────────┬────────╯
#             │
#             ▼
#    ╔════════════════════╗         ╭──────────────────╮
#    ║  🧪 Evaluate       ║────YES──▶│ 🎉 ถึงเป้าหมาย!  │
#    ║  ทดสอบกับ Dataset  ║         │    accuracy ≥ 83% │
#    ║  accuracy ≥ 83%?  ║         ╰──────────────────╯
#    ╚═════════╤══════════╝
#              │ NO
#              ▼
#    ╔════════════════════╗
#    ║  🔍 Reflect        ║
#    ║  วิเคราะห์ข้อที่ผิด ║
#    ║  หา pattern ข้อผิด ║
#    ╚═════════╤══════════╝
#              │
#              ▼
#    ╔════════════════════╗
#    ║  🆕 Improve        ║
#    ║  สร้าง Prompt v2   ║
#    ║  ลงทะเบียน MLflow  ║
#    ╚═════════╤══════════╝
#              │
#              ╰──────────────────╮
#                                 │ loop กลับไป Evaluate
#    ╭─────────────────╮         │
#    │ 📝 Prompt v2     │◀────────╯
#    ╰─────────────────╯
# ```
#
# ---
#
# ## 📊 MLflow — ศูนย์กลางการติดตามทุกอย่าง
#
# ```
#    ╔══════════════════════════════════════════════════════════╗
#    ║                    📊 MLflow Server                      ║
#    ╠══════════════════════════════════════════════════════════╣
#    ║                                                          ║
#    ║  ┌──────────────────┐    ┌──────────────────────────┐   ║
#    ║  │ 📦 Prompt Registry│    │ 📈 Experiment Tracking    │   ║
#    ║  │                  │    │                          │   ║
#    ║  │ sc_math_solver   │    │  Metrics:                │   ║
#    ║  │   v1 → v2 → v3  │    │    accuracy: 83.3%       │   ║
#    ║  │                  │    │    iterations: 2         │   ║
#    ║  │ chain_extract v1 │    │                          │   ║
#    ║  │ chain_analyze v1 │    │  Parameters:             │   ║
#    ║  │ chain_report  v1 │    │    model: gemini-2.0     │   ║
#    ║  │                  │    │    sc_samples: 3         │   ║
#    ║  │ crit_generate v1 │    │    target_acc: 83%       │   ║
#    ║  │ crit_critic   v1 │    │                          │   ║
#    ║  │ crit_revise   v1 │    │                          │   ║
#    ║  └──────────────────┘    └──────────────────────────┘   ║
#    ║                                                          ║
#    ╚══════════════════════════════════════════════════════════╝
# ```
#
# ---
#
# ## 🧭 แนวคิดหลัก
#
# ```
#    วัดผล  ──▶  วิเคราะห์  ──▶  ปรับปรุง  ──▶  วัดผลซ้ำ
#      │            │               │               │
#      ▼            ▼               ▼               ▼
#    MLflow     Reflection      New Prompt       MLflow
#    Evaluate     Loop          Register        Compare
# ```
#
# > **"Prompt Engineering ไม่ใช่ศิลปะ แต่เป็นวิทยาศาสตร์"**
# > วัด → วิเคราะห์ → ปรับ → วนซ้ำ เหมือน Software Development ที่ดี

# %% [markdown]
# ---
# ## ⚙️ ส่วนที่ 0: ติดตั้งและตั้งค่า
#
# เริ่มต้นด้วยการ import library ที่จำเป็น และตั้งค่าการเชื่อมต่อ

# %%
# ติดตั้ง Library ที่จำเป็น
# !pip install mlflow google-genai -q
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# ─────────────────────────────────────────────────────────
#  Import Libraries
# ─────────────────────────────────────────────────────────

import mlflow
import mlflow.genai
import json
import time
import re

from collections import Counter
from typing import List, Dict, Any

from google import genai
from google.genai import types

# ─────────────────────────────────────────────────────────
#  การตั้งค่าหลัก (แก้ไขตรงนี้)
# ─────────────────────────────────────────────────────────

API_KEY   = "key"   # <<<< ใส่ Gemini API Key ของคุณ
MODEL_ID  = "gemini-2.0-flash"      # โมเดลที่ใช้
MLFLOW_URI = "http://127.0.0.1:5000" # ที่อยู่ MLflow Server

# ─────────────────────────────────────────────────────────
#  สร้าง Client และเชื่อมต่อ MLflow
# ─────────────────────────────────────────────────────────

client = genai.Client(api_key=API_KEY)

print("=" * 50)
print(f"  ✅ Gemini Model : {MODEL_ID}")
# Out:
# ==================================================
#   ✅ Gemini Model : gemini-2.0-flash

# %%
mlflow.set_tracking_uri(MLFLOW_URI)
mlflow.set_experiment("prompt_engineering_lab")  # ชื่อ Experiment ใน MLflow

print(f"  ✅ MLflow URI   : {mlflow.get_tracking_uri()}")
print("=" * 50)
# Out:
#   ✅ MLflow URI   : http://127.0.0.1:5000
# ==================================================

# %% [markdown]
# ### 💡 ทำไมต้องใช้ Version Tracker?
#
# MLflow เก็บ Prompt เป็น Version (1, 2, 3, ...) แต่**ไม่รองรับ "latest"** โดยตรง
# เราจึงสร้าง dictionary ไว้ติดตาม version ล่าสุดของแต่ละ prompt เอง
#
# ```
# _prompt_versions = {
#     "sc_math_solver": 3,    ← ตอนนี้อยู่ที่ version 3
#     "chain_extract":  1,    ← ยังอยู่ version 1
#     ...
# }
# ```

# %%
# ─────────────────────────────────────────────────────────
#  Version Tracker: ติดตาม Version ล่าสุดของแต่ละ Prompt
# ─────────────────────────────────────────────────────────

_prompt_versions: Dict[str, int] = {}


def track_version(name: str, version: int):
    """
    บันทึก version ล่าสุดของ prompt ลงใน dictionary
    ถ้า version ใหม่สูงกว่า version เดิม ให้อัปเดต
    """
    current_max = _prompt_versions.get(name, 0)
    _prompt_versions[name] = max(current_max, version)


def get_latest_version(name: str) -> int:
    """
    ดึง version ล่าสุดของ prompt
    ถ้ายังไม่เคย track ไว้ คืนค่า 1 เป็น default
    """
    return _prompt_versions.get(name, 1)


def load_latest_prompt(name: str):
    """
    โหลด prompt version ล่าสุดจาก MLflow Registry
    ใช้ format: prompts:/<ชื่อ>/<version>
    """
    latest_version = get_latest_version(name)
    prompt_uri = f"prompts:/{name}/{latest_version}"
    return mlflow.genai.load_prompt(prompt_uri)


# ─────────────────────────────────────────────────────────
#  ทดสอบว่า Version Tracker ทำงานได้
# ─────────────────────────────────────────────────────────

track_version("test_prompt", 1)
track_version("test_prompt", 3)
track_version("test_prompt", 2)  # ไม่ควรทับ version 3

assert get_latest_version("test_prompt") == 3, "Version Tracker มีปัญหา!"
print("  ✅ Version Tracker ทำงานถูกต้อง")
print(f"     track 1, 3, 2 → latest = {get_latest_version('test_prompt')}")
# Out:
#   ✅ Version Tracker ทำงานถูกต้อง
#      track 1, 3, 2 → latest = 3

# %% [markdown]
# ---
# ## 🎨 ส่วนที่ 1: Helper Functions สำหรับแสดงผล
#
# เราจะสร้างฟังก์ชันช่วยแสดงผลสวยงาม ใน Jupyter Notebook
# เพื่อให้อ่านและเข้าใจผลลัพธ์ได้ง่ายขึ้น

# %%
# ─────────────────────────────────────────────────────────
#  ฟังก์ชันหลัก: เรียก Gemini API
# ─────────────────────────────────────────────────────────

def call_gemini(prompt: str,
                temperature: float = 0.0,
                max_tokens: int = 2048) -> str:
    """
    ส่ง prompt ไปให้ Gemini และรับ text กลับมา

    Parameters:
        prompt      : ข้อความที่จะส่งให้ AI
        temperature : ความสร้างสรรค์ (0.0 = แม่นยำ, 1.0 = สร้างสรรค์)
        max_tokens  : จำนวน token สูงสุดของคำตอบ

    Returns:
        str : คำตอบจาก Gemini เป็น text
    """
    response = client.models.generate_content(
        model=MODEL_ID,
        contents=prompt,
        config=types.GenerateContentConfig(
            temperature=temperature,
            max_output_tokens=max_tokens,
        ),
    )
    return response.text


# ─────────────────────────────────────────────────────────
#  ฟังก์ชันแสดงผล: หัวข้อ (Title)
# ─────────────────────────────────────────────────────────

def print_title(text: str, level: int = 1):
    """
    แสดงหัวข้อแบ่งระดับ

    level 1 → หัวข้อใหญ่ (มีกรอบ ━━━)
    level 2 → หัวข้อรอง (เส้น ──)
    level 3 → หัวข้อย่อย (จุด ▸)
    """
    if level == 1:
        border = "━" * 62
        print(f"\n{border}")
        print(f"  🔷 {text}")
        print(f"{border}")

    elif level == 2:
        padding = "─" * max(1, 500 - len(text))
        print(f"\n  ── {text} {padding}")

    else:  # level 3
        print(f"\n    ▸ {text}")


# ─────────────────────────────────────────────────────────
#  ฟังก์ชันแสดงผล: กล่องข้อความ (Box)
# ─────────────────────────────────────────────────────────

def print_box(title: str, content: str,
              emoji: str = "📌", width: int = 78):
    """
    แสดงข้อความในกล่องสวยงาม พร้อม Word-wrap อัตโนมัติ

    Parameters:
        title   : ชื่อกล่อง
        content : เนื้อหาภายในกล่อง
        emoji   : ไอคอนหัวกล่อง
        width   : ความกว้างกล่อง (characters)
    """
    inner_width = width - 4  # พื้นที่ข้อความ (ลบกรอบ 4 ด้าน)

    # วาดกรอบบน
    print(f"\n  ┌{'─' * (width - 2)}┐")
    print(f"  │ {emoji} {title:<{inner_width - 2}}│")
    print(f"  ├{'─' * (width - 2)}┤")
    print(f"  │{' ' * (width - 2)}│")

    # แสดงเนื้อหาทีละบรรทัด พร้อม Word-wrap
    for line in content.split("\n"):
        line = line.rstrip()

        if not line:
            # บรรทัดว่าง
            print(f"  │{' ' * (width - 2)}│")
            continue

        # ตัดบรรทัดยาวให้พอดีกล่อง
        while len(line) > inner_width:
            cut_point = line[:inner_width].rfind(" ")
            if cut_point <= 0:
                cut_point = inner_width  # ตัดกลางคำถ้าจำเป็น
            print(f"  │ {line[:cut_point]:<{inner_width}} │")
            line = line[cut_point:].lstrip()

        print(f"  │ {line:<{inner_width}} │")

    # วาดกรอบล่าง
    print(f"  │{' ' * (width - 2)}│")
    print(f"  └{'─' * (width - 2)}┘")


# ─────────────────────────────────────────────────────────
#  ฟังก์ชันแสดงผล: ตาราง (Table)
# ─────────────────────────────────────────────────────────

def print_table(headers: List[str],
                rows: List[List[str]],
                title: str = ""):
    """
    แสดงตารางสวยงาม พร้อมปรับความกว้างแต่ละคอลัมน์อัตโนมัติ

    Parameters:
        headers : ชื่อคอลัมน์ ['Col A', 'Col B', ...]
        rows    : ข้อมูลแต่ละแถว [['a1', 'b1'], ['a2', 'b2'], ...]
        title   : หัวตาราง (optional)
    """
    if title:
        print(f"\n  📊 {title}")

    # คำนวณความกว้างแต่ละคอลัมน์ = max(ความยาว header, ความยาว data)
    col_widths = [
        max(
            len(str(header)),
            max((len(str(row[i])) for row in rows), default=0)
        ) + 2
        for i, header in enumerate(headers)
    ]

    # สร้าง separator แต่ละคอลัมน์
    def make_separator(left, mid, right):
        return f"  {left}" + f"{mid}".join("─" * (w + 1) for w in col_widths) + f"─{right}"

    # วาดหัวตาราง
    print(make_separator("┌", "─┬", "─┐"))

    header_line = "  │".join(f" {h:^{w}}" for h, w in zip(headers, col_widths))
    print(f"  │{header_line} │")

    print(make_separator("├", "─┼", "─┤"))

    # วาดข้อมูลแต่ละแถว
    for row in rows:
        row_line = "  │".join(f" {str(v):^{w}}" for v, w in zip(row, col_widths))
        print(f"  │{row_line} │")

    print(make_separator("└", "─┴", "─┘"))


# ─────────────────────────────────────────────────────────
#  ฟังก์ชันแสดงผล: Progress Bar และ Metric
# ─────────────────────────────────────────────────────────

def print_progress(current: int, total: int,
                   label: str = "", bar_width: int = 30):
    """
    แสดง Progress Bar แบบ text
    ตัวอย่าง: [████████░░░░░░░░░░░░░░░░░░░░░░] 27% Iter 1

    """
    pct = current / total if total > 0 else 0
    filled = int(bar_width * pct)
    bar = "█" * filled + "░" * (bar_width - filled)
    print(f"  [{bar}] {pct:.0%}  {label}")


def print_metric(label: str, value, unit: str = "", emoji: str = "📈"):
    """
    แสดง Metric สั้นๆ
    ตัวอย่าง: 📈 Accuracy: 83.3%
    """
    if isinstance(value, float):
        print(f"    {emoji} {label}: {value:.1f}{unit}")
    else:
        print(f"    {emoji} {label}: {value}{unit}")


def print_divider(char: str = "─", width: int = 60):
    """แสดงเส้นคั่น"""
    print(f"  {char * width}")


# ─────────────────────────────────────────────────────────
#  ทดสอบ Helper Functions
# ─────────────────────────────────────────────────────────

print_title("ทดสอบ Helper Functions", 1)
print_title("ระดับ 2: หัวข้อรอง", 2)
print_title("ระดับ 3: หัวข้อย่อย", 3)

print_box(
    title   = "ตัวอย่าง Box",
    content = "บรรทัดที่ 1: Hello World\nบรรทัดที่ 2: สวัสดีโลก\n\nบรรทัดว่าง แล้วต่อ...",
    emoji   = "🎯",
)

print_table(
    headers = ["เทคนิค", "ความซับซ้อน", "ใช้เมื่อ"],
    rows    = [
        ["Self-Consistency", "ปานกลาง", "Math / Logic"],
        ["Prompt Chaining",  "สูง",     "งานหลายขั้น"],
        ["Self-Critique",    "สูง",     "ต้องการ Accuracy สูง"],
    ],
    title = "ตัวอย่างตาราง",
)

print_progress(70, 100, "Example 70%")
print_metric("Test Score", 92.5, "%", "🏆")
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 ทดสอบ Helper Functions
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   ── ระดับ 2: หัวข้อรอง ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#     ▸ ระดับ 3: หัวข้อย่อย
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🎯 ตัวอย่าง Box                                                            │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ บรรทัดที่ 1: Hello World                                                   │
#   │ บรรทัดที่ 2: สวัสดีโลก                                                     │
#   │                                                                            │
#   │ บรรทัดว่าง แล้วต่อ...                                                      │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   📊 ตัวอย่างตาราง
#   ┌────────────────────┬───────────────┬─────────────────────────┐
#   │       เทคนิค        │  ความซับซ้อน   │        ใช้เมื่อ        │
#   ├────────────────────┼───────────────┼─────────────────────────┤
#   │  Self-Consistency   │    ปานกลาง     │      Math / Logic      │
#   │  Prompt Chaining    │      สูง       │      งานหลายขั้น       │
#   │   Self-Critique     │      สูง       │  ต้องการ Accuracy สูง  │
#   └────────────────────┴───────────────┴─────────────────────────┘
#   [█████████████████████░░░░░░░░░] 70%  Example 70%
#     🏆 Test Score: 92.5%

# %%
# ─────────────────────────────────────────────────────────
#  ทดสอบการเชื่อมต่อ Gemini API
# ─────────────────────────────────────────────────────────

print_title("ทดสอบการเชื่อมต่อ Gemini API")

test_prompt = "ตอบสั้นๆ ภายใน 1 ประโยค: MLflow ช่วยอะไรในการพัฒนา AI?"
test_answer = call_gemini(test_prompt, max_tokens=100)

print_box(
    title   = "คำถามทดสอบ",
    content = f"Q: {test_prompt}\n\nA: {test_answer}",
    emoji   = "🧪",
)
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 ทดสอบการเชื่อมต่อ Gemini API
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🧪 คำถามทดสอบ                                                              │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ Q: ตอบสั้นๆ ภายใน 1 ประโยค: MLflow ช่วยอะไรในการพัฒนา AI?                  │
#   │                                                                            │
#   │ A: MLflow ช่วยจัดการวงจรชีวิตของโมเดล AI ตั้งแต่การทดลอง, การติดตามผล,     │
#   │ การสร้างแพ็กเกจ, ไปจนถึงการนำไปใช้งานจริง                                  │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ---
# ## 📘 เทคนิคที่ 1: Self-Consistency (SC)
#
# ### หลักการ
#
# แทนที่จะถามคำถามครั้งเดียว → ถาม **N ครั้ง** ด้วย temperature สูง
# (ทำให้ได้ reasoning paths ที่หลากหลาย) → **โหวตเสียงข้างมาก**
#
# ### ทำไมถึงได้ผล?
#
# - AI อาจเดินทางผิดในบางครั้ง แต่ถ้าถาม 5 ครั้ง ส่วนใหญ่จะได้คำตอบถูก
# - Majority voting ช่วยกรองข้อผิดพลาดออก
# - ยิ่ง N มาก ยิ่งแม่นยำ (แต่ใช้เวลาและ token มากขึ้น)
#
# ### แผนผัง
#
# ```
#                    ┌─ Path 1 (temp=0.7) ── Answer: 42 ─┐
#                    │                                     │
#  Question ─────────┼─ Path 2 (temp=0.7) ── Answer: 42 ─┼──→ โหวต → 42 ✅
#                    │                                     │    (2/3)
#                    └─ Path 3 (temp=0.7) ── Answer: 38 ─┘
# ```
#
# ### เหมาะกับงานประเภทไหน?
#
# | ✅ เหมาะ | ❌ ไม่เหมาะ |
# |---------|-----------|
# | คณิตศาสตร์ | งานสร้างสรรค์ |
# | Logic / Reasoning | งานที่ต้องการ variety |
# | คำถามที่มีคำตอบเดียว | ต้องการประหยัด cost |

# %% [markdown]
# ![image.png](attachment:c09e3471-1dfe-4c93-9d0c-a4af84dcb143.png)

# %%
# ─────────────────────────────────────────────────────────
#  ลงทะเบียน Self-Consistency Prompt v1 ใน MLflow
# ─────────────────────────────────────────────────────────

print_title("เทคนิคที่ 1: Self-Consistency")

SC_PROMPT_NAME = "sc_math_solver"

# Prompt Version 1: ง่าย ตรงไปตรงมา
SC_PROMPT_V1 = """วิเคราะห์ปัญหาต่อไปนี้และให้คำตอบ

ปัญหา: {{ problem }}

แสดงวิธีคิดทีละขั้นตอน แล้วสรุปคำตอบเป็นตัวเลข"""

# ลงทะเบียนใน MLflow Prompt Registry
sc_prompt_v1 = mlflow.genai.register_prompt(
    name=SC_PROMPT_NAME,
    template=SC_PROMPT_V1,
    commit_message="v1: Basic prompt — minimal instruction",
)

track_version(SC_PROMPT_NAME, sc_prompt_v1.version)

print(f"  ✅ ลงทะเบียนสำเร็จ: '{SC_PROMPT_NAME}' version {sc_prompt_v1.version}")
print_box(
    title   = f"SC Prompt v{sc_prompt_v1.version}",
    content = SC_PROMPT_V1,
    emoji   = "📝",
)
# Out:
# 2026/02/18 04:10:56 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: sc_math_solver, version 4
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 เทคนิคที่ 1: Self-Consistency
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   ✅ ลงทะเบียนสำเร็จ: 'sc_math_solver' version 4
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 📝 SC Prompt v4                                                            │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ วิเคราะห์ปัญหาต่อไปนี้และให้คำตอบ                                          │
#   │                                                                            │
#   │ ปัญหา: {{ problem }}                                                       │
#   │                                                                            │
#   │ แสดงวิธีคิดทีละขั้นตอน แล้วสรุปคำตอบเป็นตัวเลข                             │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘

# %%
# ─────────────────────────────────────────────────────────
#  Self-Consistency Engine: ส่วนสำคัญของเทคนิค
# ─────────────────────────────────────────────────────────

def extract_number_from_text(text: str) -> str:
    """
    สกัดตัวเลขสุดท้ายจาก text
    เหตุผล: AI มักสรุปคำตอบไว้ตอนท้าย เช่น "ดังนั้น คำตอบคือ 42"

    ตัวอย่าง:
        "...ดังนั้น คำตอบคือ 1,575 บาท" → "1575"
        "แต่ละคนได้ 4 ลูก"               → "4"
    """
    # หาตัวเลขทั้งหมด (รวม comma และ decimal)
    all_numbers = re.findall(r"\b\d[\d,]*(?:\.\d+)?\b", text)

    if not all_numbers:
        return "N/A"

    # เอาตัวเลขสุดท้าย (มักเป็นคำตอบสุดท้าย) และลบ comma ออก
    last_number = all_numbers[-1].replace(",", "")
    return last_number


def run_self_consistency(template: str,
                         problem: str,
                         n_samples: int = 5,
                         temperature: float = 0.7,
                         show_details: bool = True) -> Dict:
    """
    รัน Self-Consistency: สุ่มคำตอบ N ครั้ง → Majority Vote

    Parameters:
        template     : Prompt template (มี {{ problem }})
        problem      : โจทย์ที่ต้องการคำตอบ
        n_samples    : จำนวนครั้งที่ถาม (มากขึ้น = แม่นยำขึ้น แต่ช้าลง)
        temperature  : ความหลากหลายของคำตอบ (สูง = หลากหลาย)
        show_details : True = แสดงทุก Path (debug mode)
                       False = แสดงแค่สรุป (fast mode)

    Returns:
        dict: {
            "final_answer" : คำตอบที่ชนะการโหวต
            "confidence"   : สัดส่วน (เช่น 0.6 = 3/5)
            "answers"      : list คำตอบทุก path
            "distribution" : การกระจายของคำตอบ
        }
    """
    # แทน placeholder ด้วยโจทย์จริง
    filled_prompt = template.replace("{{ problem }}", problem)

    answers_collected = []
    full_responses = []

    print_title(f"รัน {n_samples} Reasoning Paths (temperature={temperature})", 2)

    # ── รัน N paths ──
    for path_num in range(1, n_samples + 1):

        # เรียก AI
        response = call_gemini(filled_prompt, temperature=temperature)
        full_responses.append(response)

        # สกัดคำตอบตัวเลข
        extracted_ans = extract_number_from_text(response)
        answers_collected.append(extracted_ans)

        if show_details:
            # แสดงผล path เต็มๆ ใน box
            print_box(
                title   = f"Path {path_num}/{n_samples}  →  คำตอบ: {extracted_ans}",
                content = response,
                emoji   = "🧠",
            )
        else:
            # แสดงสรุปสั้น (1 บรรทัด)
            preview = response.replace("\n", " ")[:65]
            status  = "✅" if extracted_ans != "N/A" else "⚠️"
            print(f"      {status} Path {path_num}: ans={extracted_ans:>10s}  │  {preview}...")

        time.sleep(1.0)  # หน่วงเวลาเล็กน้อย ป้องกัน rate limit

    # ── Majority Voting ──
    # นับเฉพาะคำตอบที่สกัดได้ (ไม่นับ "N/A")
    vote_counter = Counter(a for a in answers_collected if a != "N/A")

    if vote_counter:
        winner_ans, winner_count = vote_counter.most_common(1)[0]
        confidence = winner_count / n_samples
    else:
        winner_ans, confidence = "N/A", 0.0

    # ── แสดงผล Vote ──
    vote_lines = []
    for ans, count in vote_counter.most_common():
        filled_bar = "█" * (count * 6)
        empty_bar  = "░" * ((n_samples - count) * 6)
        is_winner  = "  ← Winner ✅" if ans == winner_ans else ""
        vote_lines.append(f"  {ans:>12s} :  {filled_bar}{empty_bar}  ({count}/{n_samples}){is_winner}")

    vote_lines.append(f"\n  🏆 Final Answer : {winner_ans}")
    vote_lines.append(f"  📊 Confidence   : {confidence:.0%}  ({int(confidence * n_samples)}/{n_samples} เห็นด้วย)")

    print_box(
        title   = "ผลการโหวต (Majority Vote)",
        content = "\n".join(vote_lines),
        emoji   = "🗳️",
    )

    return {
        "final_answer" : winner_ans,
        "confidence"   : confidence,
        "answers"      : answers_collected,
        "distribution" : dict(vote_counter),
        "all_responses": full_responses,
    }

# %%
# ─────────────────────────────────────────────────────────
#  ทดสอบ Self-Consistency
# ─────────────────────────────────────────────────────────

# โจทย์ง่าย: ทดสอบว่า SC ทำงานได้
EASY_PROBLEM = "มีแอปเปิ้ล 24 ลูก แบ่งให้เด็ก 6 คนเท่าๆ กัน แต่ละคนได้กี่ลูก?"

# โจทย์ยาก: หลายขั้นตอน มีหน่วยซับซ้อน
HARD_PROBLEM = """บริษัทมีพนักงาน 3 แผนก:
- แผนก A: 15 คน เงินเดือนเฉลี่ย 35,000 บาท
- แผนก B: 20 คน เงินเดือนเฉลี่ย 42,000 บาท
- แผนก C: 10 คน เงินเดือนเฉลี่ย 58,000 บาท

บริษัทจะขึ้นเงินเดือนทุกคน 8%
ค่าใช้จ่ายเงินเดือนรวมต่อเดือนหลังขึ้นเงินเดือนเป็นเท่าไหร่?"""

# %%
# ── ทดสอบโจทย์ง่าย ──
print_title("ทดสอบ: โจทย์ง่าย (หาร)")
print_box("โจทย์", EASY_PROBLEM, "❓")
sc_easy_result = run_self_consistency(SC_PROMPT_V1, EASY_PROBLEM, n_samples=3)
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 ทดสอบ: โจทย์ง่าย (หาร)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ ❓ โจทย์                                                                   │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ มีแอปเปิ้ล 24 ลูก แบ่งให้เด็ก 6 คนเท่าๆ กัน แต่ละคนได้กี่ลูก?              │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🧠 Path 1/3  →  คำตอบ: 4                                                   │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ **วิธีคิดทีละขั้นตอน:**                                                    │
#   │                                                                            │
#   │ 1. **โจทย์ถามอะไร:** โจทย์ถามว่า เด็กแต่ละคนจะได้แอปเปิ้ลกี่ลูก            │
#   │ 2. **โจทย์ให้อะไรมา:** โจทย์ให้จำนวนแอปเปิ้ลทั้งหมด (24 ลูก) และจำนวนเด็ก  │
#   │ (6 คน)                                                                     │
#   │ 3. **ต้องใช้วิธีอะไร:** เนื่องจากต้องการแบ่งแอปเปิ้ลให้เด็กแต่ละคนเท่าๆ    │
#   │ กัน เราจึงต้องใช้วิธีหาร                                                   │
#   │ 4. **เขียนประโยคสัญลักษณ์:** 24 ÷ 6 = ?                                    │
#   │ 5. **คำนวณ:** 24 หารด้วย 6 เท่ากับ 4                                       │
#   │                                                                            │
#   │ **สรุปคำตอบ:**                                                             │
#   │                                                                            │
#   │ เด็กแต่ละคนจะได้แอปเปิ้ล **4** ลูก                                         │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🧠 Path 2/3  →  คำตอบ: 4                                                   │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ **วิธีคิดทีละขั้นตอน:**                                                    │
#   │                                                                            │
#   │ 1. **โจทย์ถามอะไร:** โจทย์ถามว่าถ้าแบ่งแอปเปิ้ล 24 ลูก ให้เด็ก 6 คนเท่าๆ   │
#   │ กัน แต่ละคนจะได้แอปเปิ้ลกี่ลูก                                             │
#   │                                                                            │
#   │ 2. **ใช้วิธีอะไรในการแก้ปัญหา:**                                           │
#   │ ปัญหานี้เป็นการแบ่งสิ่งของออกเป็นส่วนเท่าๆ กัน ดังนั้นเราจะใช้วิธีการ      │
#   │ **หาร**                                                                    │
#   │                                                                            │
#   │ 3. **เขียนประโยคสัญลักษณ์:** 24 ÷ 6 = ?                                    │
#   │                                                                            │
#   │ 4. **ทำการหาร:** 24 ÷ 6 = 4                                                │
#   │                                                                            │
#   │ **สรุปคำตอบ:**                                                             │
#   │                                                                            │
#   │ แต่ละคนจะได้แอปเปิ้ล **4** ลูก                                             │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🧠 Path 3/3  →  คำตอบ: 4                                                   │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ **วิธีคิดทีละขั้นตอน:**                                                    │
#   │                                                                            │
#   │ 1. **โจทย์กำหนดอะไร:**                                                     │
#   │    - มีแอปเปิ้ลทั้งหมด 24 ลูก                                              │
#   │    - มีเด็กทั้งหมด 6 คน                                                    │
#   │    - ต้องการแบ่งแอปเปิ้ลให้เด็กแต่ละคนเท่าๆ กัน                            │
#   │                                                                            │
#   │ 2. **โจทย์ถามอะไร:**                                                       │
#   │    - เด็กแต่ละคนจะได้แอปเปิ้ลกี่ลูก?                                       │
#   │                                                                            │
#   │ 3. **ใช้วิธีการอะไร:**                                                     │
#   │    - ใช้การหาร เพื่อแบ่งของให้เท่าๆ กัน                                    │
#   │                                                                            │
#   │ 4. **เขียนสมการ:**                                                         │
#   │    - จำนวนแอปเปิ้ลทั้งหมด / จำนวนเด็ก = จำนวนแอปเปิ้ลต่อคน                 │
#   │    - 24 / 6 = ?                                                            │
#   │                                                                            │
#   │ 5. **คำนวณ:**                                                              │
#   │    - 24 / 6 = 4                                                            │
#   │                                                                            │
#   │ **สรุปคำตอบ:**                                                             │
#   │                                                                            │
#   │ เด็กแต่ละคนจะได้แอปเปิ้ล 4 ลูก                                             │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │              4 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 4                                                       │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘

# %%
# ── ทดสอบโจทย์ยาก ──
print_title("ทดสอบ: โจทย์ยาก (คำนวณเงินเดือน)")
print_box("โจทย์", HARD_PROBLEM, "❓")
sc_hard_result = run_self_consistency(SC_PROMPT_V1, HARD_PROBLEM, n_samples=5)
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 ทดสอบ: โจทย์ยาก (คำนวณเงินเดือน)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ ❓ โจทย์                                                                   │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ บริษัทมีพนักงาน 3 แผนก:                                                    │
#   │ - แผนก A: 15 คน เงินเดือนเฉลี่ย 35,000 บาท                                 │
#   │ - แผนก B: 20 คน เงินเดือนเฉลี่ย 42,000 บาท                                 │
#   │ - แผนก C: 10 คน เงินเดือนเฉลี่ย 58,000 บาท                                 │
#   │                                                                            │
#   │ บริษัทจะขึ้นเงินเดือนทุกคน 8%                                              │
#   │ ค่าใช้จ่ายเงินเดือนรวมต่อเดือนหลังขึ้นเงินเดือนเป็นเท่าไหร่?               │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ── รัน 5 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🧠 Path 1/5  →  คำตอบ: 2100600                                             │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ **วิธีคิด:**                                                               │
#   │                                                                            │
#   │ 1. **คำนวณเงินเดือนรวมของแต่ละแผนกก่อนขึ้นเงินเดือน:**                     │
#   │    * แผนก A: 15 คน * 35,000 บาท/คน = 525,000 บาท                           │
#   │    * แผนก B: 20 คน * 42,000 บาท/คน = 840,000 บาท                           │
#   │    * แผนก C: 10 คน * 58,000 บาท/คน = 580,000 บาท                           │
#   │                                                                            │
#   │ 2. **คำนวณเงินเดือนรวมของบริษัททั้งหมดก่อนขึ้นเงินเดือน:**                 │
#   │    * เงินเดือนรวม: 525,000 บาท + 840,000 บาท + 580,000 บาท = 1,945,000 บาท │
#   │                                                                            │
#   │ 3. **คำนวณจำนวนเงินที่เพิ่มขึ้นจากเงินเดือนทั้งหมด:**                      │
#   │    * เงินเดือนที่เพิ่มขึ้น: 1,945,000 บาท * 8% = 155,600 บาท               │
#   │                                                                            │
#   │ 4. **คำนวณเงินเดือนรวมของบริษัททั้งหมดหลังขึ้นเงินเดือน:**                 │
#   │    * เงินเดือนรวมหลังขึ้นเงินเดือน: 1,945,000 บาท + 155,600 บาท =          │
#   │ 2,100,600 บาท                                                              │
#   │                                                                            │
#   │ **คำตอบ:**                                                                 │
#   │                                                                            │
#   │ ค่าใช้จ่ายเงินเดือนรวมต่อเดือนหลังขึ้นเงินเดือนเป็น **2,100,600 บาท**      │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🧠 Path 2/5  →  คำตอบ: 2100600                                             │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ **วิธีคิดทีละขั้นตอน:**                                                    │
#   │                                                                            │
#   │ 1. **คำนวณเงินเดือนรวมก่อนขึ้นเงินเดือนของแต่ละแผนก:**                     │
#   │    * แผนก A: 15 คน * 35,000 บาท/คน = 525,000 บาท                           │
#   │    * แผนก B: 20 คน * 42,000 บาท/คน = 840,000 บาท                           │
#   │    * แผนก C: 10 คน * 58,000 บาท/คน = 580,000 บาท                           │
#   │                                                                            │
#   │ 2. **คำนวณเงินเดือนรวมทั้งหมดก่อนขึ้นเงินเดือน:**                          │
#   │    * เงินเดือนรวม = 525,000 บาท + 840,000 บาท + 580,000 บาท = 1,945,000    │
#   │ บาท                                                                        │
#   │                                                                            │
#   │ 3. **คำนวณจำนวนเงินที่ขึ้นเงินเดือนทั้งหมด:**                              │
#   │    * จำนวนเงินที่ขึ้น = 1,945,000 บาท * 8% = 155,600 บาท                   │
#   │                                                                            │
#   │ 4. **คำนวณเงินเดือนรวมทั้งหมดหลังขึ้นเงินเดือน:**                          │
#   │    * เงินเดือนรวมหลังขึ้นเงินเดือน = 1,945,000 บาท + 155,600 บาท =         │
#   │ 2,100,600 บาท                                                              │
#   │                                                                            │
#   │ **สรุปคำตอบ:**                                                             │
#   │                                                                            │
#   │ ค่าใช้จ่ายเงินเดือนรวมต่อเดือนหลังขึ้นเงินเดือนคือ **2,100,600 บาท**       │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🧠 Path 3/5  →  คำตอบ: 2100600                                             │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ แน่นอนครับ                                                                 │
#   │ นี่คือการวิเคราะห์ปัญหาและวิธีคำนวณค่าใช้จ่ายเงินเดือนรวมหลังขึ้นเงินเดือน │
#   │ 8% ทีละขั้นตอน:                                                            │
#   │                                                                            │
#   │ **1. คำนวณเงินเดือนรวมก่อนขึ้นเงินเดือนของแต่ละแผนก:**                     │
#   │                                                                            │
#   │ *   **แผนก A:** 15 คน * 35,000 บาท/คน = 525,000 บาท                        │
#   │ *   **แผนก B:** 20 คน * 42,000 บาท/คน = 840,000 บาท                        │
#   │ *   **แผนก C:** 10 คน * 58,000 บาท/คน = 580,000 บาท                        │
#   │                                                                            │
#   │ **2. คำนวณเงินเดือนรวมทั้งหมดของบริษัทก่อนขึ้นเงินเดือน:**                 │
#   │                                                                            │
#   │ *   525,000 บาท + 840,000 บาท + 580,000 บาท = 1,945,000 บาท                │
#   │                                                                            │
#   │ **3. คำนวณเปอร์เซ็นต์การขึ้นเงินเดือน:**                                   │
#   │                                                                            │
#   │ *   8% = 0.08                                                              │
#   │                                                                            │
#   │ **4. คำนวณจำนวนเงินที่ขึ้นเงินเดือนทั้งหมด:**                              │
#   │                                                                            │
#   │ *   1,945,000 บาท * 0.08 = 155,600 บาท                                     │
#   │                                                                            │
#   │ **5. คำนวณเงินเดือนรวมทั้งหมดของบริษัทหลังขึ้นเงินเดือน:**                 │
#   │                                                                            │
#   │ *   1,945,000 บาท + 155,600 บาท = 2,100,600 บาท                            │
#   │                                                                            │
#   │ **ดังนั้น ค่าใช้จ่ายเงินเดือนรวมต่อเดือนหลังขึ้นเงินเดือน 8% คือ           │
#   │ 2,100,600 บาท**                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🧠 Path 4/5  →  คำตอบ: 2090600                                             │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ **วิธีคิดทีละขั้นตอน:**                                                    │
#   │                                                                            │
#   │ 1. **คำนวณเงินเดือนรวมของแต่ละแผนกก่อนขึ้นเงินเดือน:**                     │
#   │    - แผนก A: 15 คน * 35,000 บาท/คน = 525,000 บาท                           │
#   │    - แผนก B: 20 คน * 42,000 บาท/คน = 840,000 บาท                           │
#   │    - แผนก C: 10 คน * 58,000 บาท/คน = 580,000 บาท                           │
#   │                                                                            │
#   │ 2. **คำนวณเงินเดือนรวมของบริษัทก่อนขึ้นเงินเดือน:**                        │
#   │    - เงินเดือนรวม = 525,000 บาท + 840,000 บาท + 580,000 บาท = 1,945,000    │
#   │ บาท                                                                        │
#   │                                                                            │
#   │ 3. **คำนวณเปอร์เซ็นต์การขึ้นเงินเดือน:**                                   │
#   │    - การขึ้นเงินเดือน 8% หมายถึง เงินเดือนใหม่ = เงินเดือนเก่า * (1 +      │
#   │ 0.08) = เงินเดือนเก่า * 1.08                                               │
#   │                                                                            │
#   │ 4. **คำนวณเงินเดือนรวมของบริษัทหลังขึ้นเงินเดือน:**                        │
#   │    - เงินเดือนรวมใหม่ = 1,945,000 บาท * 1.08 = 2,090,600 บาท               │
#   │                                                                            │
#   │ **สรุปคำตอบ:**                                                             │
#   │                                                                            │
#   │ ค่าใช้จ่ายเงินเดือนรวมต่อเดือนหลังขึ้นเงินเดือน 8% คือ **2,090,600 บาท**   │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🧠 Path 5/5  →  คำตอบ: 2100600                                             │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ **วิธีคิดทีละขั้นตอน:**                                                    │
#   │                                                                            │
#   │ 1. **คำนวณเงินเดือนรวมของแต่ละแผนกก่อนขึ้นเงินเดือน:**                     │
#   │    * แผนก A: 15 คน * 35,000 บาท/คน = 525,000 บาท                           │
#   │    * แผนก B: 20 คน * 42,000 บาท/คน = 840,000 บาท                           │
#   │    * แผนก C: 10 คน * 58,000 บาท/คน = 580,000 บาท                           │
#   │                                                                            │
#   │ 2. **คำนวณเงินเดือนรวมของทั้งบริษัทก่อนขึ้นเงินเดือน:**                    │
#   │    * เงินเดือนรวม = 525,000 บาท + 840,000 บาท + 580,000 บาท = 1,945,000    │
#   │ บาท                                                                        │
#   │                                                                            │
#   │ 3. **คำนวณจำนวนเงินที่ขึ้นเงินเดือนทั้งหมด:**                              │
#   │    * เงินที่ขึ้น = 1,945,000 บาท * 8% = 155,600 บาท                        │
#   │                                                                            │
#   │ 4. **คำนวณเงินเดือนรวมของทั้งบริษัทหลังขึ้นเงินเดือน:**                    │
#   │    * เงินเดือนรวมหลังขึ้น = 1,945,000 บาท + 155,600 บาท = 2,100,600 บาท    │
#   │                                                                            │
#   │ **สรุปคำตอบ:**                                                             │
#   │                                                                            │
#   │ ค่าใช้จ่ายเงินเดือนรวมต่อเดือนหลังขึ้นเงินเดือนเป็น **2,100,600 บาท**      │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │        2100600 :  ████████████████████████░░░░░░  (4/5)  ← Winner ✅        │
#   │        2090600 :  ██████░░░░░░░░░░░░░░░░░░░░░░░░  (1/5)                    │
#   │                                                                            │
#   │   🏆 Final Answer : 2100600                                                 │
#   │   📊 Confidence   : 80%  (4/5 เห็นด้วย)                                     │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ---
# ## 📘 เทคนิคที่ 2: Prompt Chaining
#
# ### หลักการ
#
# แทนที่จะเขียน Prompt ยาวๆ ครั้งเดียว → **แบ่งงานออกเป็นขั้นตอนย่อย**
# โดย output ของแต่ละขั้น จะเป็น input ของขั้นถัดไป
#
# ### ทำไมถึงได้ผล?
#
# - AI ทำงานได้ดีขึ้นเมื่อ focus ทีละอย่าง
# - Debug ง่าย: รู้ว่าขั้นไหนผิด
# - แต่ละขั้นสามารถ optimize แยกกันได้
# - ใช้ output จากขั้นก่อนเป็น context
#
# ### แผนผัง Lab นี้ (วิเคราะห์ Review)
#
# ```
#  Review ──→ [Step 1: Extract]  ──→ JSON ข้อมูลดิบ
#                                         │
#                                         ▼
#             [Step 2: Analyze] ──→ Score + Business Insight
#                                         │
#                                         ▼
#             [Step 3: Report]  ──→ Executive Summary
# ```
#
# ### เหมาะกับงานประเภทไหน?
#
# | ✅ เหมาะ | ❌ ไม่เหมาะ |
# |---------|-----------|
# | งานที่แบ่งขั้นได้ชัด | งานง่ายๆ 1 ขั้น |
# | ต้องการ intermediate results | ต้องการ speed สูง |
# | งาน document processing | ต้นทุน API ต่ำ |

# %%
# ─────────────────────────────────────────────────────────
#  ลงทะเบียน Prompt Chain 3 ขั้นตอน ใน MLflow
# ─────────────────────────────────────────────────────────

print_title("เทคนิคที่ 2: Prompt Chaining")

# ── กำหนด Template แต่ละขั้น ──

CHAIN_PROMPTS = {

    # ขั้นที่ 1: สกัดข้อมูลสำคัญจาก Review
    "chain_extract": {
        "template": """คุณเป็นผู้เชี่ยวชาญด้านการสกัดข้อมูลจาก Review

รีวิว:
{{ review }}

งาน: สกัดข้อมูลสำคัญออกมาให้ครบถ้วน ตอบเป็น JSON เท่านั้น

{
  "positive_points"  : ["จุดดีที่ลูกค้ากล่าวถึง"],
  "negative_points"  : ["จุดด้อยที่ลูกค้ากล่าวถึง"],
  "overall_emotion"  : "positive / negative / mixed",
  "has_sarcasm"      : "yes / no — อธิบายสั้นๆ ว่าเจอตรงไหน",
  "would_recommend"  : "yes / no / neutral"
}""",
        "commit_message": "v1: สกัดข้อมูลพื้นฐานจาก Review",
    },

    # ขั้นที่ 2: วิเคราะห์ Sentiment และ Business Impact
    "chain_analyze": {
        "template": """คุณเป็นนักวิเคราะห์ Sentiment และ Business Intelligence

ข้อมูลที่สกัดจาก Review:
{{ extracted }}

งาน: วิเคราะห์เชิงลึก ตอบเป็น JSON เท่านั้น

{
  "sentiment_score"   : "0-10 (0=แย่มาก, 10=ดีมาก)",
  "urgent_fixes"      : ["สิ่งที่ต้องแก้เร่งด่วน เรียงตามความสำคัญ"],
  "business_opportunities" : ["โอกาสทางธุรกิจที่เห็นได้"],
  "business_risks"    : ["ความเสี่ยงถ้าไม่แก้ไข"]
}""",
        "commit_message": "v1: วิเคราะห์ Sentiment + Business Impact",
    },

    # ขั้นที่ 3: สรุปรายงานสำหรับผู้บริหาร
    "chain_report": {
        "template": """คุณเป็น Business Report Writer ผู้เชี่ยวชาญ

ข้อมูลดิบจาก Review:
{{ extracted }}

ผลการวิเคราะห์:
{{ analysis }}

งาน: เขียน Executive Summary กระชับ ชัดเจน ใช้ตัดสินใจได้ทันที

รูปแบบ:
**HEADLINE:** [สรุปสถานการณ์ใน 1 ประโยค]

**KEY FINDINGS:**
• [ข้อค้นพบสำคัญที่ 1]
• [ข้อค้นพบสำคัญที่ 2]
• [ข้อค้นพบสำคัญที่ 3]

**PRIORITY ACTIONS:**
1. [สิ่งที่ต้องทำทันที]
2. [สิ่งที่ต้องทำภายใน 1 สัปดาห์]
3. [สิ่งที่ต้องทำภายใน 1 เดือน]

**RISK LEVEL:** LOW / MEDIUM / HIGH
**REASON:** [เหตุผล 1-2 ประโยค]""",
        "commit_message": "v1: สร้าง Executive Summary Report",
    },
}

# ── ลงทะเบียนทุก Prompt ใน MLflow ──
registered_chain_prompts = {}

for prompt_name, prompt_info in CHAIN_PROMPTS.items():
    registered = mlflow.genai.register_prompt(
        name=prompt_name,
        template=prompt_info["template"],
        commit_message=prompt_info["commit_message"],
    )
    registered_chain_prompts[prompt_name] = registered
    track_version(prompt_name, registered.version)

    print(f"  ✅ ลงทะเบียน: '{prompt_name}' version {registered.version}")

print_divider()
print(f"  📦 ลงทะเบียน Prompt Chain ทั้งหมด {len(CHAIN_PROMPTS)} ขั้นตอน")
# Out:
# 2026/02/18 04:11:24 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: chain_extract, version 2
# 2026/02/18 04:11:24 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: chain_analyze, version 2
# 2026/02/18 04:11:24 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: chain_report, version 2
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 เทคนิคที่ 2: Prompt Chaining
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   ✅ ลงทะเบียน: 'chain_extract' version 2
#   ✅ ลงทะเบียน: 'chain_analyze' version 2
#   ✅ ลงทะเบียน: 'chain_report' version 2
#   ────────────────────────────────────────────────────────────
#   📦 ลงทะเบียน Prompt Chain ทั้งหมด 3 ขั้นตอน

# %%
# ─────────────────────────────────────────────────────────
#  Chain Runner: รัน 3 ขั้นตอนต่อเนื่องกัน
# ─────────────────────────────────────────────────────────

def run_prompt_chain(review_text: str) -> Dict:
    """
    รัน Prompt Chain 3 ขั้น: Extract → Analyze → Report

    Output ของแต่ละขั้นจะถูกส่งต่อเป็น Input ของขั้นถัดไป

    Parameters:
        review_text : รีวิวที่ต้องการวิเคราะห์

    Returns:
        dict: ผลลัพธ์จากทุกขั้น {
            "chain_extract": "...",
            "chain_analyze": "...",
            "chain_report" : "...",
        }
    """
    step_results = {}

    step_configs = [
        {
            "name"  : "chain_extract",
            "emoji" : "🔍",
            "label" : "สกัดข้อมูล (Extract)",
            "build_prompt": lambda p, _: p.format(review=review_text),
        },
        {
            "name"  : "chain_analyze",
            "emoji" : "📊",
            "label" : "วิเคราะห์ Sentiment (Analyze)",
            "build_prompt": lambda p, r: p.format(extracted=r.get("chain_extract", "")),
        },
        {
            "name"  : "chain_report",
            "emoji" : "📋",
            "label" : "สรุปรายงาน (Report)",
            "build_prompt": lambda p, r: p.format(
                extracted = r.get("chain_extract", ""),
                analysis  = r.get("chain_analyze", ""),
            ),
        },
    ]

    print_title(f"รัน Prompt Chain ({len(step_configs)} ขั้นตอน)", 2)

    for step_num, step in enumerate(step_configs, start=1):
        # โหลด prompt เวอร์ชันล่าสุด
        prompt = load_latest_prompt(step["name"])

        # สร้าง prompt จริงโดยแทนค่า
        filled = step["build_prompt"](prompt, step_results)

        # เรียก AI และจับเวลา
        start_time = time.time()
        result     = call_gemini(filled)
        elapsed    = time.time() - start_time

        step_results[step["name"]] = result

        # แสดงผลแต่ละขั้น
        print_box(
            title   = f"ขั้นที่ {step_num}: {step['label']}  ⏱️ {elapsed:.1f}s",
            content = result,
            emoji   = step["emoji"],
        )

        time.sleep(1.0)

    print(f"\n  ✅ Chain สำเร็จ! ผ่านทั้ง {len(step_configs)} ขั้นตอน")
    return step_results

# %%
# ─────────────────────────────────────────────────────────
#  ทดสอบ Prompt Chain ด้วย Review แบบ Sarcastic (ประชดประชัน)
# ─────────────────────────────────────────────────────────

# Review ที่มีการประชดประชัน ทดสอบว่า Chain สามารถจับได้ไหม
SARCASTIC_REVIEW = """
ว้าว! ประทับใจมากจริงๆ ครับ สั่งไปเมื่อ 3 อาทิตย์ที่แล้ว เพิ่งได้รับวันนี้เอง
ช้าแค่นี้เองนะ ระดับ World Class มากๆ

ตัวสินค้าก็ดีครับ ถ้าไม่นับว่ามันแตกมาครึ่งหนึ่ง ก็ถือว่าโอเคนะ
จ่ายไป 2,500 บาท ได้ของที่ใช้ได้แค่ 3 วัน คุ้มมากๆ

Customer Service ตอบเร็วมากภายใน 5 วันทำการ ประทับใจในความรวดเร็ว

โดยรวมถ้าชอบความตื่นเต้นว่าของจะมาถึงมือหรือเปล่า แนะนำเลยครับ
"""

print_box(
    title   = "Review ทดสอบ (แบบประชดประชัน)",
    content = SARCASTIC_REVIEW,
    emoji   = "💬",
)

chain_results = run_prompt_chain(SARCASTIC_REVIEW)
# Out:
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 💬 Review ทดสอบ (แบบประชดประชัน)                                           │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │                                                                            │
#   │ ว้าว! ประทับใจมากจริงๆ ครับ สั่งไปเมื่อ 3 อาทิตย์ที่แล้ว                   │
#   │ เพิ่งได้รับวันนี้เอง                                                       │
#   │ ช้าแค่นี้เองนะ ระดับ World Class มากๆ                                      │
#   │                                                                            │
#   │ ตัวสินค้าก็ดีครับ ถ้าไม่นับว่ามันแตกมาครึ่งหนึ่ง ก็ถือว่าโอเคนะ            │
#   │ จ่ายไป 2,500 บาท ได้ของที่ใช้ได้แค่ 3 วัน คุ้มมากๆ                         │
#   │                                                                            │
#   │ Customer Service ตอบเร็วมากภายใน 5 วันทำการ ประทับใจในความรวดเร็ว          │
#   │                                                                            │
#   │ โดยรวมถ้าชอบความตื่นเต้นว่าของจะมาถึงมือหรือเปล่า แนะนำเลยครับ             │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ── รัน Prompt Chain (3 ขั้นตอน) ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🔍 ขั้นที่ 1: สกัดข้อมูล (Extract)  ⏱️ 1.8s                                │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ ```json                                                                    │
#   │ {                                                                          │
#   │   "positive_points": [                                                     │
#   │     "สินค้าดี (แต่มีปัญหา)",                                               │
#   │     "Customer Service ตอบเร็ว (ภายใน 5 วันทำการ)"                          │
#   │   ],                                                                       │
#   │   "negative_points": [                                                     │
#   │     "ระยะเวลาจัดส่งนาน (3 อาทิตย์)",                                       │
#   │     "สินค้าแตกเสียหายครึ่งหนึ่ง",                                          │
#   │     "สินค้าใช้งานได้เพียง 3 วัน"                                           │
#   │   ],                                                                       │
#   │   "overall_emotion": "negative",                                           │
#   │   "has_sarcasm": "yes - รีวิวนี้เต็มไปด้วยประชดประชัน เช่น                 │
#   │ 'ช้าแค่นี้เองนะ ระดับ World Class มากๆ' และ 'คุ้มมากๆ'",                   │
#   │   "would_recommend": "no"                                                  │
#   │ }                                                                          │
#   │ ```                                                                        │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 📊 ขั้นที่ 2: วิเคราะห์ Sentiment (Analyze)  ⏱️ 3.3s                       │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ ```json                                                                    │
#   │ {                                                                          │
#   │   "sentiment_score": "2",                                                  │
#   │   "urgent_fixes": [                                                        │
#   │                                                                            │
#   │ "ปรับปรุงกระบวนการจัดส่งเพื่อลดระยะเวลาและป้องกันความเสียหายของสินค้า",    │
#   │                                                                            │
#   │ "ตรวจสอบคุณภาพสินค้าก่อนจัดส่งเพื่อลดปัญหาการแตกหักและสินค้าใช้งานไม่ได้", │
#   │     "ปรับปรุงคุณภาพสินค้าให้มีความทนทานและใช้งานได้นานกว่า 3 วัน",         │
#   │     "ปรับปรุงการสื่อสารกับลูกค้าให้รวดเร็วและมีประสิทธิภาพมากกว่า 5        │
#   │ วันทำการ"                                                                  │
#   │   ],                                                                       │
#   │   "business_opportunities": [                                              │
#   │     "สร้างความร่วมมือกับบริษัทขนส่งที่มีประสิทธิภาพและน่าเชื่อถือ",        │
#   │     "พัฒนาระบบตรวจสอบคุณภาพสินค้าที่เข้มงวดก่อนจัดส่ง",                    │
#   │     "พัฒนาผลิตภัณฑ์ให้มีคุณภาพสูงและทนทานมากขึ้น",                         │
#   │     "สร้างระบบ Customer Service                                            │
#   │ ที่ตอบสนองรวดเร็วและแก้ไขปัญหาให้ลูกค้าได้อย่างมีประสิทธิภาพ",             │
#   │     "สร้างโปรแกรม Loyalty Program                                          │
#   │ เพื่อรักษาลูกค้าปัจจุบันและดึงดูดลูกค้าใหม่"                               │
#   │   ],                                                                       │
#   │   "business_risks": [                                                      │
#   │     "สูญเสียลูกค้าเนื่องจากความไม่พอใจในคุณภาพสินค้าและบริการ",            │
#   │     "เกิดภาพลักษณ์เชิงลบต่อแบรนด์เนื่องจากรีวิวที่ไม่ดี",                  │
#   │     "ต้นทุนเพิ่มขึ้นจากการจัดการกับสินค้าที่เสียหายและการคืนสินค้า",       │
#   │     "สูญเสียความสามารถในการแข่งขันในตลาด",                                 │
#   │     "อาจถูกฟ้องร้องจากลูกค้าหากสินค้าก่อให้เกิดความเสียหาย"                │
#   │   ]                                                                        │
#   │ }                                                                          │
#   │ ```                                                                        │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 📋 ขั้นที่ 3: สรุปรายงาน (Report)  ⏱️ 3.0s                                 │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ **HEADLINE:**                                                              │
#   │ ประสบการณ์ลูกค้าเชิงลบอย่างรุนแรงส่งผลกระทบต่อความน่าเชื่อถือของแบรนด์และอ │
#   │ าจนำไปสู่การสูญเสียลูกค้า                                                  │
#   │                                                                            │
#   │ **KEY FINDINGS:**                                                          │
#   │ • รีวิวเชิงลบเน้นปัญหาด้านคุณภาพสินค้า (แตกหัก, ใช้งานได้สั้น)             │
#   │ และระยะเวลาจัดส่งที่นานเกินไป                                              │
#   │ • Customer Service ตอบสนองช้า (5 วันทำการ)                                 │
#   │ ไม่สามารถชดเชยประสบการณ์ที่ไม่ดีได้                                        │
#   │ • รีวิวมีการประชดประชันสูง บ่งบอกถึงความไม่พอใจอย่างมากและไม่แนะนำสินค้า   │
#   │                                                                            │
#   │ **PRIORITY ACTIONS:**                                                      │
#   │ 1. (ทันที)                                                                 │
#   │ ติดต่อลูกค้าที่รีวิวเพื่อแสดงความรับผิดชอบและเสนอแนวทางแก้ไขปัญหาเฉพาะหน้า │
#   │ 2. (ภายใน 1 สัปดาห์) ประชุมทีมที่เกี่ยวข้อง (จัดส่ง, QC, Customer          │
#   │ Service) เพื่อวิเคราะห์สาเหตุของปัญหาและวางแผนแก้ไข                        │
#   │ 3. (ภายใน 1 เดือน) ปรับปรุงกระบวนการจัดส่ง, ตรวจสอบคุณภาพสินค้าก่อนส่ง,    │
#   │ และพัฒนาระบบ Customer Service ให้รวดเร็วและมีประสิทธิภาพ                   │
#   │                                                                            │
#   │ **RISK LEVEL:** HIGH                                                       │
#   │ **REASON:**                                                                │
#   │ รีวิวเชิงลบจำนวนมากและรุนแรงส่งผลเสียต่อภาพลักษณ์แบรนด์อย่างรวดเร็ว        │
#   │ และอาจนำไปสู่การสูญเสียลูกค้าจำนวนมากหากไม่แก้ไขอย่างเร่งด่วน              │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ✅ Chain สำเร็จ! ผ่านทั้ง 3 ขั้นตอน

# %% [markdown]
# ---
# ## 📘 เทคนิคที่ 3: Self-Critique
#
# ### หลักการ
#
# ให้ AI **ตรวจและวิพากษ์คำตอบตัวเอง** แล้วนำผลวิพากษ์มาปรับปรุง
#
# เปรียบเหมือนนักเขียนที่เขียนร่างแรก → แก้ไขเอง → ร่างสุดท้ายดีขึ้น
#
# ### แผนผัง
#
# ```
#  คำถาม ──→ [Generate]  ──→  คำตอบ Draft
#                                    │
#                                    ▼
#             [Critique]  ──→  จุดอ่อน / ข้อผิดพลาด
#                                    │
#                                    ▼
#             [Revise]    ──→  คำตอบ Final (ดีขึ้น)
#                                    │
#                            (ทำซ้ำได้ N รอบ)
# ```
#
# ### ข้อดี vs ข้อเสีย
#
# | ✅ ข้อดี | ⚠️ ข้อเสีย |
# |---------|----------|
# | ลด bias และ logical fallacy | ใช้ token มากกว่า 3x |
# | ได้คำตอบรอบด้านขึ้น | ช้ากว่า |
# | เหมาะกับหัวข้อ controversial | อาจ over-critique |

# %%
# ─────────────────────────────────────────────────────────
#  ลงทะเบียน Self-Critique Prompts ใน MLflow
# ─────────────────────────────────────────────────────────

print_title("เทคนิคที่ 3: Self-Critique")

CRITIQUE_PROMPTS = {

    # ขั้นที่ 1: สร้างคำตอบเบื้องต้น
    "crit_generate": {
        "template": """คุณเป็นผู้เชี่ยวชาญที่ให้คำแนะนำอย่างรอบคอบและสมดุล

คำถาม: {{ task }}

ตอบคำถามนี้อย่างครอบคลุม พิจารณาหลายมุมมอง
พร้อมให้เหตุผลชัดเจนสำหรับทุกข้อ""",
        "commit_message": "v1: Generate initial answer",
    },

    # ขั้นที่ 2: วิพากษ์คำตอบอย่างเข้มข้น
    "crit_critic": {
        "template": """คุณเป็น Devil's Advocate ผู้เชี่ยวชาญ — หน้าที่คือหาจุดอ่อนทุกอย่าง

โจทย์เดิม:
{{ task }}

คำตอบที่ต้องวิพากษ์:
{{ answer }}

ตรวจสอบอย่างเข้มข้นตามหัวข้อเหล่านี้:

□ Logical Fallacies  — มีการใช้ตรรกะที่ผิดพลาดไหม?
□ Unsupported Claims — มีการอ้างสิ่งที่ไม่มีหลักฐานสนับสนุนไหม?
□ Missing Perspectives — ขาดมุมมองสำคัญอะไรไปบ้าง?
□ Bias — มีความลำเอียงไหม? (เช่น เข้าข้างฝ่ายใดฝ่ายหนึ่ง)
□ Feasibility — สิ่งที่แนะนำทำได้จริงในทางปฏิบัติไหม?

⚠️ ข้อกำหนด: ต้องหาปัญหาอย่างน้อย 3 ข้อ ห้ามพูดว่าดีโดยไม่ชี้ข้อผิด

ตอบในรูปแบบ:
ISSUES:
- [ปัญหาที่ 1: อธิบายชัดเจน]
- [ปัญหาที่ 2: อธิบายชัดเจน]
- [ปัญหาที่ 3: อธิบายชัดเจน]

VERDICT: WEAK / ACCEPTABLE / STRONG
SUMMARY: [สรุป 2 ประโยค ว่าทำไมถึงให้ verdict นี้]""",
        "commit_message": "v1: Adversarial critic with structured output",
    },

    # ขั้นที่ 3: ปรับปรุงคำตอบโดยใช้ผลวิพากษ์
    "crit_revise": {
        "template": """คุณเป็นผู้เชี่ยวชาญที่รับผลวิพากษ์มาปรับปรุงคำตอบ

โจทย์เดิม:
{{ task }}

คำตอบเดิม:
{{ answer }}

ผลวิพากษ์จาก Critic:
{{ critique }}

งาน: ปรับปรุงคำตอบโดย:
1. แก้ไขทุกปัญหาที่ถูกชี้ใน ISSUES
2. เพิ่มมุมมองที่ขาดหายไป
3. รักษาจุดแข็งของคำตอบเดิม

ตอบในรูปแบบ:
WHAT_I_FIXED:
- [สิ่งที่แก้ไข 1]
- [สิ่งที่แก้ไข 2]

REVISED_ANSWER:
[คำตอบใหม่ที่ปรับปรุงแล้ว]

CONFIDENCE: LOW / MEDIUM / HIGH
REASON: [เหตุผล 1 ประโยค]""",
        "commit_message": "v1: Structured revision based on critique",
    },
}

# ── ลงทะเบียนทุก Prompt ──
for prompt_name, prompt_info in CRITIQUE_PROMPTS.items():
    registered = mlflow.genai.register_prompt(
        name=prompt_name,
        template=prompt_info["template"],
        commit_message=prompt_info["commit_message"],
    )
    track_version(prompt_name, registered.version)
    print(f"  ✅ ลงทะเบียน: '{prompt_name}' version {registered.version}")
# Out:
# 2026/02/18 04:11:35 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: crit_generate, version 2
# 2026/02/18 04:11:35 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: crit_critic, version 2
# 2026/02/18 04:11:35 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: crit_revise, version 2
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 เทคนิคที่ 3: Self-Critique
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   ✅ ลงทะเบียน: 'crit_generate' version 2
#   ✅ ลงทะเบียน: 'crit_critic' version 2
#   ✅ ลงทะเบียน: 'crit_revise' version 2

# %%
# ─────────────────────────────────────────────────────────
#  Self-Critique Runner
# ─────────────────────────────────────────────────────────

def run_self_critique(task: str, n_rounds: int = 1) -> Dict:
    """
    รัน Self-Critique Loop: Generate → Critique → Revise

    Parameters:
        task     : คำถาม / โจทย์ที่ต้องการคำตอบ
        n_rounds : จำนวนรอบที่วิพากษ์และแก้ไข (มากขึ้น = ดีขึ้น แต่ช้าลง)

    Returns:
        dict: {
            "initial_answer" : คำตอบแรกก่อน critique
            "final_answer"   : คำตอบสุดท้ายหลัง revise ทุกรอบ
            "rounds"         : ผลของแต่ละรอบ
        }
    """
    # โหลด prompts ล่าสุด
    generate_prompt = load_latest_prompt("crit_generate")
    critic_prompt   = load_latest_prompt("crit_critic")
    revise_prompt   = load_latest_prompt("crit_revise")

    print_title(f"Self-Critique ({n_rounds} รอบ)", 2)

    # ── ขั้นที่ 1: สร้างคำตอบแรก ──
    print("    📝 กำลังสร้างคำตอบเบื้องต้น...")
    initial_answer = call_gemini(
        generate_prompt.format(task=task),
        temperature=0.2,
    )
    print_box("ขั้นที่ 1: คำตอบเบื้องต้น (Draft)", initial_answer, "📝")
    time.sleep(1.0)

    current_answer = initial_answer
    all_rounds_data = []

    # ── รัน N รอบ Critique + Revise ──
    for round_num in range(1, n_rounds + 1):
        print_title(f"รอบที่ {round_num}/{n_rounds}", 2)

        # Critique: วิพากษ์คำตอบ
        print("    ⚔️  กำลังวิพากษ์คำตอบ...")
        critique = call_gemini(
            critic_prompt.format(task=task, answer=current_answer),
            temperature=0.1,  # temperature ต่ำ = วิพากษ์อย่างสม่ำเสมอ
        )
        print_box(f"ขั้นที่ 2: ผลวิพากษ์ (รอบ {round_num})", critique, "⚔️")
        time.sleep(1.0)

        # Revise: ปรับปรุงคำตอบ
        print("    ✏️  กำลังปรับปรุงคำตอบ...")
        revised = call_gemini(
            revise_prompt.format(task=task, answer=current_answer, critique=critique),
            temperature=0.2,
        )
        print_box(f"ขั้นที่ 3: คำตอบที่ปรับปรุงแล้ว (รอบ {round_num})", revised, "✨")
        time.sleep(1.0)

        # บันทึกผลรอบนี้
        verdict = next(
            (v for v in ["STRONG", "ACCEPTABLE", "WEAK"] if v in critique),
            "UNKNOWN",
        )
        all_rounds_data.append({
            "round"  : round_num,
            "critique": critique,
            "revised" : revised,
            "verdict" : verdict,
        })
        current_answer = revised  # ใช้คำตอบใหม่ในรอบถัดไป

    # สรุปผล
    print_title("สรุป Self-Critique", 2)
    for rd in all_rounds_data:
        verdict_emoji = {"STRONG": "💪", "ACCEPTABLE": "👍", "WEAK": "⚠️"}.get(rd["verdict"], "❓")
        print_metric(f"รอบ {rd['round']} Verdict", rd["verdict"], "", verdict_emoji)

    return {
        "initial_answer": initial_answer,
        "final_answer"  : current_answer,
        "rounds"        : all_rounds_data,
        "task"          : task,
    }

# %%
# ─────────────────────────────────────────────────────────
#  ทดสอบ Self-Critique ด้วยหัวข้อที่ต้องพิจารณาหลายมุม
# ─────────────────────────────────────────────────────────

COMPLEX_TASK = """
บริษัท Startup ด้าน FinTech (45 คน, กระจาย 3 จังหวัด) ควรใช้นโยบาย
Remote Work 100% หรือ มาออฟฟิศทุกวัน?

โปรดพิจารณาจาก 3 มุมมอง: นายจ้าง, ลูกจ้าง, และลูกค้า
"""

print_box("โจทย์ทดสอบ Self-Critique", COMPLEX_TASK, "❓")

critique_result = run_self_critique(COMPLEX_TASK, n_rounds=2)
# Out:
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ ❓ โจทย์ทดสอบ Self-Critique                                                │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │                                                                            │
#   │ บริษัท Startup ด้าน FinTech (45 คน, กระจาย 3 จังหวัด) ควรใช้นโยบาย         │
#   │ Remote Work 100% หรือ มาออฟฟิศทุกวัน?                                      │
#   │                                                                            │
#   │ โปรดพิจารณาจาก 3 มุมมอง: นายจ้าง, ลูกจ้าง, และลูกค้า                       │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ── Self-Critique (2 รอบ) ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#     📝 กำลังสร้างคำตอบเบื้องต้น...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 📝 ขั้นที่ 1: คำตอบเบื้องต้น (Draft)                                       │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ แน่นอนครับ ผมจะพิจารณาประเด็นนี้อย่างรอบคอบและสมดุล                        │
#   │ โดยคำนึงถึงผลกระทบต่อทุกฝ่ายที่เกี่ยวข้อง ทั้งนายจ้าง ลูกจ้าง และลูกค้า    │
#   │ เพื่อให้ได้ข้อสรุปที่เหมาะสมที่สุดสำหรับบริษัท Startup ด้าน FinTech        │
#   │ ที่มีพนักงาน 45 คน กระจายอยู่ใน 3 จังหวัด                                  │
#   │                                                                            │
#   │ **ภาพรวมสถานการณ์:**                                                       │
#   │                                                                            │
#   │ บริษัท Startup ด้าน FinTech ที่มีพนักงาน 45 คน กระจายอยู่ใน 3 จังหวัด      │
#   │ กำลังพิจารณานโยบายการทำงาน 2 รูปแบบหลัก:                                   │
#   │                                                                            │
#   │ 1.  **Remote Work 100%:** พนักงานทุกคนทำงานจากที่ไหนก็ได้ตลอดเวลา          │
#   │ 2.  **มาออฟฟิศทุกวัน:** พนักงานทุกคนต้องเข้ามาทำงานที่สำนักงานเป็นประจำ    │
#   │                                                                            │
#   │ **การพิจารณาจาก 3 มุมมอง:**                                                │
#   │                                                                            │
#   │ **1. มุมมองนายจ้าง (บริษัท):**                                             │
#   │                                                                            │
#   │ *   **Remote Work 100%:**                                                  │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **ลดต้นทุน:** ลดค่าเช่าสำนักงาน ค่าสาธารณูปโภค ค่าเดินทาง      │
#   │ และค่าใช้จ่ายอื่นๆ ที่เกี่ยวข้องกับการมีสำนักงาน                           │
#   │         *   **ขยายขอบเขตการสรรหาบุคลากร:**                                 │
#   │ สามารถจ้างคนเก่งจากทั่วประเทศหรือทั่วโลก                                   │
#   │ โดยไม่จำกัดเฉพาะพื้นที่ใกล้เคียงสำนักงาน                                   │
#   │         *   **เพิ่มความคล่องตัว:** ปรับเปลี่ยนขนาดทีมได้ง่ายขึ้น           │
#   │ และสามารถตอบสนองต่อความต้องการของตลาดได้อย่างรวดเร็ว                       │
#   │         *   **ดึงดูดและรักษาพนักงาน:**                                     │
#   │ พนักงานหลายคนให้ความสำคัญกับความยืดหยุ่นในการทำงาน การมีนโยบาย Remote      │
#   │ Work ที่ดีจะช่วยดึงดูดและรักษาพนักงานที่มีความสามารถไว้ได้                 │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความท้าทายในการสื่อสารและการทำงานร่วมกัน:**                  │
#   │ การสื่อสารอาจไม่ราบรื่นเท่ากับการทำงานในสำนักงาน                           │
#   │ และอาจเกิดความเข้าใจผิดได้ง่าย                                             │
#   │         *   **การควบคุมและติดตามงาน:**                                     │
#   │ การติดตามความคืบหน้าของงานอาจทำได้ยากขึ้น                                  │
#   │ และอาจต้องใช้เครื่องมือและกระบวนการที่ซับซ้อนมากขึ้น                       │
#   │         *   **ความเสี่ยงด้านความปลอดภัยของข้อมูล:**                        │
#   │ การทำงานจากระยะไกลอาจทำให้ข้อมูลของบริษัทมีความเสี่ยงมากขึ้น               │
#   │ หากพนักงานไม่ระมัดระวังในการรักษาความปลอดภัยของอุปกรณ์และเครือข่าย         │
#   │         *   **การสร้างวัฒนธรรมองค์กร:**                                    │
#   │ การสร้างความผูกพันและความรู้สึกเป็นเจ้าของบริษัทอาจทำได้ยากขึ้น            │
#   │ หากพนักงานไม่ได้เจอกันเป็นประจำ                                            │
#   │ *   **มาออฟฟิศทุกวัน:**                                                    │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **การสื่อสารและการทำงานร่วมกันที่มีประสิทธิภาพ:**              │
#   │ การสื่อสารแบบเห็นหน้า (face-to-face) ช่วยให้เข้าใจกันได้ง่ายขึ้น           │
#   │ และการทำงานร่วมกันเป็นทีมมีประสิทธิภาพมากขึ้น                              │
#   │         *   **การควบคุมและติดตามงานที่ง่ายขึ้น:**                          │
#   │ ผู้จัดการสามารถติดตามความคืบหน้าของงานได้อย่างใกล้ชิด                      │
#   │ และสามารถให้คำแนะนำหรือแก้ไขปัญหาได้ทันที                                  │
#   │         *   **การสร้างวัฒนธรรมองค์กรที่แข็งแกร่ง:**                        │
#   │ การที่พนักงานได้เจอกันเป็นประจำ                                            │
#   │ ช่วยสร้างความผูกพันและความรู้สึกเป็นเจ้าของบริษัท                          │
#   │         *   **ความปลอดภัยของข้อมูล:**                                      │
#   │ การทำงานในสำนักงานช่วยลดความเสี่ยงด้านความปลอดภัยของข้อมูล                 │
#   │ เนื่องจากบริษัทสามารถควบคุมการเข้าถึงข้อมูลและอุปกรณ์ได้                   │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ต้นทุนที่สูง:** ต้องเสียค่าเช่าสำนักงาน ค่าสาธารณูปโภค       │
#   │ ค่าเดินทาง และค่าใช้จ่ายอื่นๆ ที่เกี่ยวข้องกับการมีสำนักงาน                │
#   │         *   **ข้อจำกัดในการสรรหาบุคลากร:**                                 │
#   │ ต้องจำกัดการสรรหาบุคลากรเฉพาะพื้นที่ใกล้เคียงสำนักงาน                      │
#   │         *   **ความยืดหยุ่นที่ต่ำ:**                                        │
#   │ พนักงานอาจรู้สึกไม่สะดวกหากต้องเดินทางมาทำงานทุกวัน                        │
#   │ และอาจมีปัญหาในการจัดการเวลาส่วนตัว                                        │
#   │         *   **อาจไม่ดึงดูดพนักงานรุ่นใหม่:**                               │
#   │ พนักงานรุ่นใหม่หลายคนให้ความสำคัญกับความยืดหยุ่นในการทำงาน                 │
#   │ การบังคับให้มาทำงานที่สำนักงานทุกวันอาจทำให้บริษัทไม่น่าสนใจ               │
#   │                                                                            │
#   │ **2. มุมมองลูกจ้าง (พนักงาน):**                                            │
#   │                                                                            │
#   │ *   **Remote Work 100%:**                                                  │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **ความยืดหยุ่นในการทำงาน:** สามารถทำงานจากที่ไหนก็ได้          │
#   │ และสามารถจัดตารางเวลาการทำงานได้ตามความเหมาะสม                             │
#   │         *   **ลดค่าใช้จ่ายในการเดินทาง:** ไม่ต้องเสียค่าเดินทาง ค่าอาหาร   │
#   │ และค่าใช้จ่ายอื่นๆ ที่เกี่ยวข้องกับการเดินทางไปทำงาน                       │
#   │         *   **เพิ่มความสมดุลระหว่างชีวิตการทำงานและชีวิตส่วนตัว:**         │
#   │ สามารถใช้เวลาอยู่กับครอบครัว ทำงานอดิเรก หรือดูแลสุขภาพได้มากขึ้น          │
#   │         *   **สภาพแวดล้อมการทำงานที่สะดวกสบาย:**                           │
#   │ สามารถทำงานในสภาพแวดล้อมที่ตนเองชอบ                                        │
#   │ และสามารถปรับแต่งพื้นที่ทำงานให้เหมาะสมกับความต้องการของตนเอง              │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความรู้สึกเหงาและโดดเดี่ยว:**                                │
#   │ อาจรู้สึกเหงาและโดดเดี่ยวหากไม่ได้เจอกับเพื่อนร่วมงานเป็นประจำ             │
#   │         *   **ความยากลำบากในการตัดขาดจากงาน:** อาจทำงานมากเกินไป           │
#   │ และอาจมีปัญหาในการแบ่งแยกระหว่างชีวิตการทำงานและชีวิตส่วนตัว               │
#   │         *   **ปัญหาด้านการสื่อสาร:**                                       │
#   │ อาจมีปัญหาในการสื่อสารกับเพื่อนร่วมงาน และอาจพลาดข้อมูลสำคัญ               │
#   │         *   **ความกังวลเกี่ยวกับความก้าวหน้าในอาชีพ:**                     │
#   │ อาจกังวลว่าการทำงานจากระยะไกลจะส่งผลเสียต่อความก้าวหน้าในอาชีพ             │
#   │                                                                            │
#   │ *   **มาออฟฟิศทุกวัน:**                                                    │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **การมีปฏิสัมพันธ์กับเพื่อนร่วมงาน:**                          │
#   │ ได้เจอและพูดคุยกับเพื่อนร่วมงานเป็นประจำ ช่วยสร้างความสัมพันธ์ที่ดี        │
#   │ และช่วยให้รู้สึกเป็นส่วนหนึ่งของทีม                                        │
#   │         *   **การเข้าถึงทรัพยากรและอุปกรณ์:**                              │
#   │ สามารถเข้าถึงทรัพยากรและอุปกรณ์ของบริษัทได้อย่างง่ายดาย                    │
#   │         *   **การเรียนรู้และพัฒนาตนเอง:** สามารถเรียนรู้จากเพื่อนร่วมงาน   │
#   │ และสามารถเข้าร่วมกิจกรรมต่างๆ ที่บริษัทจัดขึ้น                             │
#   │         *   **ความชัดเจนในบทบาทและหน้าที่:**                               │
#   │ มีความชัดเจนในบทบาทและหน้าที่ของตนเอง                                      │
#   │ และได้รับการสนับสนุนจากผู้จัดการอย่างใกล้ชิด                               │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความเครียดจากการเดินทาง:**                                   │
#   │ ต้องเสียเวลาและค่าใช้จ่ายในการเดินทางไปทำงาน                               │
#   │         *   **ความยืดหยุ่นที่ต่ำ:**                                        │
#   │ ไม่สามารถจัดตารางเวลาการทำงานได้ตามความต้องการของตนเอง                     │
#   │         *   **สภาพแวดล้อมการทำงานที่ไม่สะดวกสบาย:**                        │
#   │ อาจต้องทำงานในสภาพแวดล้อมที่ไม่ชอบ และอาจไม่มีพื้นที่ส่วนตัว               │
#   │         *   **ความยากลำบากในการจัดการเวลาส่วนตัว:**                        │
#   │ อาจมีปัญหาในการจัดการเวลาส่วนตัว และอาจไม่มีเวลาอยู่กับครอบครัว            │
#   │                                                                            │
#   │ **3. มุมมองลูกค้า:**                                                       │
#   │                                                                            │
#   │ *   **Remote Work 100%:**                                                  │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **การบริการที่รวดเร็วและมีประสิทธิภาพ:**                       │
#   │ บริษัทสามารถให้บริการลูกค้าได้ตลอด 24 ชั่วโมง                              │
#   │ เนื่องจากพนักงานสามารถทำงานจากที่ไหนก็ได้                                  │
#   │         *   **ราคาที่แข่งขันได้:** บริษัทสามารถลดต้นทุนในการดำเนินงาน      │
#   │ และสามารถเสนอราคาที่แข่งขันได้ให้กับลูกค้า                                 │
#   │         *   **นวัตกรรมที่ต่อเนื่อง:**                                      │
#   │ บริษัทสามารถดึงดูดและรักษาพนักงานที่มีความสามารถ                           │
#   │ และสามารถพัฒนานวัตกรรมใหม่ๆ เพื่อตอบสนองความต้องการของลูกค้า               │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความกังวลเกี่ยวกับความปลอดภัยของข้อมูล:**                    │
#   │ ลูกค้าอาจกังวลเกี่ยวกับความปลอดภัยของข้อมูล                                │
#   │ หากบริษัทไม่มีมาตรการรักษาความปลอดภัยที่เข้มงวด                            │
#   │         *   **ความยากลำบากในการติดต่อ:**                                   │
#   │ ลูกค้าอาจมีปัญหาในการติดต่อกับบริษัท                                       │
#   │ หากไม่มีช่องทางการสื่อสารที่ชัดเจนและมีประสิทธิภาพ                         │
#   │         *   **ความรู้สึกไม่เป็นส่วนตัว:**                                  │
#   │ ลูกค้าอาจรู้สึกว่าได้รับการบริการที่ไม่เป็นส่วนตัว                         │
#   │ หากไม่ได้ติดต่อกับพนักงานโดยตรง                                            │
#   │                                                                            │
#   │ *   **มาออฟฟิศทุกวัน:**                                                    │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **ความน่าเชื่อถือและความไว้วางใจ:**                            │
#   │ ลูกค้าอาจรู้สึกว่าบริษัทมีความน่าเชื่อถือและไว้วางใจได้                    │
#   │ หากมีสำนักงานที่ชัดเจนและพนักงานที่พร้อมให้บริการ                          │
#   │         *   **การบริการที่เป็นส่วนตัว:**                                   │
#   │ ลูกค้าสามารถติดต่อกับพนักงานโดยตรง และได้รับการบริการที่เป็นส่วนตัว        │
#   │         *   **ความสะดวกในการติดต่อ:** ลูกค้าสามารถติดต่อกับบริษัทได้ง่าย   │
#   │ หากมีช่องทางการสื่อสารที่หลากหลาย                                          │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **การบริการที่อาจไม่รวดเร็ว:**                                 │
#   │ บริษัทอาจไม่สามารถให้บริการลูกค้าได้ตลอด 24 ชั่วโมง                        │
#   │ หากพนักงานทำงานเฉพาะในเวลาทำการ                                            │
#   │         *   **ราคาที่อาจสูงกว่า:** บริษัทอาจต้องเสนอราคาที่สูงกว่า         │
#   │ เนื่องจากมีต้นทุนในการดำเนินงานที่สูงกว่า                                  │
#   │         *   **นวัตกรรมที่อาจช้ากว่า:** บริษัทอาจพัฒนานวัตกรรมใหม่ๆ         │
#   │ ได้ช้ากว่า เนื่องจากมีข้อจำกัดในการสรรหาบุคลากร                            │
#   │                                                                            │
#   │ **ข้อเสนอแนะ:**                                                            │
#   │                                                                            │
#   │ จากที่ได้พิจารณาในทุกมุมมอง                                                │
#   │ ผมขอเสนอแนะแนวทางที่อาจเหมาะสมที่สุดสำหรับบริษัท Startup ด้าน FinTech      │
#   │ แห่งนี้ คือ **Hybrid Model (รูปแบบผสมผสาน)** โดยมีรายละเอียดดังนี้:        │
#   │                                                                            │
#   │ 1.  **กำหนดบทบาทและหน้าที่ที่เหมาะสม:**                                    │
#   │ พิจารณาว่าบทบาทใดที่จำเป็นต้องทำงานในสำนักงาน (เช่น ทีมขาย                 │
#   │ ทีมบริการลูกค้า) และบทบาทใด                                                │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ── รอบที่ 1/2 ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#     ⚔️  กำลังวิพากษ์คำตอบ...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ ⚔️ ขั้นที่ 2: ผลวิพากษ์ (รอบ 1)                                            │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ ISSUES:                                                                    │
#   │ - **ปัญหาที่ 1: การประเมินผลกระทบต่อลูกค้าไม่สมดุล:**                      │
#   │ การวิเคราะห์มุมมองลูกค้าค่อนข้างผิวเผิน โดยเฉพาะในส่วนของ Remote Work      │
#   │ 100% ที่เน้นแต่ข้อดี เช่น การบริการที่รวดเร็วและราคาที่แข่งขันได้          │
#   │ แต่ไม่ได้เจาะลึกถึงผลกระทบด้านความเชื่อมั่นและความปลอดภัยของข้อมูลอย่างเพี │
#   │ ยงพอ ในธุรกิจ FinTech                                                      │
#   │ ความน่าเชื่อถือและความปลอดภัยเป็นปัจจัยสำคัญที่ลูกค้าให้ความสำคัญเป็นอันดั │
#   │ บต้นๆ                                                                      │
#   │ การที่บริษัทไม่มีสำนักงานที่ชัดเจนอาจทำให้ลูกค้ารู้สึกไม่มั่นใจและส่งผลเสี │
#   │ ยต่อการตัดสินใจใช้บริการได้                                                │
#   │ - **ปัญหาที่ 2: การมองข้ามความแตกต่างของลักษณะงานใน FinTech:**             │
#   │ การวิเคราะห์ไม่ได้จำแนกประเภทของงานในบริษัท FinTech อย่างละเอียด เช่น      │
#   │ งานพัฒนาซอฟต์แวร์ งานวิเคราะห์ข้อมูล งานบริการลูกค้า งานขาย                │
#   │ ซึ่งแต่ละงานอาจมีความเหมาะสมกับรูปแบบการทำงานที่แตกต่างกัน                 │
#   │ การเหมารวมว่าทุกงานสามารถทำ Remote Work 100% ได้ หรือต้องมาออฟฟิศทุกวัน    │
#   │ อาจไม่เหมาะสมและส่งผลเสียต่อประสิทธิภาพการทำงานของบางทีม                   │
#   │ - **ปัญหาที่ 3: ข้อเสนอแนะ Hybrid Model ยังขาดรายละเอียด:**                │
#   │ ข้อเสนอแนะให้ใช้ Hybrid Model เป็นแนวคิดที่ดี                              │
#   │ แต่ยังขาดรายละเอียดที่ชัดเจนว่าจะกำหนดบทบาทและหน้าที่ที่เหมาะสมอย่างไร     │
#   │ จะจัดการเรื่องการสื่อสารและการทำงานร่วมกันระหว่างทีมที่ทำงาน Remote        │
#   │ และทีมที่ทำงานในออฟฟิศอย่างไร                                              │
#   │ จะสร้างความเท่าเทียมและความรู้สึกเป็นเจ้าของบริษัทให้กับพนักงานทุกคนได้อย่ │
#   │ างไร หากไม่มีรายละเอียดที่ชัดเจน การนำ Hybrid Model                        │
#   │ ไปใช้จริงอาจเกิดปัญหาและไม่ประสบความสำเร็จ                                 │
#   │                                                                            │
#   │ VERDICT: WEAK                                                              │
#   │                                                                            │
#   │ SUMMARY:                                                                   │
#   │ การวิเคราะห์มีประโยชน์ในการชี้ให้เห็นข้อดีข้อเสียของแต่ละรูปแบบการทำงาน    │
#   │ แต่ยังขาดความลึกซึ้งในการพิจารณาผลกระทบต่อลูกค้าและความแตกต่างของลักษณะงาน │
#   │ ใน FinTech ทำให้ข้อเสนอแนะ Hybrid Model ยังไม่สามารถนำไปปฏิบัติได้จริง     │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#     ✏️  กำลังปรับปรุงคำตอบ...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ ✨ ขั้นที่ 3: คำตอบที่ปรับปรุงแล้ว (รอบ 1)                                 │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ WHAT_I_FIXED:                                                              │
#   │ - [แก้ไขปัญหาที่ 1: เพิ่มความสมดุลในการประเมินผลกระทบต่อลูกค้า             │
#   │ โดยเน้นย้ำถึงความสำคัญของความน่าเชื่อถือและความปลอดภัยของข้อมูลในธุรกิจ    │
#   │ FinTech และผลกระทบที่อาจเกิดขึ้นจาก Remote Work 100%]                      │
#   │ - [แก้ไขปัญหาที่ 2: เพิ่มการจำแนกประเภทของงานในบริษัท FinTech              │
#   │ และพิจารณาความเหมาะสมของแต่ละงานกับรูปแบบการทำงานที่แตกต่างกัน]            │
#   │ - [แก้ไขปัญหาที่ 3: เพิ่มรายละเอียดเกี่ยวกับ Hybrid Model                  │
#   │ โดยเน้นการกำหนดบทบาทและหน้าที่ที่เหมาะสม                                   │
#   │ การจัดการการสื่อสารและการทำงานร่วมกัน                                      │
#   │ และการสร้างความเท่าเทียมและความรู้สึกเป็นเจ้าของบริษัท]                    │
#   │ - [เพิ่มมุมมองที่ขาดหายไป:                                                 │
#   │ เพิ่มการพิจารณาเรื่องความพร้อมด้านเทคโนโลยีและโครงสร้างพื้นฐานที่จำเป็นสำห │
#   │ รับการรองรับ Remote Work 100% หรือ Hybrid Model]                           │
#   │                                                                            │
#   │ REVISED_ANSWER:                                                            │
#   │ แน่นอนครับ ผมจะพิจารณาประเด็นนี้อย่างรอบคอบและสมดุล                        │
#   │ โดยคำนึงถึงผลกระทบต่อทุกฝ่ายที่เกี่ยวข้อง ทั้งนายจ้าง ลูกจ้าง และลูกค้า    │
#   │ เพื่อให้ได้ข้อสรุปที่เหมาะสมที่สุดสำหรับบริษัท Startup ด้าน FinTech        │
#   │ ที่มีพนักงาน 45 คน กระจายอยู่ใน 3 จังหวัด                                  │
#   │                                                                            │
#   │ **ภาพรวมสถานการณ์:**                                                       │
#   │                                                                            │
#   │ บริษัท Startup ด้าน FinTech ที่มีพนักงาน 45 คน กระจายอยู่ใน 3 จังหวัด      │
#   │ กำลังพิจารณานโยบายการทำงาน 2 รูปแบบหลัก:                                   │
#   │                                                                            │
#   │ 1.  **Remote Work 100%:** พนักงานทุกคนทำงานจากที่ไหนก็ได้ตลอดเวลา          │
#   │ 2.  **มาออฟฟิศทุกวัน:** พนักงานทุกคนต้องเข้ามาทำงานที่สำนักงานเป็นประจำ    │
#   │                                                                            │
#   │ **การพิจารณาจาก 3 มุมมอง:**                                                │
#   │                                                                            │
#   │ **1. มุมมองนายจ้าง (บริษัท):**                                             │
#   │                                                                            │
#   │ *   **Remote Work 100%:**                                                  │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **ลดต้นทุน:** ลดค่าเช่าสำนักงาน ค่าสาธารณูปโภค ค่าเดินทาง      │
#   │ และค่าใช้จ่ายอื่นๆ ที่เกี่ยวข้องกับการมีสำนักงาน                           │
#   │         *   **ขยายขอบเขตการสรรหาบุคลากร:**                                 │
#   │ สามารถจ้างคนเก่งจากทั่วประเทศหรือทั่วโลก                                   │
#   │ โดยไม่จำกัดเฉพาะพื้นที่ใกล้เคียงสำนักงาน                                   │
#   │         *   **เพิ่มความคล่องตัว:** ปรับเปลี่ยนขนาดทีมได้ง่ายขึ้น           │
#   │ และสามารถตอบสนองต่อความต้องการของตลาดได้อย่างรวดเร็ว                       │
#   │         *   **ดึงดูดและรักษาพนักงาน:**                                     │
#   │ พนักงานหลายคนให้ความสำคัญกับความยืดหยุ่นในการทำงาน การมีนโยบาย Remote      │
#   │ Work ที่ดีจะช่วยดึงดูดและรักษาพนักงานที่มีความสามารถไว้ได้                 │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความท้าทายในการสื่อสารและการทำงานร่วมกัน:**                  │
#   │ การสื่อสารอาจไม่ราบรื่นเท่ากับการทำงานในสำนักงาน                           │
#   │ และอาจเกิดความเข้าใจผิดได้ง่าย                                             │
#   │         *   **การควบคุมและติดตามงาน:**                                     │
#   │ การติดตามความคืบหน้าของงานอาจทำได้ยากขึ้น                                  │
#   │ และอาจต้องใช้เครื่องมือและกระบวนการที่ซับซ้อนมากขึ้น                       │
#   │         *   **ความเสี่ยงด้านความปลอดภัยของข้อมูล:**                        │
#   │ การทำงานจากระยะไกลอาจทำให้ข้อมูลของบริษัทมีความเสี่ยงมากขึ้น               │
#   │ หากพนักงานไม่ระมัดระวังในการรักษาความปลอดภัยของอุปกรณ์และเครือข่าย         │
#   │         *   **การสร้างวัฒนธรรมองค์กร:**                                    │
#   │ การสร้างความผูกพันและความรู้สึกเป็นเจ้าของบริษัทอาจทำได้ยากขึ้น            │
#   │ หากพนักงานไม่ได้เจอกันเป็นประจำ                                            │
#   │ *   **มาออฟฟิศทุกวัน:**                                                    │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **การสื่อสารและการทำงานร่วมกันที่มีประสิทธิภาพ:**              │
#   │ การสื่อสารแบบเห็นหน้า (face-to-face) ช่วยให้เข้าใจกันได้ง่ายขึ้น           │
#   │ และการทำงานร่วมกันเป็นทีมมีประสิทธิภาพมากขึ้น                              │
#   │         *   **การควบคุมและติดตามงานที่ง่ายขึ้น:**                          │
#   │ ผู้จัดการสามารถติดตามความคืบหน้าของงานได้อย่างใกล้ชิด                      │
#   │ และสามารถให้คำแนะนำหรือแก้ไขปัญหาได้ทันที                                  │
#   │         *   **การสร้างวัฒนธรรมองค์กรที่แข็งแกร่ง:**                        │
#   │ การที่พนักงานได้เจอกันเป็นประจำ                                            │
#   │ ช่วยสร้างความผูกพันและความรู้สึกเป็นเจ้าของบริษัท                          │
#   │         *   **ความปลอดภัยของข้อมูล:**                                      │
#   │ การทำงานในสำนักงานช่วยลดความเสี่ยงด้านความปลอดภัยของข้อมูล                 │
#   │ เนื่องจากบริษัทสามารถควบคุมการเข้าถึงข้อมูลและอุปกรณ์ได้                   │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ต้นทุนที่สูง:** ต้องเสียค่าเช่าสำนักงาน ค่าสาธารณูปโภค       │
#   │ ค่าเดินทาง และค่าใช้จ่ายอื่นๆ ที่เกี่ยวข้องกับการมีสำนักงาน                │
#   │         *   **ข้อจำกัดในการสรรหาบุคลากร:**                                 │
#   │ ต้องจำกัดการสรรหาบุคลากรเฉพาะพื้นที่ใกล้เคียงสำนักงาน                      │
#   │         *   **ความยืดหยุ่นที่ต่ำ:**                                        │
#   │ พนักงานอาจรู้สึกไม่สะดวกหากต้องเดินทางมาทำงานทุกวัน                        │
#   │ และอาจมีปัญหาในการจัดการเวลาส่วนตัว                                        │
#   │         *   **อาจไม่ดึงดูดพนักงานรุ่นใหม่:**                               │
#   │ พนักงานรุ่นใหม่หลายคนให้ความสำคัญกับความยืดหยุ่นในการทำงาน                 │
#   │ การบังคับให้มาทำงานที่สำนักงานทุกวันอาจทำให้บริษัทไม่น่าสนใจ               │
#   │                                                                            │
#   │ **2. มุมมองลูกจ้าง (พนักงาน):**                                            │
#   │                                                                            │
#   │ *   **Remote Work 100%:**                                                  │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **ความยืดหยุ่นในการทำงาน:** สามารถทำงานจากที่ไหนก็ได้          │
#   │ และสามารถจัดตารางเวลาการทำงานได้ตามความเหมาะสม                             │
#   │         *   **ลดค่าใช้จ่ายในการเดินทาง:** ไม่ต้องเสียค่าเดินทาง ค่าอาหาร   │
#   │ และค่าใช้จ่ายอื่นๆ ที่เกี่ยวข้องกับการเดินทางไปทำงาน                       │
#   │         *   **เพิ่มความสมดุลระหว่างชีวิตการทำงานและชีวิตส่วนตัว:**         │
#   │ สามารถใช้เวลาอยู่กับครอบครัว ทำงานอดิเรก หรือดูแลสุขภาพได้มากขึ้น          │
#   │         *   **สภาพแวดล้อมการทำงานที่สะดวกสบาย:**                           │
#   │ สามารถทำงานในสภาพแวดล้อมที่ตนเองชอบ                                        │
#   │ และสามารถปรับแต่งพื้นที่ทำงานให้เหมาะสมกับความต้องการของตนเอง              │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความรู้สึกเหงาและโดดเดี่ยว:**                                │
#   │ อาจรู้สึกเหงาและโดดเดี่ยวหากไม่ได้เจอกับเพื่อนร่วมงานเป็นประจำ             │
#   │         *   **ความยากลำบากในการตัดขาดจากงาน:** อาจทำงานมากเกินไป           │
#   │ และอาจมีปัญหาในการแบ่งแยกระหว่างชีวิตการทำงานและชีวิตส่วนตัว               │
#   │         *   **ปัญหาด้านการสื่อสาร:**                                       │
#   │ อาจมีปัญหาในการสื่อสารกับเพื่อนร่วมงาน และอาจพลาดข้อมูลสำคัญ               │
#   │         *   **ความกังวลเกี่ยวกับความก้าวหน้าในอาชีพ:**                     │
#   │ อาจกังวลว่าการทำงานจากระยะไกลจะส่งผลเสียต่อความก้าวหน้าในอาชีพ             │
#   │                                                                            │
#   │ *   **มาออฟฟิศทุกวัน:**                                                    │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **การมีปฏิสัมพันธ์กับเพื่อนร่วมงาน:**                          │
#   │ ได้เจอและพูดคุยกับเพื่อนร่วมงานเป็นประจำ ช่วยสร้างความสัมพันธ์ที่ดี        │
#   │ และช่วยให้รู้สึกเป็นส่วนหนึ่งของทีม                                        │
#   │         *   **การเข้าถึงทรัพยากรและอุปกรณ์:**                              │
#   │ สามารถเข้าถึงทรัพยากรและอุปกรณ์ของบริษัทได้อย่างง่ายดาย                    │
#   │         *   **การเรียนรู้และพัฒนาตนเอง:** สามารถเรียนรู้จากเพื่อนร่วมงาน   │
#   │ และสามารถเข้าร่วมกิจกรรมต่างๆ ที่บริษัทจัดขึ้น                             │
#   │         *   **ความชัดเจนในบทบาทและหน้าที่:**                               │
#   │ มีความชัดเจนในบทบาทและหน้าที่ของตนเอง                                      │
#   │ และได้รับการสนับสนุนจากผู้จัดการอย่างใกล้ชิด                               │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความเครียดจากการเดินทาง:**                                   │
#   │ ต้องเสียเวลาและค่าใช้จ่ายในการเดินทางไปทำงาน                               │
#   │         *   **ความยืดหยุ่นที่ต่ำ:**                                        │
#   │ ไม่สามารถจัดตารางเวลาการทำงานได้ตามความต้องการของตนเอง                     │
#   │         *   **สภาพแวดล้อมการทำงานที่ไม่สะดวกสบาย:**                        │
#   │ อาจต้องทำงานในสภาพแวดล้อมที่ไม่ชอบ และอาจไม่มีพื้นที่ส่วนตัว               │
#   │         *   **ความยากลำบากในการจัดการเวลาส่วนตัว:**                        │
#   │ อาจมีปัญหาในการจัดการเวลาส่วนตัว และอาจไม่มีเวลาอยู่กับครอบครัว            │
#   │                                                                            │
#   │ **3. มุมมองลูกค้า:**                                                       │
#   │                                                                            │
#   │ *   **Remote Work 100%:**                                                  │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **การบริการที่รวดเร็วและมีประสิทธิภาพ:**                       │
#   │ บริษัทสามารถให้บริการลูกค้าได้ตลอด 24 ชั่วโมง                              │
#   │ หากมีการจัดการที่ดีและพนักงานมีความพร้อม                                   │
#   │         *   **ราคาที่แข่งขันได้:** บริษัทสามารถลดต้นทุนในการดำเนินงาน      │
#   │ และสามารถเสนอราคาที่แข่งขันได้ให้กับลูกค้า                                 │
#   │         *   **นวัตกรรมที่ต่อเนื่อง:**                                      │
#   │ บริษัทสามารถดึงดูดและรักษาพนักงานที่มีความสามารถ                           │
#   │ และสามารถพัฒนานวัตกรรมใหม่ๆ เพื่อตอบสนองความต้องการของลูกค้า               │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความกังวลเกี่ยวกับความปลอดภัยของข้อมูล:**                    │
#   │ ลูกค้าอาจกังวลเกี่ยวกับความปลอดภัยของข้อมูล                                │
#   │ หากบริษัทไม่มีมาตรการรักษาความปลอดภัยที่เข้มงวด เช่น การเข้ารหัสข้อมูล     │
#   │ การตรวจสอบสิทธิ์การเข้าถึง และการฝึกอบรมพนักงาน                            │
#   │         *   **ความยากลำบากในการติดต่อและความน่าเชื่อถือ:**                 │
#   │ ลูกค้าอาจมีปัญหาในการติดต่อกับบริษัท                                       │
#   │ หากไม่มีช่องทางการสื่อสารที่ชัดเจนและมีประสิทธิภาพ                         │
#   │ และอาจรู้สึกว่าบริษัทขาดความน่าเชื่อถือเนื่องจากไม่มีสำนักงานที่ชัดเจน     │
#   │ **ในธุรกิจ FinTech ความน่าเชื่อถือเป็นสิ่งสำคัญ                            │
#   │ หากลูกค้าไม่มั่นใจในความปลอดภัยของข้อมูลหรือความพร้อมในการให้บริการ        │
#   │ อาจส่งผลเสียต่อการตัดสินใจใช้บริการ**                                      │
#   │         *   **ความรู้สึกไม่เป็นส่วนตัว:**                                  │
#   │ ลูกค้าอาจรู้สึกว่าได้รับการบริการที่ไม่เป็นส่วนตัว                         │
#   │ หากไม่ได้ติดต่อกับพนักงานโดยตรง                                            │
#   │                                                                            │
#   │ *   **มาออฟฟิศทุกวัน:**                                                    │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **ความน่าเชื่อถือและความไว้วางใจ                               │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ── รอบที่ 2/2 ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#     ⚔️  กำลังวิพากษ์คำตอบ...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ ⚔️ ขั้นที่ 2: ผลวิพากษ์ (รอบ 2)                                            │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ ISSUES:                                                                    │
#   │ - [ปัญหาที่ 1: การประเมินผลกระทบต่อลูกค้าในส่วนของ Remote Work 100%        │
#   │ ยังไม่สมบูรณ์                                                              │
#   │ แม้จะกล่าวถึงความกังวลเรื่องความปลอดภัยของข้อมูลและความน่าเชื่อถือ         │
#   │ แต่ยังขาดการเจาะจงถึงประเภทของบริการ FinTech ที่บริษัท Startup นำเสนอ      │
#   │ หากบริการนั้นเกี่ยวข้องกับการจัดการเงินทุนจำนวนมาก                         │
#   │ หรือข้อมูลส่วนบุคคลที่ละเอียดอ่อน ความกังวลของลูกค้าจะยิ่งสูงขึ้น          │
#   │ และอาจส่งผลให้ Remote Work 100% ไม่เหมาะสมอย่างยิ่ง                        │
#   │ การประเมินควรพิจารณาถึงความเสี่ยงที่อาจเกิดขึ้นจากการรั่วไหลของข้อมูล      │
#   │ หรือการโจมตีทางไซเบอร์                                                     │
#   │ ที่อาจส่งผลกระทบต่อความเชื่อมั่นของลูกค้าและชื่อเสียงของบริษัท]            │
#   │ - [ปัญหาที่ 2: การพิจารณาประเภทของงานในบริษัท FinTech ยังไม่ละเอียดพอ      │
#   │ การแบ่งประเภทงานเป็นเพียงภาพรวมกว้างๆ เช่น งานที่ต้องติดต่อลูกค้าโดยตรง    │
#   │ และงานที่ไม่ต้องติดต่อลูกค้าโดยตรง                                         │
#   │ ไม่เพียงพอต่อการตัดสินใจว่างานใดเหมาะสมกับ Remote Work                     │
#   │ หรือการทำงานที่ออฟฟิศ                                                      │
#   │ ควรพิจารณาถึงลักษณะงานที่ต้องการความร่วมมืออย่างใกล้ชิด (เช่น              │
#   │ การพัฒนาซอฟต์แวร์ การวิเคราะห์ข้อมูล) งานที่ต้องการความปลอดภัยสูง (เช่น    │
#   │ การจัดการฐานข้อมูล การตรวจสอบธุรกรรม)                                      │
#   │ และงานที่ต้องการความรวดเร็วในการตอบสนองต่อปัญหา (เช่น การบริการลูกค้า      │
#   │ การแก้ไขข้อผิดพลาด)                                                        │
#   │ การวิเคราะห์ที่ละเอียดกว่านี้จะช่วยให้บริษัทสามารถจัดสรรงานให้เหมาะสมกับรู │
#   │ ปแบบการทำงานที่แตกต่างกัน และลดผลกระทบด้านลบที่อาจเกิดขึ้น]                │
#   │ - [ปัญหาที่ 3:                                                             │
#   │ การพิจารณาเรื่องความพร้อมด้านเทคโนโลยีและโครงสร้างพื้นฐานยังไม่ครอบคลุม    │
#   │ แม้จะกล่าวถึงความจำเป็นในการมีเครื่องมือและกระบวนการที่ซับซ้อนมากขึ้นสำหรั │
#   │ บการควบคุมและติดตามงาน                                                     │
#   │ แต่ยังขาดการพิจารณาถึงความพร้อมของพนักงานแต่ละคนในการเข้าถึงอินเทอร์เน็ตคว │
#   │ ามเร็วสูง อุปกรณ์ที่ทันสมัย และสภาพแวดล้อมการทำงานที่เหมาะสม               │
#   │ หากพนักงานบางคนไม่สามารถเข้าถึงทรัพยากรเหล่านี้ได้                         │
#   │ จะส่งผลให้เกิดความไม่เท่าเทียมกันในการทำงาน                                │
#   │ และอาจส่งผลเสียต่อประสิทธิภาพการทำงานโดยรวมของบริษัท นอกจากนี้             │
#   │ ยังควรพิจารณาถึงความพร้อมของระบบรักษาความปลอดภัยทางไซเบอร์ของบริษัทในการป้ │
#   │ องกันการโจมตีและการรั่วไหลของข้อมูล หากระบบรักษาความปลอดภัยไม่แข็งแกร่งพอ  │
#   │ Remote Work 100% อาจเป็นความเสี่ยงที่มากเกินไป]                            │
#   │                                                                            │
#   │ VERDICT: WEAK                                                              │
#   │ SUMMARY: แม้จะมีการพิจารณาหลายมุมมอง                                       │
#   │ แต่การวิเคราะห์ยังขาดความละเอียดในรายละเอียดที่สำคัญ                       │
#   │ โดยเฉพาะอย่างยิ่งในเรื่องความเสี่ยงด้านความปลอดภัยของข้อมูล                │
#   │ และความพร้อมด้านเทคโนโลยี ซึ่งเป็นปัจจัยสำคัญสำหรับบริษัท FinTech          │
#   │ การประเมินผลกระทบต่อลูกค้ายังไม่เจาะจงถึงประเภทของบริการที่บริษัทนำเสนอ    │
#   │ ทำให้ข้อสรุปที่ได้อาจไม่เหมาะสมกับสถานการณ์จริง                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#     ✏️  กำลังปรับปรุงคำตอบ...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ ✨ ขั้นที่ 3: คำตอบที่ปรับปรุงแล้ว (รอบ 2)                                 │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ WHAT_I_FIXED:                                                              │
#   │ - [แก้ไขปัญหาที่ 1: เพิ่มการวิเคราะห์ผลกระทบต่อลูกค้าโดยจำแนกประเภทบริการ  │
#   │ FinTech ที่บริษัทนำเสนอ (เช่น การจัดการเงินทุน, การให้สินเชื่อ,            │
#   │ การชำระเงิน)                                                               │
#   │ และประเมินความเสี่ยงด้านความปลอดภัยของข้อมูลและความน่าเชื่อถือที่เกี่ยวข้อ │
#   │ งกับแต่ละบริการอย่างละเอียด]                                               │
#   │ - [แก้ไขปัญหาที่ 2: เพิ่มการจำแนกประเภทงานในบริษัท FinTech ให้ละเอียดขึ้น  │
#   │ โดยพิจารณาลักษณะงานที่ต้องการความร่วมมือ, ความปลอดภัยสูง,                  │
#   │ และความรวดเร็วในการตอบสนองต่อปัญหา                                         │
#   │ เพื่อให้สามารถจัดสรรงานให้เหมาะสมกับรูปแบบการทำงานที่แตกต่างกัน]           │
#   │ - [แก้ไขปัญหาที่ 3:                                                        │
#   │ เพิ่มการพิจารณาความพร้อมด้านเทคโนโลยีและโครงสร้างพื้นฐานของพนักงานแต่ละคน  │
#   │ (อินเทอร์เน็ต, อุปกรณ์, สภาพแวดล้อม)                                       │
#   │ และระบบรักษาความปลอดภัยทางไซเบอร์ของบริษัท                                 │
#   │ เพื่อประเมินความเสี่ยงและความเป็นไปได้ของ Remote Work 100%]                │
#   │ - [เพิ่มมุมมองที่ขาดหายไป:                                                 │
#   │ เพิ่มการพิจารณาด้านกฎหมายและข้อบังคับที่เกี่ยวข้องกับธุรกิจ FinTech        │
#   │ และการทำงานจากระยะไกล เช่น PDPA, GDPR,                                     │
#   │ และข้อกำหนดของหน่วยงานกำกับดูแลทางการเงิน]                                 │
#   │                                                                            │
#   │ REVISED_ANSWER:                                                            │
#   │ แน่นอนครับ ผมจะพิจารณาประเด็นนี้อย่างรอบคอบและสมดุล                        │
#   │ โดยคำนึงถึงผลกระทบต่อทุกฝ่ายที่เกี่ยวข้อง ทั้งนายจ้าง ลูกจ้าง และลูกค้า    │
#   │ รวมถึงข้อกำหนดทางกฎหมาย เพื่อให้ได้ข้อสรุปที่เหมาะสมที่สุดสำหรับบริษัท     │
#   │ Startup ด้าน FinTech ที่มีพนักงาน 45 คน กระจายอยู่ใน 3 จังหวัด             │
#   │                                                                            │
#   │ **ภาพรวมสถานการณ์:**                                                       │
#   │                                                                            │
#   │ บริษัท Startup ด้าน FinTech ที่มีพนักงาน 45 คน กระจายอยู่ใน 3 จังหวัด      │
#   │ กำลังพิจารณานโยบายการทำงาน 2 รูปแบบหลัก:                                   │
#   │                                                                            │
#   │ 1.  **Remote Work 100%:** พนักงานทุกคนทำงานจากที่ไหนก็ได้ตลอดเวลา          │
#   │ 2.  **มาออฟฟิศทุกวัน:** พนักงานทุกคนต้องเข้ามาทำงานที่สำนักงานเป็นประจำ    │
#   │                                                                            │
#   │ **การพิจารณาจาก 4 มุมมอง:**                                                │
#   │                                                                            │
#   │ **1. มุมมองนายจ้าง (บริษัท):**                                             │
#   │                                                                            │
#   │ *   **Remote Work 100%:**                                                  │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **ลดต้นทุน:** ลดค่าเช่าสำนักงาน ค่าสาธารณูปโภค ค่าเดินทาง      │
#   │ และค่าใช้จ่ายอื่นๆ ที่เกี่ยวข้องกับการมีสำนักงาน                           │
#   │         *   **ขยายขอบเขตการสรรหาบุคลากร:**                                 │
#   │ สามารถจ้างคนเก่งจากทั่วประเทศหรือทั่วโลก                                   │
#   │ โดยไม่จำกัดเฉพาะพื้นที่ใกล้เคียงสำนักงาน                                   │
#   │         *   **เพิ่มความคล่องตัว:** ปรับเปลี่ยนขนาดทีมได้ง่ายขึ้น           │
#   │ และสามารถตอบสนองต่อความต้องการของตลาดได้อย่างรวดเร็ว                       │
#   │         *   **ดึงดูดและรักษาพนักงาน:**                                     │
#   │ พนักงานหลายคนให้ความสำคัญกับความยืดหยุ่นในการทำงาน การมีนโยบาย Remote      │
#   │ Work ที่ดีจะช่วยดึงดูดและรักษาพนักงานที่มีความสามารถไว้ได้                 │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความท้าทายในการสื่อสารและการทำงานร่วมกัน:**                  │
#   │ การสื่อสารอาจไม่ราบรื่นเท่ากับการทำงานในสำนักงาน                           │
#   │ และอาจเกิดความเข้าใจผิดได้ง่าย                                             │
#   │         *   **การควบคุมและติดตามงาน:**                                     │
#   │ การติดตามความคืบหน้าของงานอาจทำได้ยากขึ้น                                  │
#   │ และอาจต้องใช้เครื่องมือและกระบวนการที่ซับซ้อนมากขึ้น                       │
#   │         *   **ความเสี่ยงด้านความปลอดภัยของข้อมูล:**                        │
#   │ การทำงานจากระยะไกลอาจทำให้ข้อมูลของบริษัทมีความเสี่ยงมากขึ้น               │
#   │ หากพนักงานไม่ระมัดระวังในการรักษาความปลอดภัยของอุปกรณ์และเครือข่าย         │
#   │         *   **การสร้างวัฒนธรรมองค์กร:**                                    │
#   │ การสร้างความผูกพันและความรู้สึกเป็นเจ้าของบริษัทอาจทำได้ยากขึ้น            │
#   │ หากพนักงานไม่ได้เจอกันเป็นประจำ                                            │
#   │         *   **ความพร้อมด้านเทคโนโลยีและโครงสร้างพื้นฐาน:**                 │
#   │ ต้องลงทุนในเทคโนโลยีและโครงสร้างพื้นฐานที่รองรับการทำงานจากระยะไกล เช่น    │
#   │ ระบบรักษาความปลอดภัยทางไซเบอร์, VPN,                                       │
#   │ และเครื่องมือสื่อสารและการทำงานร่วมกัน                                     │
#   │         *   **ความสอดคล้องกับกฎหมายและข้อบังคับ:**                         │
#   │ ต้องตรวจสอบให้แน่ใจว่านโยบาย Remote Work                                   │
#   │ สอดคล้องกับกฎหมายและข้อบังคับที่เกี่ยวข้อง เช่น PDPA, GDPR,                │
#   │ และข้อกำหนดของหน่วยงานกำกับดูแลทางการเงิน                                  │
#   │ *   **มาออฟฟิศทุกวัน:**                                                    │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **การสื่อสารและการทำงานร่วมกันที่มีประสิทธิภาพ:**              │
#   │ การสื่อสารแบบเห็นหน้า (face-to-face) ช่วยให้เข้าใจกันได้ง่ายขึ้น           │
#   │ และการทำงานร่วมกันเป็นทีมมีประสิทธิภาพมากขึ้น                              │
#   │         *   **การควบคุมและติดตามงานที่ง่ายขึ้น:**                          │
#   │ ผู้จัดการสามารถติดตามความคืบหน้าของงานได้อย่างใกล้ชิด                      │
#   │ และสามารถให้คำแนะนำหรือแก้ไขปัญหาได้ทันที                                  │
#   │         *   **การสร้างวัฒนธรรมองค์กรที่แข็งแกร่ง:**                        │
#   │ การที่พนักงานได้เจอกันเป็นประจำ                                            │
#   │ ช่วยสร้างความผูกพันและความรู้สึกเป็นเจ้าของบริษัท                          │
#   │         *   **ความปลอดภัยของข้อมูล:**                                      │
#   │ การทำงานในสำนักงานช่วยลดความเสี่ยงด้านความปลอดภัยของข้อมูล                 │
#   │ เนื่องจากบริษัทสามารถควบคุมการเข้าถึงข้อมูลและอุปกรณ์ได้                   │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ต้นทุนที่สูง:** ต้องเสียค่าเช่าสำนักงาน ค่าสาธารณูปโภค       │
#   │ ค่าเดินทาง และค่าใช้จ่ายอื่นๆ ที่เกี่ยวข้องกับการมีสำนักงาน                │
#   │         *   **ข้อจำกัดในการสรรหาบุคลากร:**                                 │
#   │ ต้องจำกัดการสรรหาบุคลากรเฉพาะพื้นที่ใกล้เคียงสำนักงาน                      │
#   │         *   **ความยืดหยุ่นที่ต่ำ:**                                        │
#   │ พนักงานอาจรู้สึกไม่สะดวกหากต้องเดินทางมาทำงานทุกวัน                        │
#   │ และอาจมีปัญหาในการจัดการเวลาส่วนตัว                                        │
#   │         *   **อาจไม่ดึงดูดพนักงานรุ่นใหม่:**                               │
#   │ พนักงานรุ่นใหม่หลายคนให้ความสำคัญกับความยืดหยุ่นในการทำงาน                 │
#   │ การบังคับให้มาทำงานที่สำนักงานทุกวันอาจทำให้บริษัทไม่น่าสนใจ               │
#   │                                                                            │
#   │ **2. มุมมองลูกจ้าง (พนักงาน):**                                            │
#   │                                                                            │
#   │ *   **Remote Work 100%:**                                                  │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **ความยืดหยุ่นในการทำงาน:** สามารถทำงานจากที่ไหนก็ได้          │
#   │ และสามารถจัดตารางเวลาการทำงานได้ตามความเหมาะสม                             │
#   │         *   **ลดค่าใช้จ่ายในการเดินทาง:** ไม่ต้องเสียค่าเดินทาง ค่าอาหาร   │
#   │ และค่าใช้จ่ายอื่นๆ ที่เกี่ยวข้องกับการเดินทางไปทำงาน                       │
#   │         *   **เพิ่มความสมดุลระหว่างชีวิตการทำงานและชีวิตส่วนตัว:**         │
#   │ สามารถใช้เวลาอยู่กับครอบครัว ทำงานอดิเรก หรือดูแลสุขภาพได้มากขึ้น          │
#   │         *   **สภาพแวดล้อมการทำงานที่สะดวกสบาย:**                           │
#   │ สามารถทำงานในสภาพแวดล้อมที่ตนเองชอบ                                        │
#   │ และสามารถปรับแต่งพื้นที่ทำงานให้เหมาะสมกับความต้องการของตนเอง              │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความรู้สึกเหงาและโดดเดี่ยว:**                                │
#   │ อาจรู้สึกเหงาและโดดเดี่ยวหากไม่ได้เจอกับเพื่อนร่วมงานเป็นประจำ             │
#   │         *   **ความยากลำบากในการตัดขาดจากงาน:** อาจทำงานมากเกินไป           │
#   │ และอาจมีปัญหาในการแบ่งแยกระหว่างชีวิตการทำงานและชีวิตส่วนตัว               │
#   │         *   **ปัญหาด้านการสื่อสาร:**                                       │
#   │ อาจมีปัญหาในการสื่อสารกับเพื่อนร่วมงาน และอาจพลาดข้อมูลสำคัญ               │
#   │         *   **ความกังวลเกี่ยวกับความก้าวหน้าในอาชีพ:**                     │
#   │ อาจกังวลว่าการทำงานจากระยะไกลจะส่งผลเสียต่อความก้าวหน้าในอาชีพ             │
#   │         *   **ความพร้อมด้านเทคโนโลยีและโครงสร้างพื้นฐานส่วนบุคคล:**        │
#   │ อาจมีปัญหาในการเข้าถึงอินเทอร์เน็ตความเร็วสูง อุปกรณ์ที่ทันสมัย            │
#   │ และสภาพแวดล้อมการทำงานที่เหมาะสม                                           │
#   │ *   **มาออฟฟิศทุกวัน:**                                                    │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **การมีปฏิสัมพันธ์กับเพื่อนร่วมงาน:**                          │
#   │ ได้เจอและพูดคุยกับเพื่อนร่วมงานเป็นประจำ ช่วยสร้างความสัมพันธ์ที่ดี        │
#   │ และช่วยให้รู้สึกเป็นส่วนหนึ่งของทีม                                        │
#   │         *   **การเข้าถึงทรัพยากรและอุปกรณ์:**                              │
#   │ สามารถเข้าถึงทรัพยากรและอุปกรณ์ของบริษัทได้อย่างง่ายดาย                    │
#   │         *   **การเรียนรู้และพัฒนาตนเอง:** สามารถเรียนรู้จากเพื่อนร่วมงาน   │
#   │ และสามารถเข้าร่วมกิจกรรมต่างๆ ที่บริษัทจัดขึ้น                             │
#   │         *   **ความชัดเจนในบทบาทและหน้าที่:**                               │
#   │ มีความชัดเจนในบทบาทและหน้าที่ของตนเอง                                      │
#   │ และได้รับการสนับสนุนจากผู้จัดการอย่างใกล้ชิด                               │
#   │     *   **ข้อเสีย:**                                                       │
#   │         *   **ความเครียดจากการเดินทาง:**                                   │
#   │ ต้องเสียเวลาและค่าใช้จ่ายในการเดินทางไปทำงาน                               │
#   │         *   **ความยืดหยุ่นที่ต่ำ:**                                        │
#   │ ไม่สามารถจัดตารางเวลาการทำงานได้ตามความต้องการของตนเอง                     │
#   │         *   **สภาพแวดล้อมการทำงานที่ไม่สะดวกสบาย:**                        │
#   │ อาจต้องทำงานในสภาพแวดล้อมที่ไม่ชอบ และอาจไม่มีพื้นที่ส่วนตัว               │
#   │         *   **ความยากลำบากในการจัดการเวลาส่วนตัว:**                        │
#   │ อาจมีปัญหาในการจัดการเวลาส่วนตัว และอาจไม่มีเวลาอยู่กับครอบครัว            │
#   │                                                                            │
#   │ **3. มุมมองลูกค้า:**                                                       │
#   │                                                                            │
#   │ *   **Remote Work 100%:**                                                  │
#   │     *   **ข้อดี:**                                                         │
#   │         *   **การบริการที่รวดเร็วและมีประสิทธิภาพ:**                       │
#   │ บริษัทสามารถให้บริการลูกค้าได้ตลอด 24 ชั่วโมง                              │
#   │ หากมีการจัดการที่ดีและพนักงานมีความพร้อม                                   │
#   │         *   **ราคาที่แข่งขันได้:** บริษัทสามารถลดต้นทุนในการดำเนินงาน      │
#   │ และสามารถเสนอราคาที่แข่งขันได้ให้กับลูกค้า                                 │
#   │         *   **นวัตกรรมที่ต่อเนื่อง:** บริษัทสามารถดึง                      │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ── สรุป Self-Critique ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#     ⚠️ รอบ 1 Verdict: WEAK
#     ⚠️ รอบ 2 Verdict: WEAK

# %% [markdown]
# ---
# ## 🔁 Reflection Loop: ปรับปรุง Prompt อัตโนมัติ
#
# ### หลักการ
#
# **Reflection** คือการให้ AI วิเคราะห์ว่าทำไม Prompt ถึงให้ผลลัพธ์ไม่ดี
# แล้วสร้าง Prompt ใหม่ที่แก้ปัญหานั้น → วนซ้ำจนได้ accuracy ตามเป้า
#
# ### แผนผัง
#
# ```
#  Prompt vN ──→ [ทดสอบกับ Dataset] ──→ Accuracy ≥ Target?
#                                              │
#                                        YES   │   NO
#                                         ↓    │    ↓
#                                        DONE  │  [Reflect]
#                                              │    ↓
#                                              │  วิเคราะห์ข้อที่ผิด
#                                              │    ↓
#                                              │  สร้าง Prompt vN+1
#                                              │    ↓
#                                              └──→ Loop
# ```
#
# ### Dataset ที่ใช้ทดสอบ
#
# | ระดับ | จำนวน | ตัวอย่าง |
# |-------|-------|---------|
# | easy  | 2 ข้อ | หาร, คูณ ธรรมดา |
# | medium| 2 ข้อ | หลายขั้นตอน, ส่วนลด |
# | hard  | 2 ข้อ | ทำงานร่วม, ที่นั่ง |

# %%
# ─────────────────────────────────────────────────────────
#  Test Dataset: 6 โจทย์ 3 ระดับ
# ─────────────────────────────────────────────────────────

print_title("Reflection Loop: ปรับปรุง Prompt อัตโนมัติ")

TEST_DATASET = [
    # ── ระดับ Easy ──
    {
        "problem"   : "มีส้ม 24 ลูก แบ่งให้เด็ก 6 คนเท่าๆ กัน แต่ละคนได้กี่ลูก?",
        "expected"  : "4",
        "difficulty": "easy",
    },
    {
        "problem"   : "รถยนต์วิ่งด้วยความเร็ว 80 กม./ชม. นาน 3 ชั่วโมง วิ่งได้กี่กิโลเมตร?",
        "expected"  : "240",
        "difficulty": "easy",
    },

    # ── ระดับ Medium ──
    {
        "problem"   : "เสื้อ ราคา 350 บาท ซื้อ 3 ตัว และกางเกง ราคา 450 บาท ซื้อ 2 ตัว "
                      "ถ้าซื้อเกิน 1,500 บาท ได้ส่วนลด 15% จ่ายทั้งหมดเท่าไหร่?",
        "expected"  : "1785",
        "difficulty": "medium",
    },
    {
        "problem"   : "รถ 5 คัน วิ่งรวมกัน 450 กม./วัน อัตราสิ้นเปลือง 12 กม./ลิตร "
                      "น้ำมันราคา 42 บาท/ลิตร ค่าน้ำมันรวมทั้งหมดต่อวันเท่าไหร่?",
        "expected"  : "1575",
        "difficulty": "medium",
    },

    # ── ระดับ Hard ──
    {
        "problem"   : "ทีม A ทำงานได้ 1/30 ของงานต่อวัน ทีม B ทำได้ 1/45 ของงานต่อวัน "
                      "ถ้าทำงานพร้อมกัน ใช้กี่วันถึงเสร็จ? (ปัดขึ้นเป็นจำนวนเต็ม)",
        "expected"  : "18",
        "difficulty": "hard",
    },
    {
        "problem"   : "ร้านอาหารมี: โต๊ะเดี่ยว 8 โต๊ะ (2 คน/โต๊ะ), โต๊ะคู่ 5 โต๊ะ (4 คน/โต๊ะ), "
                      "โต๊ะใหญ่ 3 โต๊ะ (8 คน/โต๊ะ). ตอนนี้มีลูกค้า 35 คน และจะมาเพิ่มอีก "
                      "2 กลุ่ม กลุ่มละ 7 คน เหลือที่นั่งว่างกี่ที่?",
        "expected"  : "5",
        "difficulty": "hard",
    },
]

# แสดง Dataset ในตาราง
print_table(
    headers = ["#", "Difficulty", "Expected", "โจทย์ (ย่อ)"],
    rows    = [
        [
            str(i + 1),
            item["difficulty"],
            item["expected"],
            item["problem"][:45] + "...",
        ]
        for i, item in enumerate(TEST_DATASET)
    ],
    title = "Test Dataset (6 โจทย์)",
)
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 Reflection Loop: ปรับปรุง Prompt อัตโนมัติ
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   📊 Test Dataset (6 โจทย์)
#   ┌─────┬──────────────┬────────────┬─────────────────────────────────────────────────────┐
#   │  #   │  Difficulty   │  Expected   │                    โจทย์ (ย่อ)                     │
#   ├─────┼──────────────┼────────────┼─────────────────────────────────────────────────────┤
#   │  1   │     easy      │     4       │  มีส้ม 24 ลูก แบ่งให้เด็ก 6 คนเท่าๆ กัน แต่ละค...  │
#   │  2   │     easy      │    240      │  รถยนต์วิ่งด้วยความเร็ว 80 กม./ชม. นาน 3 ชั่วโ...  │
#   │  3   │    medium     │    1785     │  เสื้อ ราคา 350 บาท ซื้อ 3 ตัว และกางเกง ราคา ...  │
#   │  4   │    medium     │    1575     │  รถ 5 คัน วิ่งรวมกัน 450 กม./วัน อัตราสิ้นเปลื...  │
#   │  5   │     hard      │     18      │  ทีม A ทำงานได้ 1/30 ของงานต่อวัน ทีม B ทำได้ ...  │
#   │  6   │     hard      │     5       │  ร้านอาหารมี: โต๊ะเดี่ยว 8 โต๊ะ (2 คน/โต๊ะ), โ...  │
#   └─────┴──────────────┴────────────┴─────────────────────────────────────────────────────┘

# %%
# ─────────────────────────────────────────────────────────
#  Evaluate Function: ทดสอบ Prompt กับ Dataset
# ─────────────────────────────────────────────────────────

def evaluate_prompt(template: str,
                    dataset: List[Dict],
                    n_samples: int = 3,
                    label: str = "Prompt") -> Dict:
    """
    ทดสอบ SC Prompt กับ dataset ทั้งหมด และคืนค่า accuracy

    Parameters:
        template  : Prompt template ที่จะทดสอบ
        dataset   : list ของ {problem, expected, difficulty}
        n_samples : จำนวน SC paths ต่อโจทย์
        label     : ชื่อสำหรับแสดงผล

    Returns:
        dict: {
            "accuracy"  : overall accuracy (%)
            "results"   : ผลแต่ละข้อ
            "breakdown" : accuracy แยกตาม difficulty
        }
    """
    correct_count = 0
    all_results   = []

    print_title(f"ประเมิน: {label}", 2)

    for idx, item in enumerate(dataset, start=1):
        # รัน SC (verbose=False เพื่อแสดงผลสั้น)
        sc_result = run_self_consistency(
            template    = template,
            problem     = item["problem"],
            n_samples   = n_samples,
            temperature = 0.7,
            show_details = False,
        )

        # เปรียบเทียบคำตอบ
        predicted = sc_result["final_answer"].replace(",", "").strip()
        expected  = item["expected"].strip()
        is_correct = (predicted == expected)

        if is_correct:
            correct_count += 1

        all_results.append({
            "idx"        : idx,
            "problem"    : item["problem"][:45],
            "expected"   : expected,
            "predicted"  : predicted,
            "confidence" : sc_result["confidence"],
            "difficulty" : item["difficulty"],
            "correct"    : is_correct,
        })

        # แสดงผลแต่ละข้อ
        status = "✅" if is_correct else "❌"
        print(
            f"      {status} Q{idx} [{item['difficulty']:6s}]  "
            f"Expected={expected:>6s}  Got={predicted:>6s}  "
            f"Confidence={sc_result['confidence']:.0%}"
        )

    # ── คำนวณ Accuracy รวม ──
    overall_accuracy = (correct_count / len(dataset)) * 100

    # ── คำนวณ Accuracy แยกตาม Difficulty ──
    breakdown = {}
    for difficulty in ["easy", "medium", "hard"]:
        diff_results = [r for r in all_results if r["difficulty"] == difficulty]
        diff_correct = sum(1 for r in diff_results if r["correct"])
        diff_total   = len(diff_results)
        diff_acc     = (diff_correct / diff_total * 100) if diff_total > 0 else 0
        breakdown[difficulty] = {
            "correct" : diff_correct,
            "total"   : diff_total,
            "accuracy": diff_acc,
        }

    # ── แสดงผลสรุป ──
    print_table(
        headers = ["#", "Difficulty", "Expected", "Got", "Confidence", "Result"],
        rows    = [
            [
                str(r["idx"]),
                r["difficulty"],
                r["expected"],
                r["predicted"],
                f"{r['confidence']:.0%}",
                "✅" if r["correct"] else "❌",
            ]
            for r in all_results
        ],
        title = f"ผลการประเมิน — {label}",
    )

    # Summary box
    difficulty_emoji = {"easy": "🟢", "medium": "🟡", "hard": "🔴"}
    summary_lines = [f"Overall Accuracy: {overall_accuracy:.1f}%  ({correct_count}/{len(dataset)})\n"]
    for diff, info in breakdown.items():
        filled = int(info["accuracy"] / 10)
        bar    = "█" * filled + "░" * (10 - filled)
        summary_lines.append(
            f"{difficulty_emoji[diff]} {diff.capitalize():8s}:  {bar}  "
            f"{info['accuracy']:.0f}%  ({info['correct']}/{info['total']})"
        )

    print_box(
        title   = f"สรุป Accuracy — {label}",
        content = "\n".join(summary_lines),
        emoji   = "🎯",
    )

    return {
        "accuracy" : overall_accuracy,
        "results"  : all_results,
        "breakdown": breakdown,
    }

# %%
# ─────────────────────────────────────────────────────────
#  Reflect Function: วิเคราะห์ข้อผิดพลาด → สร้าง Prompt ใหม่
# ─────────────────────────────────────────────────────────

def reflect_and_improve_prompt(current_template: str,
                               eval_result: Dict) -> str:
    """
    วิเคราะห์ว่า Prompt ผิดพลาดตรงไหน และสร้าง Prompt ที่ดีขึ้น

    Parameters:
        current_template : Prompt เวอร์ชันปัจจุบัน
        eval_result      : ผลการ evaluate (จาก evaluate_prompt)

    Returns:
        str: Prompt template ใหม่ที่ควรดีขึ้น
             (ถ้าสกัดไม่ได้ จะคืน template เดิม)
    """
    wrong_items = [r for r in eval_result["results"] if not r["correct"]]

    if not wrong_items:
        print("  🎉 Accuracy 100% — ไม่จำเป็นต้องปรับปรุง!")
        return current_template

    # สร้าง Reflection Prompt
    wrong_summary = json.dumps(wrong_items[:4], ensure_ascii=False, indent=2)

    reflection_prompt = f"""คุณเป็น Prompt Engineer ผู้เชี่ยวชาญด้าน Math Reasoning

## Prompt ปัจจุบัน:
```
{current_template}
```

## ผลการทดสอบ:
- Overall Accuracy: {eval_result['accuracy']:.1f}%
- ข้อที่ผิด {len(wrong_items)} ข้อ

## รายละเอียดข้อที่ผิด:
{wrong_summary}

## งานของคุณ:
1. วิเคราะห์ pattern ว่าทำไม Prompt ปัจจุบันถึงให้คำตอบผิด
2. ระบุจุดอ่อน 2-3 จุดของ Prompt ปัจจุบัน
3. สร้าง Prompt ใหม่ที่แก้ไขจุดอ่อนเหล่านั้น

## กฎที่ต้องรักษา:
- ต้องมี {{{{ problem }}}} ใน prompt (สำหรับแทน placeholder)
- ให้ AI แสดง reasoning ก่อนสรุปคำตอบ
- กำหนด output format ชัดเจน
- คำตอบสุดท้ายต้องเป็นตัวเลข

## รูปแบบ output:
ขึ้นต้น Prompt ใหม่ด้วย [NEW_PROMPT_START]
จบด้วย [NEW_PROMPT_END]"""

    print_title("กำลัง Reflect...", 3)
    reflection_response = call_gemini(reflection_prompt, temperature=0.3, max_tokens=4096)

    print_box("ผล Reflection Analysis", reflection_response, "🔍")

    # สกัด Prompt ใหม่
    if "[NEW_PROMPT_START]" in reflection_response and "[NEW_PROMPT_END]" in reflection_response:
        start_idx  = reflection_response.index("[NEW_PROMPT_START]") + len("[NEW_PROMPT_START]")
        end_idx    = reflection_response.index("[NEW_PROMPT_END]")
        new_prompt = reflection_response[start_idx:end_idx].strip()

        print_box(
            title   = f"Prompt ใหม่ที่สร้างขึ้น ({len(new_prompt)} ตัวอักษร)",
            content = new_prompt,
            emoji   = "🆕",
        )
        return new_prompt

    print("    ⚠️  ไม่พบ Prompt ใหม่ใน response — ใช้ template เดิม")
    return current_template

# %%
# ─────────────────────────────────────────────────────────
#  Optimization Loop: วนทดสอบและปรับปรุงจนถึง Target
# ─────────────────────────────────────────────────────────

def run_optimization_loop(prompt_name: str,
                           initial_template: str,
                           dataset: List[Dict],
                           target_accuracy: float = 83.0,
                           max_iterations: int = 3,
                           n_samples: int = 3) -> Dict:
    """
    วน Loop: Evaluate → Reflect → Improve → Register → Repeat

    Parameters:
        prompt_name      : ชื่อ Prompt ใน MLflow Registry
        initial_template : Prompt เริ่มต้น
        dataset          : Dataset สำหรับทดสอบ
        target_accuracy  : เป้าหมาย accuracy (%)
        max_iterations   : รอบสูงสุด (ป้องกัน loop ไม่สิ้นสุด)
        n_samples        : SC paths ต่อโจทย์

    Returns:
        dict: สรุปผลทุก iteration
    """
    optimization_history = []
    current_template     = initial_template

    print_title(f"Optimization Loop — เป้าหมาย {target_accuracy}%", 2)
    print_divider("═")

    for iteration in range(1, max_iterations + 1):
        print(f"\n  🔄 Iteration {iteration}/{max_iterations}")
        print_divider()

        # ── ทดสอบ Prompt ปัจจุบัน ──
        eval_result = evaluate_prompt(
            template  = current_template,
            dataset   = dataset,
            n_samples = n_samples,
            label     = f"Iteration {iteration}",
        )

        # บันทึกประวัติ
        optimization_history.append({
            "iteration": iteration,
            "accuracy" : eval_result["accuracy"],
            "breakdown": eval_result["breakdown"],
        })

        # ── ตรวจสอบว่าถึง Target แล้วหรือยัง ──
        if eval_result["accuracy"] >= target_accuracy:
            print(f"\n  🎉 ถึงเป้าหมายแล้ว! {eval_result['accuracy']:.1f}% ≥ {target_accuracy}%")
            break

        print(f"\n  🔍 ยังไม่ถึงเป้า ({eval_result['accuracy']:.1f}% < {target_accuracy}%)")
        print(    "     กำลัง Reflect และสร้าง Prompt ใหม่...")

        # ── Reflect และสร้าง Prompt ใหม่ ──
        new_template = reflect_and_improve_prompt(current_template, eval_result)

        if new_template != current_template:
            # ลงทะเบียน Prompt ใหม่ใน MLflow
            new_registered = mlflow.genai.register_prompt(
                name=prompt_name,
                template=new_template,
                commit_message=(
                    f"Reflection iter {iteration}: "
                    f"accuracy {eval_result['accuracy']:.1f}% → improving"
                ),
            )
            track_version(prompt_name, new_registered.version)
            print(f"  📦 ลงทะเบียน version ใหม่: v{new_registered.version}")
            current_template = new_template
        else:
            print("  ⚠️  Prompt ไม่เปลี่ยนแปลง — หยุด Loop")
            break

        time.sleep(2.0)

    # ── แสดง History ──
    print_title("ประวัติการ Optimize", 2)
    print_table(
        headers = ["Iter", "Accuracy", "Easy", "Medium", "Hard"],
        rows    = [
            [
                str(h["iteration"]),
                f"{h['accuracy']:.1f}%",
                f"{h['breakdown']['easy']['accuracy']:.0f}%",
                f"{h['breakdown']['medium']['accuracy']:.0f}%",
                f"{h['breakdown']['hard']['accuracy']:.0f}%",
            ]
            for h in optimization_history
        ],
        title = "Accuracy แต่ละ Iteration",
    )

    # แสดงการปรับปรุงรวม
    if len(optimization_history) > 1:
        total_improvement = (
            optimization_history[-1]["accuracy"] - optimization_history[0]["accuracy"]
        )
        emoji = "📈" if total_improvement >= 0 else "📉"
        print_metric("การปรับปรุงรวม", total_improvement, "%", emoji)

    return {
        "history"          : optimization_history,
        "final_template"   : current_template,
        "final_accuracy"   : optimization_history[-1]["accuracy"],
        "total_iterations" : len(optimization_history),
    }

# %%
# ─────────────────────────────────────────────────────────
#  รัน Optimization Loop จริง!
# ─────────────────────────────────────────────────────────

print_title("เริ่ม Optimization Loop!")

loop_result = run_optimization_loop(
    prompt_name      = SC_PROMPT_NAME,
    initial_template = SC_PROMPT_V1,
    dataset          = TEST_DATASET,
    target_accuracy  = 83.0,    # เป้าหมาย: ตอบถูก 5/6 ข้อขึ้นไป
    max_iterations   = 3,       # ลองปรับปรุงสูงสุด 3 รอบ
    n_samples        = 3,       # SC 3 paths ต่อโจทย์ (ประหยัด cost)
)
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 เริ่ม Optimization Loop!
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   ── Optimization Loop — เป้าหมาย 83.0% ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ════════════════════════════════════════════════════════════
#
#   🔄 Iteration 1/3
#   ────────────────────────────────────────────────────────────
#
#   ── ประเมิน: Iteration 1 ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=         4  │  **วิธีคิด:**  1. **โจทย์ถามอะไร:** โจทย์ถามว่าเด็กแต่ละคนจะได้ส้ม...
#       ✅ Path 2: ans=         4  │  **วิธีคิด:**  1. **โจทย์ถามอะไร:** โจทย์ถามว่าเด็กแต่ละคนจะได้ส้ม...
#       ✅ Path 3: ans=         4  │  **วิธีคิดทีละขั้นตอน:**  1. **โจทย์ถามอะไร:** โจทย์ถามว่าแต่ละคนจ...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │              4 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 4                                                       │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ✅ Q1 [easy  ]  Expected=     4  Got=     4  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=       240  │  **วิธีคิด:**  1. **เข้าใจสูตร:** ระยะทาง = ความเร็ว x เวลา 2. **ก...
#       ✅ Path 2: ans=       240  │  **วิธีคิด:**  1. **สูตร:** ระยะทาง = ความเร็ว x เวลา 2. **แทนค่า:...
#       ✅ Path 3: ans=       240  │  **วิธีคิด:**  1. **เข้าใจโจทย์:** โจทย์ถามหาระยะทางที่รถยนต์วิ่งไ...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │            240 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 240                                                     │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ✅ Q2 [easy  ]  Expected=   240  Got=   240  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=   1657.50  │  แน่นอนครับ นี่คือวิธีคิดทีละขั้นตอน พร้อมคำตอบ:  **1. ราคารวมของเ...
#       ✅ Path 2: ans=   1657.50  │  แน่นอนครับ มาวิเคราะห์และคำนวณหาคำตอบกันทีละขั้นตอน:  **1. ราคารว...
#       ✅ Path 3: ans=   1657.50  │  **วิธีคิดทีละขั้นตอน:**  1. **ราคารวมของเสื้อ:**    * ราคาเสื้อต่...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │        1657.50 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 1657.50                                                 │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ❌ Q3 [medium]  Expected=  1785  Got=1657.50  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=      1575  │  แน่นอนครับ นี่คือวิธีวิเคราะห์และแก้ปัญหา พร้อมแสดงวิธีคิดทีละขั้...
#       ✅ Path 2: ans=      1575  │  แน่นอนครับ นี่คือการวิเคราะห์ปัญหาและวิธีคำนวณค่าน้ำมันรวมทั้งหมด...
#       ✅ Path 3: ans=      1575  │  แน่นอนครับ นี่คือการวิเคราะห์ปัญหาและวิธีคิดทีละขั้นตอน พร้อมคำตอ...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │           1575 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 1575                                                    │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ✅ Q4 [medium]  Expected=  1575  Got=  1575  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=        18  │  แน่นอนครับ นี่คือวิธีวิเคราะห์และแก้ปัญหา:  **1. หาอัตราการทำงานร...
#       ✅ Path 2: ans=        18  │  แน่นอนครับ นี่คือวิธีวิเคราะห์และแก้ปัญหา:  **ขั้นตอนที่ 1: หาอัต...
#       ✅ Path 3: ans=        18  │  แน่นอนครับ มาดูวิธีวิเคราะห์และแก้ปัญหานี้กันทีละขั้นตอน:  **1. ห...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │             18 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 18                                                      │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ✅ Q5 [hard  ]  Expected=    18  Got=    18  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=        11  │  แน่นอนครับ มาวิเคราะห์และแก้ปัญหานี้ไปพร้อมๆ กัน:  **1. คำนวณจำนว...
#       ✅ Path 2: ans=        11  │  แน่นอนครับ มาวิเคราะห์ปัญหานี้ทีละขั้นตอนกัน:  **1. คำนวณจำนวนที่...
#       ✅ Path 3: ans=        11  │  แน่นอนครับ มาวิเคราะห์และแก้ปัญหานี้กันทีละขั้นตอน:  **1. คำนวณจำ...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │             11 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 11                                                      │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ❌ Q6 [hard  ]  Expected=     5  Got=    11  Confidence=100%
#
#   📊 ผลการประเมิน — Iteration 1
#   ┌─────┬──────────────┬────────────┬───────────┬──────────────┬───────────┐
#   │  #   │  Difficulty   │  Expected   │    Got     │  Confidence   │  Result  │
#   ├─────┼──────────────┼────────────┼───────────┼──────────────┼───────────┤
#   │  1   │     easy      │     4       │     4      │     100%      │    ✅     │
#   │  2   │     easy      │    240      │    240     │     100%      │    ✅     │
#   │  3   │    medium     │    1785     │  1657.50   │     100%      │    ❌     │
#   │  4   │    medium     │    1575     │   1575     │     100%      │    ✅     │
#   │  5   │     hard      │     18      │    18      │     100%      │    ✅     │
#   │  6   │     hard      │     5       │    11      │     100%      │    ❌     │
#   └─────┴──────────────┴────────────┴───────────┴──────────────┴───────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🎯 สรุป Accuracy — Iteration 1                                             │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ Overall Accuracy: 66.7%  (4/6)                                             │
#   │                                                                            │
#   │ 🟢 Easy    :  ██████████  100%  (2/2)                                       │
#   │ 🟡 Medium  :  █████░░░░░  50%  (1/2)                                        │
#   │ 🔴 Hard    :  █████░░░░░  50%  (1/2)                                        │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   🔍 ยังไม่ถึงเป้า (66.7% < 83.0%)
#      กำลัง Reflect และสร้าง Prompt ใหม่...
#
#     ▸ กำลัง Reflect...
# 2026/02/18 04:13:41 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: sc_math_solver, version 5
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🔍 ผล Reflection Analysis                                                  │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ [NEW_PROMPT_START]                                                         │
#   │                                                                            │
#   │ วิเคราะห์และแก้ปัญหาคณิตศาสตร์ต่อไปนี้อย่างละเอียด:                        │
#   │                                                                            │
#   │ {{ problem }}                                                              │
#   │                                                                            │
#   │ **วิธีคิด:**                                                               │
#   │                                                                            │
#   │ 1.  **ทำความเข้าใจปัญหา:** อ่านโจทย์อย่างละเอียด ระบุสิ่งที่โจทย์ถาม       │
#   │ และข้อมูลที่โจทย์ให้มา                                                     │
#   │ 2.  **วางแผนการแก้ปัญหา:** พิจารณาว่าต้องใช้ขั้นตอนอะไรบ้างในการแก้ปัญหา   │
#   │ เลือกใช้สูตรหรือวิธีการที่เหมาะสม                                          │
#   │ 3.  **ดำเนินการแก้ปัญหา:** แสดงวิธีคำนวณทีละขั้นตอนอย่างชัดเจน             │
#   │ อธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอน                                      │
#   │ 4.  **ตรวจสอบความถูกต้อง:** ตรวจสอบความถูกต้องของคำตอบที่ได้               │
#   │ และความสมเหตุสมผลของคำตอบ                                                  │
#   │                                                                            │
#   │ **ขั้นตอนการคำนวณ:**                                                       │
#   │                                                                            │
#   │ (แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด พร้อมอธิบายเหตุผล)                   │
#   │                                                                            │
#   │ **สรุป:**                                                                  │
#   │                                                                            │
#   │ ดังนั้น คำตอบคือ: [คำตอบเป็นตัวเลข]                                        │
#   │                                                                            │
#   │ [NEW_PROMPT_END]                                                           │
#   │                                                                            │
#   │ **การวิเคราะห์และเหตุผลในการปรับปรุง Prompt:**                             │
#   │                                                                            │
#   │ 1. **Pattern ของข้อผิดพลาด:**                                              │
#   │     * **ข้อ 3:** โจทย์ไม่สมบูรณ์ (กางเกงราคาเท่าไหร่?) ทำให้ AI            │
#   │ ไม่สามารถคำนวณได้อย่างถูกต้อง แม้จะพยายามเดา แต่ก็ผิดพลาด                  │
#   │     * **ข้อ 6:** โจทย์ซับซ้อน ต้องมีการคำนวณหลายขั้นตอน                    │
#   │ และอาจต้องตีความข้อมูลที่ให้มาหลายแบบ ทำให้ AI สับสนและคำนวณผิดพลาด        │
#   │                                                                            │
#   │ 2. **จุดอ่อนของ Prompt ปัจจุบัน:**                                         │
#   │     * **ขาดการเน้นย้ำเรื่องการทำความเข้าใจปัญหา:** Prompt                  │
#   │ เดิมไม่ได้เน้นย้ำให้ AI ทำความเข้าใจปัญหาอย่างละเอียดก่อนเริ่มคำนวณ ทำให้  │
#   │ AI อาจพลาดข้อมูลสำคัญ หรือตีความโจทย์ผิดพลาด                               │
#   │     * **ขาดการเน้นย้ำเรื่องการตรวจสอบความถูกต้อง:** Prompt                 │
#   │ เดิมไม่ได้เน้นย้ำให้ AI ตรวจสอบความถูกต้องของคำตอบที่ได้ ทำให้ AI          │
#   │ อาจไม่สังเกตเห็นข้อผิดพลาดในการคำนวณ                                       │
#   │     * **ความละเอียดของวิธีคิด:** Prompt เดิมอาจจะกว้างเกินไป ทำให้ AI      │
#   │ ไม่ได้แสดงวิธีคิดอย่างละเอียดเพียงพอ                                       │
#   │                                                                            │
#   │ 3. **การปรับปรุง Prompt:**                                                 │
#   │     * **เพิ่มขั้นตอน "ทำความเข้าใจปัญหา":** เพื่อให้ AI                    │
#   │ อ่านโจทย์อย่างละเอียด ระบุสิ่งที่โจทย์ถาม และข้อมูลที่โจทย์ให้มา           │
#   │     * **เพิ่มขั้นตอน "ตรวจสอบความถูกต้อง":** เพื่อให้ AI                   │
#   │ ตรวจสอบความถูกต้องของคำตอบที่ได้ และความสมเหตุสมผลของคำตอบ                 │
#   │     * **เพิ่มคำแนะนำให้แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด:** เพื่อให้    │
#   │ AI แสดงวิธีคิดอย่างละเอียด และอธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอน        │
#   │     * **กำหนด Output Format ชัดเจน:**                                      │
#   │ เน้นย้ำว่าคำตอบสุดท้ายต้องเป็นตัวเลข และอยู่ในรูปแบบที่กำหนด               │
#   │     * **ใช้คำที่ชัดเจนและเข้าใจง่าย:**                                     │
#   │ หลีกเลี่ยงการใช้คำศัพท์เฉพาะทางที่อาจทำให้ AI สับสน                        │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🆕 Prompt ใหม่ที่สร้างขึ้น (596 ตัวอักษร)                                  │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ วิเคราะห์และแก้ปัญหาคณิตศาสตร์ต่อไปนี้อย่างละเอียด:                        │
#   │                                                                            │
#   │ {{ problem }}                                                              │
#   │                                                                            │
#   │ **วิธีคิด:**                                                               │
#   │                                                                            │
#   │ 1.  **ทำความเข้าใจปัญหา:** อ่านโจทย์อย่างละเอียด ระบุสิ่งที่โจทย์ถาม       │
#   │ และข้อมูลที่โจทย์ให้มา                                                     │
#   │ 2.  **วางแผนการแก้ปัญหา:** พิจารณาว่าต้องใช้ขั้นตอนอะไรบ้างในการแก้ปัญหา   │
#   │ เลือกใช้สูตรหรือวิธีการที่เหมาะสม                                          │
#   │ 3.  **ดำเนินการแก้ปัญหา:** แสดงวิธีคำนวณทีละขั้นตอนอย่างชัดเจน             │
#   │ อธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอน                                      │
#   │ 4.  **ตรวจสอบความถูกต้อง:** ตรวจสอบความถูกต้องของคำตอบที่ได้               │
#   │ และความสมเหตุสมผลของคำตอบ                                                  │
#   │                                                                            │
#   │ **ขั้นตอนการคำนวณ:**                                                       │
#   │                                                                            │
#   │ (แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด พร้อมอธิบายเหตุผล)                   │
#   │                                                                            │
#   │ **สรุป:**                                                                  │
#   │                                                                            │
#   │ ดังนั้น คำตอบคือ: [คำตอบเป็นตัวเลข]                                        │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#   📦 ลงทะเบียน version ใหม่: v5
#
#   🔄 Iteration 2/3
#   ────────────────────────────────────────────────────────────
#
#   ── ประเมิน: Iteration 2 ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=         4  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: แบ่งส้มให้เด็ก  **1. ทำความเข้...
#       ✅ Path 2: ans=         4  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: แบ่งส้มให้เด็ก  **1. ทำความเข้...
#       ✅ Path 3: ans=         4  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: แบ่งส้มให้เด็ก  **1. ทำความเข้...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │              4 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 4                                                       │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ✅ Q1 [easy  ]  Expected=     4  Got=     4  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=       240  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: รถยนต์วิ่งได้กี่กิโลเมตร  **1....
#       ✅ Path 2: ans=       240  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: รถยนต์วิ่งได้กี่กิโลเมตร  **1....
#       ✅ Path 3: ans=       240  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: รถยนต์วิ่งได้กี่กิโลเมตร  **1....
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │            240 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 240                                                     │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ✅ Q2 [easy  ]  Expected=   240  Got=   240  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=   1657.50  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ซื้อเสื้อผ้าพร้อมส่วนลด  **1. ...
#       ✅ Path 2: ans=   1657.50  │  **1. ทำความเข้าใจปัญหา:**  *   **โจทย์ถาม:** จ่ายเงินทั้งหมดเท่าไ...
#       ✅ Path 3: ans=   1657.50  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ซื้อเสื้อและกางเกง  **1. ทำควา...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │        1657.50 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 1657.50                                                 │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ❌ Q3 [medium]  Expected=  1785  Got=1657.50  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=      1575  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ค่าน้ำมันรถ 5 คัน  **1. ทำความ...
#       ✅ Path 2: ans=      1575  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ค่าน้ำมันรถยนต์  **1. ทำความเข...
#       ✅ Path 3: ans=      1575  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์เรื่องค่าน้ำมันรถ  **1. ทำความเข...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │           1575 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 1575                                                    │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ✅ Q4 [medium]  Expected=  1575  Got=  1575  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=        18  │  **1. ทำความเข้าใจปัญหา:**  *   **สิ่งที่โจทย์ถาม:** หากทีม A และท...
#       ✅ Path 2: ans=        18  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ทีม A และ ทีม B ทำงาน  **1. ทำ...
#       ✅ Path 3: ans=        18  │  **1. ทำความเข้าใจปัญหา:**  *   **โจทย์ถาม:** ถ้าทีม A และทีม B ทำ...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │             18 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 18                                                      │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ✅ Q5 [hard  ]  Expected=    18  Got=    18  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=        11  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ที่นั่งว่างในร้านอาหาร  **1. ท...
#       ✅ Path 2: ans=        11  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ที่นั่งว่างในร้านอาหาร  **1. ท...
#       ✅ Path 3: ans=        11  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ที่นั่งว่างในร้านอาหาร  **1. ท...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │             11 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 11                                                      │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ❌ Q6 [hard  ]  Expected=     5  Got=    11  Confidence=100%
#
#   📊 ผลการประเมิน — Iteration 2
#   ┌─────┬──────────────┬────────────┬───────────┬──────────────┬───────────┐
#   │  #   │  Difficulty   │  Expected   │    Got     │  Confidence   │  Result  │
#   ├─────┼──────────────┼────────────┼───────────┼──────────────┼───────────┤
#   │  1   │     easy      │     4       │     4      │     100%      │    ✅     │
#   │  2   │     easy      │    240      │    240     │     100%      │    ✅     │
#   │  3   │    medium     │    1785     │  1657.50   │     100%      │    ❌     │
#   │  4   │    medium     │    1575     │   1575     │     100%      │    ✅     │
#   │  5   │     hard      │     18      │    18      │     100%      │    ✅     │
#   │  6   │     hard      │     5       │    11      │     100%      │    ❌     │
#   └─────┴──────────────┴────────────┴───────────┴──────────────┴───────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🎯 สรุป Accuracy — Iteration 2                                             │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ Overall Accuracy: 66.7%  (4/6)                                             │
#   │                                                                            │
#   │ 🟢 Easy    :  ██████████  100%  (2/2)                                       │
#   │ 🟡 Medium  :  █████░░░░░  50%  (1/2)                                        │
#   │ 🔴 Hard    :  █████░░░░░  50%  (1/2)                                        │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   🔍 ยังไม่ถึงเป้า (66.7% < 83.0%)
#      กำลัง Reflect และสร้าง Prompt ใหม่...
#
#     ▸ กำลัง Reflect...
# 2026/02/18 04:15:31 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: sc_math_solver, version 6
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🔍 ผล Reflection Analysis                                                  │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ [NEW_PROMPT_START]                                                         │
#   │ วิเคราะห์และแก้ปัญหาคณิตศาสตร์ต่อไปนี้อย่างละเอียด:                        │
#   │                                                                            │
#   │ {{ problem }}                                                              │
#   │                                                                            │
#   │ **วิธีคิด:**                                                               │
#   │                                                                            │
#   │ 1.  **ทำความเข้าใจปัญหา:** อ่านโจทย์อย่างละเอียด ระบุสิ่งที่โจทย์ถาม       │
#   │ และข้อมูลที่โจทย์ให้มา หากมีข้อมูลใดขาดหายไป หรือไม่สมเหตุสมผล             │
#   │ ให้ระบุออกมา                                                               │
#   │ 2.  **วางแผนการแก้ปัญหา:** พิจารณาว่าต้องใช้ขั้นตอนอะไรบ้างในการแก้ปัญหา   │
#   │ เลือกใช้สูตรหรือวิธีการที่เหมาะสม ระบุสูตรหรือหลักการที่ใช้                │
#   │ 3.  **ดำเนินการแก้ปัญหา:** แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด            │
#   │ พร้อมอธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอน เน้นการคำนวณที่ถูกต้องแม่นยำ    │
#   │ และตรวจสอบความสมเหตุสมผลของตัวเลขในแต่ละขั้นตอน                            │
#   │ 4.  **ตรวจสอบความถูกต้อง:** ตรวจสอบความถูกต้องของคำตอบที่ได้               │
#   │ โดยการทวนซ้ำขั้นตอนการคำนวณ                                                │
#   │ และตรวจสอบความสมเหตุสมผลของคำตอบกับสิ่งที่โจทย์ถาม                         │
#   │                                                                            │
#   │ **ขั้นตอนการคำนวณ:**                                                       │
#   │                                                                            │
#   │ (แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด พร้อมอธิบายเหตุผล)                   │
#   │                                                                            │
#   │ **สรุป:**                                                                  │
#   │                                                                            │
#   │ ดังนั้น คำตอบคือ: [คำตอบเป็นตัวเลข]                                        │
#   │                                                                            │
#   │ **หมายเหตุ:** หากโจทย์มีข้อมูลไม่เพียงพอ หรือไม่สมเหตุสมผล                 │
#   │ ให้ระบุเหตุผลที่ไม่สามารถหาคำตอบได้                                        │
#   │ [NEW_PROMPT_END]                                                           │
#   │                                                                            │
#   │ **การวิเคราะห์และปรับปรุง Prompt:**                                        │
#   │                                                                            │
#   │ 1.  **วิเคราะห์ Pattern ข้อผิดพลาด:**                                      │
#   │     *   **ข้อ 3:** โจทย์ไม่สมบูรณ์ (กางเกงราคาเท่าไหร่?) ทำให้ AI          │
#   │ พยายามเดาหรือใช้ข้อมูลที่ไม่ถูกต้องในการคำนวณ                              │
#   │     *   **ข้อ 6:** โจทย์มีความซับซ้อนในการตีความ (จำนวนโต๊ะ,               │
#   │ จำนวนคนต่อโต๊ะ, จำนวนคนทั้งหมด) ทำให้ AI สับสนในการคำนวณ                   │
#   │                                                                            │
#   │ 2.  **จุดอ่อนของ Prompt เดิม:**                                            │
#   │     *   **ขาดการจัดการกับข้อมูลที่ไม่สมบูรณ์:** Prompt                     │
#   │ เดิมไม่ได้ระบุวิธีจัดการกับกรณีที่โจทย์มีข้อมูลไม่เพียงพอ ทำให้ AI         │
#   │ พยายามหาคำตอบโดยใช้ข้อมูลที่ไม่ถูกต้อง                                     │
#   │     *   **ขาดความแม่นยำในการตีความโจทย์:** Prompt                          │
#   │ เดิมไม่ได้เน้นย้ำเรื่องการตีความโจทย์อย่างละเอียด ทำให้ AI                 │
#   │ อาจเข้าใจโจทย์ผิดพลาด                                                      │
#   │     *   **ขาดการเน้นย้ำเรื่องความสมเหตุสมผล:** Prompt                      │
#   │ เดิมไม่ได้เน้นย้ำเรื่องการตรวจสอบความสมเหตุสมผลของตัวเลขในแต่ละขั้นตอน     │
#   │ ทำให้ AI อาจคำนวณผิดพลาดโดยไม่รู้ตัว                                       │
#   │                                                                            │
#   │ 3.  **การปรับปรุง Prompt:**                                                │
#   │     *   **เพิ่มการจัดการกับข้อมูลที่ไม่สมบูรณ์:** เพิ่มคำแนะนำให้ AI       │
#   │ ระบุหากโจทย์มีข้อมูลไม่เพียงพอ หรือไม่สมเหตุสมผล                           │
#   │     *   **เน้นย้ำการตีความโจทย์อย่างละเอียด:** เพิ่มคำแนะนำให้ AI          │
#   │ อ่านโจทย์อย่างละเอียด และระบุสิ่งที่โจทย์ถาม                               │
#   │     *   **เน้นย้ำความสมเหตุสมผล:** เพิ่มคำแนะนำให้ AI                      │
#   │ ตรวจสอบความสมเหตุสมผลของตัวเลขในแต่ละขั้นตอน                               │
#   │     *   **เพิ่มความแม่นยำในการคำนวณ:** เน้นย้ำให้ AI                       │
#   │ แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด                                       │
#   │ และอธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอน                                   │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🆕 Prompt ใหม่ที่สร้างขึ้น (907 ตัวอักษร)                                  │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ วิเคราะห์และแก้ปัญหาคณิตศาสตร์ต่อไปนี้อย่างละเอียด:                        │
#   │                                                                            │
#   │ {{ problem }}                                                              │
#   │                                                                            │
#   │ **วิธีคิด:**                                                               │
#   │                                                                            │
#   │ 1.  **ทำความเข้าใจปัญหา:** อ่านโจทย์อย่างละเอียด ระบุสิ่งที่โจทย์ถาม       │
#   │ และข้อมูลที่โจทย์ให้มา หากมีข้อมูลใดขาดหายไป หรือไม่สมเหตุสมผล             │
#   │ ให้ระบุออกมา                                                               │
#   │ 2.  **วางแผนการแก้ปัญหา:** พิจารณาว่าต้องใช้ขั้นตอนอะไรบ้างในการแก้ปัญหา   │
#   │ เลือกใช้สูตรหรือวิธีการที่เหมาะสม ระบุสูตรหรือหลักการที่ใช้                │
#   │ 3.  **ดำเนินการแก้ปัญหา:** แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด            │
#   │ พร้อมอธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอน เน้นการคำนวณที่ถูกต้องแม่นยำ    │
#   │ และตรวจสอบความสมเหตุสมผลของตัวเลขในแต่ละขั้นตอน                            │
#   │ 4.  **ตรวจสอบความถูกต้อง:** ตรวจสอบความถูกต้องของคำตอบที่ได้               │
#   │ โดยการทวนซ้ำขั้นตอนการคำนวณ                                                │
#   │ และตรวจสอบความสมเหตุสมผลของคำตอบกับสิ่งที่โจทย์ถาม                         │
#   │                                                                            │
#   │ **ขั้นตอนการคำนวณ:**                                                       │
#   │                                                                            │
#   │ (แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด พร้อมอธิบายเหตุผล)                   │
#   │                                                                            │
#   │ **สรุป:**                                                                  │
#   │                                                                            │
#   │ ดังนั้น คำตอบคือ: [คำตอบเป็นตัวเลข]                                        │
#   │                                                                            │
#   │ **หมายเหตุ:** หากโจทย์มีข้อมูลไม่เพียงพอ หรือไม่สมเหตุสมผล                 │
#   │ ให้ระบุเหตุผลที่ไม่สามารถหาคำตอบได้                                        │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#   📦 ลงทะเบียน version ใหม่: v6
#
#   🔄 Iteration 3/3
#   ────────────────────────────────────────────────────────────
#
#   ── ประเมิน: Iteration 3 ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=         4  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: แบ่งส้มให้เด็ก  **1. ทำความเข้...
#       ✅ Path 2: ans=         4  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ส้มแบ่งเด็ก  **1. ทำความเข้าใจ...
#       ✅ Path 3: ans=         4  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: แบ่งส้มให้เด็ก  **1. ทำความเข้...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │              4 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 4                                                       │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ✅ Q1 [easy  ]  Expected=     4  Got=     4  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=       240  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: รถยนต์วิ่งได้กี่กิโลเมตร  **1....
#       ✅ Path 2: ans=       240  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: รถยนต์วิ่งได้กี่กิโลเมตร  **1....
#       ✅ Path 3: ans=       240  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: รถยนต์วิ่งได้กี่กิโลเมตร  **1....
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │            240 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 240                                                     │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ✅ Q2 [easy  ]  Expected=   240  Got=   240  Confidence=100%
#
#   ── รัน 3 Reasoning Paths (temperature=0.7) ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       ✅ Path 1: ans=    1657.5  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: เสื้อและกางเกงลดราคา  **1. ทำค...
#       ✅ Path 2: ans=   1657.50  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: เสื้อและกางเกงพร้อมส่วนลด  **1...
#       ✅ Path 3: ans=   1657.50  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: เสื้อและกางเกงลดราคา  **1. ทำค...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │        1657.50 :  ████████████░░░░░░  (2/3)  ← Winner ✅                    │
#   │         1657.5 :  ██████░░░░░░░░░░░░  (1/3)                                │
#   │                                                                            │
#   │   🏆 Final Answer : 1657.50                                                 │
#   │   📊 Confidence   : 67%  (2/3 เห็นด้วย)                                     │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ❌ Q3 [medium]  Expected=  1785  Got=1657.50  Confidence=67%
#
# ...
#       ✅ Path 1: ans=        11  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ที่นั่งว่างในร้านอาหาร  **1. ท...
#       ✅ Path 2: ans=        11  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ที่นั่งว่างในร้านอาหาร  **1. ท...
#       ✅ Path 3: ans=        11  │  ## วิเคราะห์และแก้ปัญหาคณิตศาสตร์: ที่นั่งว่างในร้านอาหาร  **1. ท...
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🗳️ ผลการโหวต (Majority Vote)                                               │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │             11 :  ██████████████████  (3/3)  ← Winner ✅                    │
#   │                                                                            │
#   │   🏆 Final Answer : 11                                                      │
#   │   📊 Confidence   : 100%  (3/3 เห็นด้วย)                                    │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#       ❌ Q6 [hard  ]  Expected=     5  Got=    11  Confidence=100%
#
#   📊 ผลการประเมิน — Iteration 3
#   ┌─────┬──────────────┬────────────┬───────────┬──────────────┬───────────┐
#   │  #   │  Difficulty   │  Expected   │    Got     │  Confidence   │  Result  │
#   ├─────┼──────────────┼────────────┼───────────┼──────────────┼───────────┤
#   │  1   │     easy      │     4       │     4      │     100%      │    ✅     │
#   │  2   │     easy      │    240      │    240     │     100%      │    ✅     │
#   │  3   │    medium     │    1785     │  1657.50   │     67%       │    ❌     │
#   │  4   │    medium     │    1575     │   1575     │     100%      │    ✅     │
#   │  5   │     hard      │     18      │    18      │     100%      │    ✅     │
#   │  6   │     hard      │     5       │    11      │     100%      │    ❌     │
#   └─────┴──────────────┴────────────┴───────────┴──────────────┴───────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🎯 สรุป Accuracy — Iteration 3                                             │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ Overall Accuracy: 66.7%  (4/6)                                             │
#   │                                                                            │
#   │ 🟢 Easy    :  ██████████  100%  (2/2)                                       │
#   │ 🟡 Medium  :  █████░░░░░  50%  (1/2)                                        │
#   │ 🔴 Hard    :  █████░░░░░  50%  (1/2)                                        │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   🔍 ยังไม่ถึงเป้า (66.7% < 83.0%)
#      กำลัง Reflect และสร้าง Prompt ใหม่...
#
#     ▸ กำลัง Reflect...
# 2026/02/18 04:17:26 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for prompt version to finish creation. Prompt name: sc_math_solver, version 7
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🔍 ผล Reflection Analysis                                                  │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ [NEW_PROMPT_START]                                                         │
#   │                                                                            │
#   │ มาวิเคราะห์และแก้ปัญหาคณิตศาสตร์ต่อไปนี้อย่างละเอียด                       │
#   │ โดยเน้นการให้เหตุผลที่ชัดเจนและแม่นยำ:                                     │
#   │                                                                            │
#   │ {{ problem }}                                                              │
#   │                                                                            │
#   │ **วิธีคิด:**                                                               │
#   │                                                                            │
#   │ 1. **ทำความเข้าใจปัญหา:** อ่านโจทย์อย่างละเอียด ระบุสิ่งที่โจทย์ถาม        │
#   │ และข้อมูลที่โจทย์ให้มา หากมีข้อมูลใดขาดหายไป หรือไม่สมเหตุสมผล             │
#   │ ให้ระบุออกมาอย่างชัดเจน                                                    │
#   │ และพิจารณาว่าข้อมูลที่ให้มาเพียงพอต่อการหาคำตอบหรือไม่                     │
#   │ 2. **วางแผนการแก้ปัญหา:** พิจารณาว่าต้องใช้ขั้นตอนอะไรบ้างในการแก้ปัญหา    │
#   │ เลือกใช้สูตรหรือวิธีการที่เหมาะสม ระบุสูตรหรือหลักการที่ใช้                │
#   │ อธิบายเหตุผลในการเลือกใช้สูตรหรือวิธีการนั้นๆ                              │
#   │ 3. **ดำเนินการแก้ปัญหา:** แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด             │
#   │ พร้อมอธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอน เน้นการคำนวณที่ถูกต้องแม่นยำ    │
#   │ และตรวจสอบความสมเหตุสมผลของตัวเลขในแต่ละขั้นตอน หากมีการประมาณค่า          │
#   │ ให้ระบุเหตุผลในการประมาณค่า และผลกระทบที่อาจเกิดขึ้นกับความแม่นยำของคำตอบ  │
#   │ 4. **ตรวจสอบความถูกต้อง:** ตรวจสอบความถูกต้องของคำตอบที่ได้                │
#   │ โดยการทวนซ้ำขั้นตอนการคำนวณ                                                │
#   │ และตรวจสอบความสมเหตุสมผลของคำตอบกับสิ่งที่โจทย์ถาม                         │
#   │ พิจารณาว่าคำตอบที่ได้อยู่ในช่วงที่ควรจะเป็นหรือไม่                         │
#   │ และมีหน่วยที่ถูกต้องหรือไม่                                                │
#   │                                                                            │
#   │ **ขั้นตอนการคำนวณ:**                                                       │
#   │                                                                            │
#   │ (แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด                                      │
#   │ พร้อมอธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอน โดยเน้นความชัดเจนและแม่นยำ)     │
#   │                                                                            │
#   │ **สรุป:**                                                                  │
#   │                                                                            │
#   │ ดังนั้น คำตอบคือ: [คำตอบเป็นตัวเลข]                                        │
#   │                                                                            │
#   │ **หมายเหตุ:** หากโจทย์มีข้อมูลไม่เพียงพอ หรือไม่สมเหตุสมผล                 │
#   │ ให้ระบุเหตุผลที่ไม่สามารถหาคำตอบได้ พร้อมทั้งอธิบายว่าข้อมูลใดที่ขาดหายไป  │
#   │ หรือไม่สมเหตุสมผล และผลกระทบที่เกิดขึ้น                                    │
#   │                                                                            │
#   │ **ตัวอย่างการให้เหตุผล:**                                                  │
#   │                                                                            │
#   │ *   "เนื่องจากโจทย์ไม่ได้ระบุราคากางเกงที่แน่นอน                           │
#   │ ทำให้ไม่สามารถคำนวณราคารวมทั้งหมดได้"                                      │
#   │ *   "จากข้อมูลที่ให้มา                                                     │
#   │ พบว่าจำนวนโต๊ะไม่สอดคล้องกับจำนวนคนที่สามารถนั่งได้                        │
#   │ ดังนั้นจึงไม่สามารถหาจำนวนโต๊ะที่ต้องการเพิ่มได้อย่างแม่นยำ"               │
#   │                                                                            │
#   │ [NEW_PROMPT_END]                                                           │
#   │                                                                            │
#   │ **การวิเคราะห์และปรับปรุง Prompt:**                                        │
#   │                                                                            │
#   │ 1.  **วิเคราะห์ Pattern ของข้อผิดพลาด:**                                   │
#   │     *   ข้อ 3: โจทย์ไม่สมบูรณ์ (ราคากางเกงหายไป) AI                        │
#   │ พยายามเดา/เติมข้อมูลเอง ทำให้คำตอบผิด                                      │
#   │     *   ข้อ 6: โจทย์ซับซ้อน (หลายเงื่อนไข) AI อาจตีความผิดพลาด             │
#   │ หรือคำนวณผิดพลาดในขั้นตอนใดขั้นตอนหนึ่ง                                    │
#   │                                                                            │
#   │ 2.  **จุดอ่อนของ Prompt เดิม:**                                            │
#   │     *   **การจัดการกับข้อมูลที่ไม่สมบูรณ์:** Prompt เดิมไม่ได้เน้นย้ำให้   │
#   │ AI ระบุอย่างชัดเจนเมื่อข้อมูลไม่เพียงพอ                                    │
#   │ และไม่ได้ให้คำแนะนำในการจัดการกับสถานการณ์เช่นนี้ ทำให้ AI พยายาม "เติม"   │
#   │ ข้อมูลเอง ซึ่งนำไปสู่คำตอบที่ผิด                                           │
#   │     *   **ความชัดเจนในการให้เหตุผล:** Prompt เดิมอาจไม่ได้เน้นย้ำให้ AI    │
#   │ อธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอนอย่างละเอียดเพียงพอ                   │
#   │ ทำให้ยากต่อการตรวจสอบว่า AI เข้าใจปัญหาอย่างถูกต้องหรือไม่                 │
#   │     *   **การตรวจสอบความสมเหตุสมผล:** Prompt เดิมอาจไม่ได้เน้นย้ำให้ AI    │
#   │ ตรวจสอบความสมเหตุสมผลของคำตอบอย่างละเอียดเพียงพอ ทำให้ AI                  │
#   │ อาจไม่ได้สังเกตเห็นข้อผิดพลาดที่เกิดจากการคำนวณที่ไม่ถูกต้อง               │
#   │ หรือการตีความโจทย์ที่ผิดพลาด                                               │
#   │                                                                            │
#   │ 3.  **การปรับปรุง Prompt ใหม่:**                                           │
#   │     *   **เน้นย้ำการระบุข้อมูลที่ไม่สมบูรณ์:** เพิ่มข้อความที่เน้นย้ำให้   │
#   │ AI ระบุอย่างชัดเจนเมื่อข้อมูลไม่เพียงพอ และอธิบายว่าข้อมูลใดที่ขาดหายไป    │
#   │ หรือไม่สมเหตุสมผล และผลกระทบที่เกิดขึ้น                                    │
#   │     *   **เพิ่มความชัดเจนในการให้เหตุผล:** เพิ่มข้อความที่เน้นย้ำให้ AI    │
#   │ อธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอนอย่างละเอียด                          │
#   │ และให้ตัวอย่างการให้เหตุผล                                                 │
#   │     *   **เน้นย้ำการตรวจสอบความสมเหตุสมผล:** เพิ่มข้อความที่เน้นย้ำให้ AI  │
#   │ ตรวจสอบความสมเหตุสมผลของคำตอบอย่างละเอียด                                  │
#   │ และพิจารณาว่าคำตอบที่ได้อยู่ในช่วงที่ควรจะเป็นหรือไม่                      │
#   │ และมีหน่วยที่ถูกต้องหรือไม่                                                │
#   │     *   **เพิ่มตัวอย่างการให้เหตุผล:**                                     │
#   │ เพิ่มตัวอย่างการให้เหตุผลเมื่อโจทย์มีข้อมูลไม่เพียงพอ เพื่อให้ AI          │
#   │ เข้าใจวิธีการตอบสนองต่อสถานการณ์เช่นนี้                                    │
#   │     *   **คงรูปแบบ Output:** รักษารูปแบบ output เดิม (คำตอบเป็นตัวเลข)     │
#   │ เพื่อให้ง่ายต่อการเปรียบเทียบผลลัพธ์                                       │
#   │                                                                            │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#
#   ┌────────────────────────────────────────────────────────────────────────────┐
#   │ 🆕 Prompt ใหม่ที่สร้างขึ้น (1607 ตัวอักษร)                                 │
#   ├────────────────────────────────────────────────────────────────────────────┤
#   │                                                                            │
#   │ มาวิเคราะห์และแก้ปัญหาคณิตศาสตร์ต่อไปนี้อย่างละเอียด                       │
#   │ โดยเน้นการให้เหตุผลที่ชัดเจนและแม่นยำ:                                     │
#   │                                                                            │
#   │ {{ problem }}                                                              │
#   │                                                                            │
#   │ **วิธีคิด:**                                                               │
#   │                                                                            │
#   │ 1. **ทำความเข้าใจปัญหา:** อ่านโจทย์อย่างละเอียด ระบุสิ่งที่โจทย์ถาม        │
#   │ และข้อมูลที่โจทย์ให้มา หากมีข้อมูลใดขาดหายไป หรือไม่สมเหตุสมผล             │
#   │ ให้ระบุออกมาอย่างชัดเจน                                                    │
#   │ และพิจารณาว่าข้อมูลที่ให้มาเพียงพอต่อการหาคำตอบหรือไม่                     │
#   │ 2. **วางแผนการแก้ปัญหา:** พิจารณาว่าต้องใช้ขั้นตอนอะไรบ้างในการแก้ปัญหา    │
#   │ เลือกใช้สูตรหรือวิธีการที่เหมาะสม ระบุสูตรหรือหลักการที่ใช้                │
#   │ อธิบายเหตุผลในการเลือกใช้สูตรหรือวิธีการนั้นๆ                              │
#   │ 3. **ดำเนินการแก้ปัญหา:** แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด             │
#   │ พร้อมอธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอน เน้นการคำนวณที่ถูกต้องแม่นยำ    │
#   │ และตรวจสอบความสมเหตุสมผลของตัวเลขในแต่ละขั้นตอน หากมีการประมาณค่า          │
#   │ ให้ระบุเหตุผลในการประมาณค่า และผลกระทบที่อาจเกิดขึ้นกับความแม่นยำของคำตอบ  │
#   │ 4. **ตรวจสอบความถูกต้อง:** ตรวจสอบความถูกต้องของคำตอบที่ได้                │
#   │ โดยการทวนซ้ำขั้นตอนการคำนวณ                                                │
#   │ และตรวจสอบความสมเหตุสมผลของคำตอบกับสิ่งที่โจทย์ถาม                         │
#   │ พิจารณาว่าคำตอบที่ได้อยู่ในช่วงที่ควรจะเป็นหรือไม่                         │
#   │ และมีหน่วยที่ถูกต้องหรือไม่                                                │
#   │                                                                            │
#   │ **ขั้นตอนการคำนวณ:**                                                       │
#   │                                                                            │
#   │ (แสดงวิธีคำนวณทีละขั้นตอนอย่างละเอียด                                      │
#   │ พร้อมอธิบายเหตุผลในการเลือกใช้แต่ละขั้นตอน โดยเน้นความชัดเจนและแม่นยำ)     │
#   │                                                                            │
#   │ **สรุป:**                                                                  │
#   │                                                                            │
#   │ ดังนั้น คำตอบคือ: [คำตอบเป็นตัวเลข]                                        │
#   │                                                                            │
#   │ **หมายเหตุ:** หากโจทย์มีข้อมูลไม่เพียงพอ หรือไม่สมเหตุสมผล                 │
#   │ ให้ระบุเหตุผลที่ไม่สามารถหาคำตอบได้ พร้อมทั้งอธิบายว่าข้อมูลใดที่ขาดหายไป  │
#   │ หรือไม่สมเหตุสมผล และผลกระทบที่เกิดขึ้น                                    │
#   │                                                                            │
#   │ **ตัวอย่างการให้เหตุผล:**                                                  │
#   │                                                                            │
#   │ *   "เนื่องจากโจทย์ไม่ได้ระบุราคากางเกงที่แน่นอน                           │
#   │ ทำให้ไม่สามารถคำนวณราคารวมทั้งหมดได้"                                      │
#   │ *   "จากข้อมูลที่ให้มา                                                     │
#   │ พบว่าจำนวนโต๊ะไม่สอดคล้องกับจำนวนคนที่สามารถนั่งได้                        │
#   │ ดังนั้นจึงไม่สามารถหาจำนวนโต๊ะที่ต้องการเพิ่มได้อย่างแม่นยำ"               │
#   │                                                                            │
#   └────────────────────────────────────────────────────────────────────────────┘
#   📦 ลงทะเบียน version ใหม่: v7
#
#   ── ประวัติการ Optimize ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   📊 Accuracy แต่ละ Iteration
#   ┌────────┬────────────┬────────┬──────────┬─────────┐
#   │  Iter   │  Accuracy   │  Easy   │  Medium   │  Hard  │
#   ├────────┼────────────┼────────┼──────────┼─────────┤
#   │   1     │   66.7%     │  100%   │   50%     │  50%   │
#   │   2     │   66.7%     │  100%   │   50%     │  50%   │
#   │   3     │   66.7%     │  100%   │   50%     │  50%   │
#   └────────┴────────────┴────────┴──────────┴─────────┘
#     📈 การปรับปรุงรวม: 0.0%

# %% [markdown]
# ---
# ## 📊 ส่วนสุดท้าย: บันทึกผลใน MLflow และสรุปรวม
#
# MLflow ช่วยให้เราติดตามและเปรียบเทียบผลการทดลองทั้งหมดได้
# รวมถึง Prompt versions, metrics, และ parameters ต่างๆ

# %%
# ─────────────────────────────────────────────────────────
#  บันทึกผลทุกอย่างใน MLflow
# ─────────────────────────────────────────────────────────

print_title("บันทึกผลใน MLflow")

with mlflow.start_run(run_name="prompt_engineering_lab_final"):

    # ── SC Optimization Metrics ──
    for hist in loop_result["history"]:
        mlflow.log_metric(
            key  = f"sc_accuracy_iter{hist['iteration']}",
            value= hist["accuracy"],
        )

    mlflow.log_metric("sc_final_accuracy",  loop_result["final_accuracy"])
    mlflow.log_metric("sc_total_iterations", loop_result["total_iterations"])

    # ── Prompt Chaining Metrics ──
    mlflow.log_metric("chain_n_steps",       3)
    mlflow.log_metric("chain_report_length", len(chain_results.get("chain_report", "")))

    # ── Self-Critique Metrics ──
    mlflow.log_metric("critique_n_rounds",    len(critique_result["rounds"]))
    mlflow.log_metric("critique_final_length", len(critique_result["final_answer"]))

    # ── Parameters ──
    mlflow.log_param("model_id",     MODEL_ID)
    mlflow.log_param("techniques",   "Self-Consistency, Prompt-Chaining, Self-Critique")
    mlflow.log_param("test_size",    len(TEST_DATASET))
    mlflow.log_param("sc_n_samples", 3)
    mlflow.log_param("target_acc",   83.0)

    print("  ✅ บันทึก Metrics สำเร็จ:")
    print(f"     - SC final accuracy: {loop_result['final_accuracy']:.1f}%")
    print(f"     - SC iterations    : {loop_result['total_iterations']}")
    print(f"     - Chain steps      : 3")
    print(f"     - Critique rounds  : {len(critique_result['rounds'])}")
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 บันทึกผลใน MLflow
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   ✅ บันทึก Metrics สำเร็จ:
#      - SC final accuracy: 66.7%
#      - SC iterations    : 3
#      - Chain steps      : 3
#      - Critique rounds  : 2
# 🏃 View run prompt_engineering_lab_final at: http://127.0.0.1:5000/#/experiments/1/runs/8f3f339dd252421389bae497e8dfc2d9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
# ─────────────────────────────────────────────────────────
#  🏆 Dashboard สรุปผลทั้งหมด
# ─────────────────────────────────────────────────────────

print_title("🏆 Lab Dashboard — สรุปผลทั้งหมด")

# ── ตาราง Technique Results ──
sarcasm_detected = (
    "sarcasm" in chain_results.get("chain_extract", "").lower()
    or "ประชด" in chain_results.get("chain_extract", "")
    or "yes" in chain_results.get("chain_extract", "").lower()
)

print_table(
    headers = ["เทคนิค", "สิ่งที่วัด", "ผลลัพธ์"],
    rows    = [
        [
            "Self-Consistency",
            "Final Accuracy",
            f"{loop_result['final_accuracy']:.1f}%",
        ],
        [
            "Prompt Chaining",
            "Sarcasm Detected",
            "✅ ใช่" if sarcasm_detected else "❓ ไม่แน่ใจ",
        ],
        [
            "Self-Critique",
            "จำนวนรอบ Revise",
            f"{len(critique_result['rounds'])} รอบ",
        ],
    ],
    title = "ผลลัพธ์แต่ละเทคนิค",
)

# ── SC Optimization Progress ──
print_title("SC Optimization Progress", 2)
for hist in loop_result["history"]:
    print_progress(
        current = int(hist["accuracy"]),
        total   = 100,
        label   = f"Iter {hist['iteration']}: {hist['accuracy']:.1f}%",
    )

# ── MLflow Registry Summary ──
print_title("MLflow Prompt Registry", 2)

all_prompt_names = [
    SC_PROMPT_NAME,
    "chain_extract",
    "chain_analyze",
    "chain_report",
    "crit_generate",
    "crit_critic",
    "crit_revise",
]

print_table(
    headers = ["Prompt Name", "Latest Version", "เทคนิค"],
    rows    = [
        [
            name,
            f"v{get_latest_version(name)}",
            "Self-Consistency" if "sc_" in name
            else "Prompt Chaining" if "chain_" in name
            else "Self-Critique",
        ]
        for name in all_prompt_names
    ],
    title = "Prompt Registry Summary",
)

# ── Links ──
print_divider("═")
print(f"\n  🌐 ดูผลใน MLflow UI : {MLFLOW_URI}")
print(f"  📊 Experiment       : prompt_engineering_lab")
print(f"  📦 Prompts          : {len(all_prompt_names)} prompts registered")
print_divider("═")
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🔷 🏆 Lab Dashboard — สรุปผลทั้งหมด
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   📊 ผลลัพธ์แต่ละเทคนิค
#   ┌────────────────────┬────────────────────┬────────────┐
#   │       เทคนิค        │     สิ่งที่วัด      │  ผลลัพธ์  │
#   ├────────────────────┼────────────────────┼────────────┤
#   │  Self-Consistency   │   Final Accuracy    │   66.7%   │
#   │  Prompt Chaining    │  Sarcasm Detected   │   ✅ ใช่   │
#   │   Self-Critique     │  จำนวนรอบ Revise    │   2 รอบ   │
#   └────────────────────┴────────────────────┴────────────┘
#
#   ── SC Optimization Progress ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   [███████████████████░░░░░░░░░░░] 66%  Iter 1: 66.7%
#   [███████████████████░░░░░░░░░░░] 66%  Iter 2: 66.7%
#   [███████████████████░░░░░░░░░░░] 66%  Iter 3: 66.7%
#
#   ── MLflow Prompt Registry ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   📊 Prompt Registry Summary
#   ┌──────────────────┬──────────────────┬─────────────────────┐
#   │   Prompt Name     │  Latest Version   │       เทคนิค       │
#   ├──────────────────┼──────────────────┼─────────────────────┤
#   │  sc_math_solver   │        v7         │  Self-Consistency  │
#   │  chain_extract    │        v2         │  Prompt Chaining   │
#   │  chain_analyze    │        v2         │  Prompt Chaining   │
#   │   chain_report    │        v2         │  Prompt Chaining   │
#   │  crit_generate    │        v2         │   Self-Critique    │
#   │   crit_critic     │        v2         │   Self-Critique    │
#   │   crit_revise     │        v2         │   Self-Critique    │
#   └──────────────────┴──────────────────┴─────────────────────┘
#   ════════════════════════════════════════════════════════════
#
#   🌐 ดูผลใน MLflow UI : http://127.0.0.1:5000
#   📊 Experiment       : prompt_engineering_lab
#   📦 Prompts          : 7 prompts registered
#   ════════════════════════════════════════════════════════════

# %% [markdown]
# ![image.png](attachment:f77759d6-4e75-48ba-90c7-5bee41379cad.png)

# %% [markdown]
# ![image.png](attachment:c137b073-7c70-4481-bd98-3e201d36386f.png)

# %% [markdown]
# ![image.png](attachment:73489557-deee-4c4c-9a7b-70aea43a4e43.png)

# %% [markdown]
# ---
# ## 📝 สรุปบทเรียน (Key Takeaways)
#
# ### 3 เทคนิค Prompt Engineering
#
# | เมื่อไหร่ควรใช้? | เทคนิค | เหตุผล |
# |----------------|--------|--------|
# | งาน Math / Logic / ต้องการความแม่นยำ | **Self-Consistency** | Majority vote ลดโอกาสผิด |
# | งานซับซ้อนหลายขั้นตอน (เช่น วิเคราะห์ document) | **Prompt Chaining** | แยก focus, debug ง่าย |
# | หัวข้อ controversial / ต้องการ unbiased answer | **Self-Critique** | วิพากษ์ตัวเอง → รอบด้านขึ้น |
# | Prompt ยังให้ผลไม่ดีพอ | **Reflection Loop** | วิเคราะห์ข้อผิด → auto-improve |
#
# ### MLflow Best Practices
#
# | ✅ ควรทำ | ❌ ไม่ควรทำ |
# |---------|-----------|
# | ใส่ `commit_message` ทุกครั้งที่ register | Register โดยไม่มี message |
# | ติดตาม version ด้วย `track_version()` | ใช้ version hardcode |
# | `log_metric` ทุกครั้งที่ evaluate | วัดผลแค่ในหัว |
# | ตั้งชื่อ prompt ให้สื่อความหมาย | ตั้งชื่อ prompt1, prompt2 |
#
# ### แนวคิดที่สำคัญที่สุด
#
# > **"Prompt Engineering ไม่ใช่ศิลปะ แต่เป็นวิทยาศาสตร์"**
# >
# > วัดผล → วิเคราะห์ → ปรับปรุง → วัดผลซ้ำ
# > เหมือนการพัฒนา Software ที่ดี ต้องมี test และ iteration
#
# ---
# **🎉 ยินดีด้วย! คุณเรียนจบ Lab นี้แล้ว**
#
# สิ่งที่คุณทำได้แล้ว:
# - ✅ เขียนและทดสอบ 3 เทคนิค Prompt Engineering
# - ✅ ลงทะเบียนและจัดการ Prompt versions ใน MLflow
# - ✅ สร้าง Reflection Loop เพื่อปรับปรุง Prompt อัตโนมัติ
# - ✅ ติดตามและเปรียบเทียบผลด้วย MLflow Tracking
# ```
