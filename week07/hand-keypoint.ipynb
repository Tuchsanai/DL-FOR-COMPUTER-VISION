# %% [markdown]
# # https://docs.ultralytics.com/datasets/pose/hand-keypoints/#dataset-yaml

# %%
import IPython
import sys

def clean_notebook():
    IPython.display.clear_output(wait=True)
    print("Notebook cleaned.")

# Run the installation commands
# !pip install opendatasets
# !pip install ultralytics
# !pip install pytubefix

# Clean up the notebook
clean_notebook()
# Out:
# Notebook cleaned.

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.47 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L40S, 45589MiB)
# Setup complete ✅ (64 CPUs, 503.7 GB RAM, 2.1/152.0 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image


# Load a model
model = YOLO("yolo11n-pose.pt")  # load a pretrained model (recommended for training)


# Train the model with the specified configuration
results = model.train(
    data="hand-keypoints.yaml",  # Path to dataset YAML file
    epochs=40,         # Number of training epochs
    imgsz=640,          # Image size (resolution)
    batch=250,           # Batch size
    device=0,           # Specify GPU (0) or CPU ('cpu')
    lr0=0.001,           # Initial learning rate
    optimizer="Adam",   # Optimizer (e.g., 'SGD', 'Adam')
    workers=16,          # Number of dataloader workers
    seed=42,            # Random seed for reproducibility
    patience=10,        # Early stopping patience (number of epochs)
    weight_decay=0.0005,  # Weight decay for regularization
    momentum=0.937,     # Momentum for SGD
    name="hand",    # Name of the experiment folder
    verbose=False        # Print detailed training logs
)
# Out:
# Ultralytics 8.3.47 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L40S, 45589MiB)
# engine/trainer: task=pose, mode=train, model=yolo11n-pose.pt, data=hand-keypoints.yaml, epochs=40, time=None, patience=10, batch=250, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=16, project=None, name=hand2, exist_ok=False, pretrained=True, optimizer=Adam, verbose=False, seed=42, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/pose/hand2
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[21, 3]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    804898  ultralytics.nn.modules.head.Pose             [1, [21, 3], [64, 128, 256]]
# YOLO11n-pose summary: 344 layers, 2,964,066 parameters, 2,964,050 gradients, 7.9 GFLOPs
#
# Transferred 505/541 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/pose/hand2', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/labels.cache... 18776 images, 0 backgrounds, 491 corrupt: 100%|██████████| 18776/18776 [00:00<?, ?it/s]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00001070.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0379]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00001796.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0006]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00001800.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0027]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00001801.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0049]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00001886.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0051      1.0038      1.0088      1.0114]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00001887.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0048      1.0062      1.0099      1.0121]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00001888.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [          1      1.0017]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00001994.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0059]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00001998.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0044]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00001999.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.007]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002000.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0083]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0146]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002002.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0178]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002003.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0178]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002143.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0582      1.0216]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002144.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0641      1.0333]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002202.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0041      1.0052       1.008      1.0093      1.0108      1.0112      1.0116]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002451.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0121]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002454.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.023      1.0012]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002545.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0051]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002744.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0159]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002745.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0334]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002746.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0399]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002747.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0453      1.0009]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002749.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0701       1.011]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002751.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0658      1.0113]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002752.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0505]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002754.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0313]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002760.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0266]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002761.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0449]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002991.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0021      1.0099]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00002996.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.007]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0211      1.0371      1.0143      1.0292      1.0036      1.0175      1.0073]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003109.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0766      1.0215]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003111.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0615      1.0047]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003114.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0173]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003162.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0111      1.0368]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003164.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0071      1.0047      1.0238      1.0125      1.0397        1.01      1.0396      1.0152]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003372.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.003      1.0101]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003385.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0125       1.027      1.0279      1.0451      1.0597]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003387.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0005      1.0227      1.0413      1.0243      1.0437      1.0603]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003388.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0187      1.0366      1.0213       1.039      1.0546]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003390.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0208      1.0405      1.0225      1.0423      1.0603]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00003391.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0067      1.0217       1.012      1.0306      1.0467]
# train: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/train/images/IMG_00
jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0013]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00026507.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0183]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00026508.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0182]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00026821.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0078      1.0395]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00026823.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0004       1.032]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00027075.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0074]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00027080.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0135]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00027704.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0027]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00027976.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0408      1.0878]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00027994.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0138]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00034349.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0249]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00034421.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0076]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00034527.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0115]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00034962.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0867]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00035027.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0038]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00035055.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0369]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00035057.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0388]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00035059.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0393]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00035123.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0529]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00035125.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0406]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00035439.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0209]
# val: WARNING ⚠️ /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00035441.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0093]
# Plotting labels to runs/pose/hand2/labels.jpg...
# optimizer: Adam(lr=0.001, momentum=0.937) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.001953125), 96 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 16 dataloader workers
# Logging results to runs/pose/hand2
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      37.9G        1.1      10.22     0.6685      1.137       1.44         72        640: 100%|██████████| 74/74 [01:20<00:00,  1.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:25<00:00,  1.60s/it]
#                    all       7808       7808       0.74       0.75      0.829      0.648          0          0          0          0
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        2/40      36.3G     0.8262      8.336     0.6035     0.5469      1.206         76        640: 100%|██████████| 74/74 [00:54<00:00,  1.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:25<00:00,  1.59s/it]
#                    all       7808       7808      0.919      0.907      0.965      0.727     0.0478     0.0265    0.00301   0.000322
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        3/40      36.3G     0.8108      7.116     0.5126     0.5392      1.197         76        640: 100%|██████████| 74/74 [00:54<00:00,  1.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:25<00:00,  1.59s/it]
#                    all       7808       7808      0.898      0.792      0.895      0.675       0.57      0.263      0.215      0.043
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        4/40      36.3G     0.8038      6.331     0.4449     0.5384      1.191         78        640: 100%|██████████| 74/74 [00:54<00:00,  1.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:25<00:00,  1.61s/it]
#                    all       7808       7808      0.891      0.873       0.94      0.719       0.18      0.105     0.0313    0.00412
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      36.3G     0.7851      5.864      0.409     0.5179      1.177         77        640: 100%|██████████| 74/74 [00:54<00:00,  1.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:25<00:00,  1.58s/it]
#                    all       7808       7808      0.916      0.775      0.861      0.662      0.464      0.279      0.173     0.0503
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      36.3G     0.7766      5.418     0.3912     0.5086      1.172         76        640: 100%|██████████| 74/74 [00:54<00:00,  1.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:25<00:00,  1.59s/it]
#                    all       7808       7808       0.94      0.917      0.972      0.784      0.801      0.506       0.54      0.235
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      36.3G     0.7574      5.149     0.3807     0.4992      1.162         66        640: 100%|██████████| 74/74 [00:54<00:00,  1.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95):  12%|█▎        | 2/16 [00:04<00:30,  2.21s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 10
#       6 model = YOLO("yolo11n-pose.pt")  # load a pretrained model (recommended for training)
#       9 # Train the model with the specified configuration
# ---> 10 results = model.train(
#      11     data="hand-keypoints.yaml",  # Path to dataset YAML file
#      12     epochs=40,         # Number of training epochs
#      13     imgsz=640,          # Image size (resolution)
#      14     batch=250,           # Batch size
#      15     device=0,           # Specify GPU (0) or CPU ('cpu')
#      16     lr0=0.001,           # Initial learning rate
#      17     optimizer="Adam",   # Optimizer (e.g., 'SGD', 'Adam')
#      18     workers=16,          # Number of dataloader workers
#      19     seed=42,            # Random seed for reproducibility
#      20     patience=10,        # Early stopping patience (number of epochs)
#      21     weight_decay=0.0005,  # Weight decay for regularization
#      22     momentum=0.937,     # Momentum for SGD
#      23     name="hand",    # Name of the experiment folder
#      24     verbose=False        # Print detailed training logs
#      25 )
#
# File /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py:806, in Model.train(self, trainer, **kwargs)
#     803     self.model = self.trainer.model
#     805 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 806 self.trainer.train()
#     807 # Update model and cfg after training
#     808 if RANK in {-1, 0}:
#
# File /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py:207, in BaseTrainer.train(self)
#     204         ddp_cleanup(self, str(file))
#     206 else:
# --> 207     self._do_train(world_size)
#
# File /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py:432, in BaseTrainer._do_train(self, world_size)
#     430 # Validation
#     431 if self.args.val or final_epoch or self.stopper.possible_stop or self.stop:
# --> 432     self.metrics, self.fitness = self.validate()
#     433 self.save_metrics(metrics={**self.label_loss_items(self.tloss), **self.metrics, **self.lr})
#     434 self.stop |= self.stopper(epoch + 1, self.fitness) or final_epoch
#
# File /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py:605, in BaseTrainer.validate(self)
#     599 def validate(self):
#     600     """
#     601     Runs validation on test set using self.validator.
#     602
#     603     The returned dict is expected to contain "fitness" key.
#     604     """
# --> 605     metrics = self.validator(self)
#     606     fitness = metrics.pop("fitness", -self.loss.detach().cpu().numpy())  # use loss as fitness measure if not found
#     607     if not self.best_fitness or self.best_fitness < fitness:
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/ultralytics/engine/validator.py:191, in BaseValidator.__call__(self, trainer, model)
#     188 with dt[3]:
#     189     preds = self.postprocess(preds)
# --> 191 self.update_metrics(preds, batch)
#     192 if self.args.plots and batch_i < 3:
#     193     self.plot_val_samples(batch, batch_i)
#
# File /usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/pose/val.py:140, in PoseValidator.update_metrics(self, preds, batch)
#     138 if nl:
#     139     stat["tp"] = self._process_batch(predn, bbox, cls)
# --> 140     stat["tp_p"] = self._process_batch(predn, bbox, cls, pred_kpts, pbatch["kpts"])
#     141 if self.args.plots:
#     142     self.confusion_matrix.process_batch(predn, bbox, cls)
#
# File /usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/pose/val.py:193, in PoseValidator._process_batch(self, detections, gt_bboxes, gt_cls, pred_kpts, gt_kpts)
#     190 if pred_kpts is not None and gt_kpts is not None:
#     191     # `0.53` is from https://github.com/jin-s13/xtcocoapi/blob/master/xtcocotools/cocoeval.py#L384
#     192     area = ops.xyxy2xywh(gt_bboxes)[:, 2:].prod(1) * 0.53
# --> 193     iou = kpt_iou(gt_kpts, pred_kpts, sigma=self.sigma, area=area)
#     194 else:  # boxes
#     195     iou = box_iou(gt_bboxes, detections[:, :4])
#
# File /usr/local/lib/python3.10/dist-packages/ultralytics/utils/metrics.py:166, in kpt_iou(kpt1, kpt2, area, sigma, eps)
#     152 """
#     153 Calculate Object Keypoint Similarity (OKS).
#     154
#    (...)
#     163     (torch.Tensor): A tensor of shape (N, M) representing keypoint similarities.
#     164 """
#     165 d = (kpt1[:, None, :, 0] - kpt2[..., 0]).pow(2) + (kpt1[:, None, :, 1] - kpt2[..., 1]).pow(2)  # (N, M, 17)
# --> 166 sigma = torch.tensor(sigma, device=kpt1.device, dtype=kpt1.dtype)  # (17, )
#     167 kpt_mask = kpt1[..., 2] != 0  # (N, 17)
#     168 e = d / ((2 * sigma).pow(2) * (area[:, None, None] + eps) * 2)  # from cocoeval
#
# KeyboardInterrupt:

# %%
Image("./runs/pose/hand2/train_batch0.jpg", width=1200)

# %%
from ultralytics import YOLO
from IPython.display import Image


# Load a model
model = YOLO("./runs/pose/hand2/weights/best.pt")  # load a tiger-pose trained model



# Perform object detection on an image
results = model("./datasets/hand-keypoints/val/images/IMG_00000417.jpg")
results[0].show()
# Out:
# image 1/1 /workspace/DL-FOR-COMPUTER-VISION/week07/datasets/hand-keypoints/val/images/IMG_00000417.jpg: 640x640 1 hand, 7.4ms
# Speed: 7.9ms preprocess, 7.4ms inference, 115.4ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
results[0].keypoints.data
# Out:
# tensor([[[102.7963, 179.2785,   0.9030],
#          [122.6599, 171.9601,   0.9348],
#          [142.2590, 156.3861,   0.9299],
#          [149.2163, 137.8172,   0.8828],
#          [161.0388, 123.8389,   0.8869],
#          [122.0855, 123.9145,   0.9754],
#          [125.5809,  97.5933,   0.9488],
#          [126.2477,  79.8931,   0.9290],
#          [ 96.0299, 129.6418,   0.9220],
#          [106.4111, 124.0240,   0.9680],
#          [108.5971,  90.2673,   0.9615],
#          [107.5857,  72.8316,   0.9320],
#          [110.6095,  62.7781,   0.9110],
#          [ 91.2756, 124.4492,   0.9412],
#          [ 93.7602,  95.5578,   0.9538],
#          [ 88.4766,  78.9816,   0.9377],
#          [ 93.6417,  61.8632,   0.9307],
#          [ 79.9383, 135.8782,   0.9130],
#          [ 76.5532, 114.9280,   0.9073],
#          [ 75.5452,  99.8014,   0.9173],
#          [ 73.2496,  84.1536,   0.8899]]], device='cuda:0')

# %% [markdown]
# #  Pose Estimation with opencv

# %%
import cv2
import matplotlib.pyplot as plt


# Load the image
image = cv2.imread("./datasets/hand-keypoints/val/images/IMG_00000417.jpg")
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

results = model(image_rgb,verbose=False)

# Iterate over detected persons
for person in results[0].keypoints.data.cpu().numpy():
   
    for idx, keypoint in enumerate(person):
        x, y, score = keypoint
        cv2.circle(image_rgb, (int(x), int(y)), radius=10, color=(0, 255, 0), thickness=-1)
        cv2.putText(image_rgb, str(idx), (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)

# Display the image using Matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(image_rgb)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# # To integrate reading a YouTube stream with Pose

# %%
import cv2
from IPython.display import display, Image, clear_output
from pytubefix import YouTube
from ultralytics import YOLO

# Set the desired width for resizing frames
set_width = 800

# Load your YOLO pose estimation model
model = YOLO("./hand_pose_best.pt")  # Replace with your pose estimation model

# YouTube video URL
video_url = "https://www.youtube.com/watch?v=jzJjdvTF10A"

# Fetch the video stream URL using pytube
yt = YouTube(video_url)
video_stream = yt.streams.filter(file_extension='mp4', progressive=True,).first()

if not video_stream:
    print("No compatible video stream found.")
    raise RuntimeError("Failed to fetch video stream.")

# Get the stream URL
stream_url = video_stream.url

# Open the YouTube stream in OpenCV
cap = cv2.VideoCapture(stream_url)

if not cap.isOpened():
    print(f"Error: Could not open YouTube video stream.")
    cap.release()
    raise RuntimeError("Video initialization failed.")

try:
    while True:
        # Read a frame from the video
        ret, frame = cap.read()
        if not ret:
            print("End of video or failed to grab frame.")
            break

        # Resize the frame for faster processing
        ratio = set_width / frame.shape[1]
        frame = cv2.resize(frame, (set_width, int(frame.shape[0] * ratio)))

        # Run pose estimation on the frame
        results = model(frame, verbose=False)

        # Iterate over detected persons and draw keypoints
        for person in results[0].keypoints.data.cpu().numpy():
            for idx, keypoint in enumerate(person):
                x, y,score = keypoint
                cv2.circle(frame, (int(x), int(y)), radius=5, color=(0, 255, 0), thickness=-1)
                cv2.putText(frame, str(idx), (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)

        # Encode the frame as JPEG
        _, buffer = cv2.imencode('.jpg', frame)
        img_bytes = buffer.tobytes()

        # Display the frame inline in the notebook
        display(Image(data=img_bytes))
        clear_output(wait=True)
finally:
    cap.release()
