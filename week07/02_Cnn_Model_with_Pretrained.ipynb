# %% [markdown]
# ## How to find All model in torchvision.models

# %%
import torchvision.models as models

model_list = dir(models)

print('Available models: ',len(model_list))
print(model_list[1:5])
# Out:
# Available models:  221
# ['AlexNet_Weights', 'ConvNeXt', 'ConvNeXt_Base_Weights', 'ConvNeXt_Large_Weights']

# %% [markdown]
# ## Show all model in pandas dataframe

# %%
import pandas as pd
import torchvision.models as models
import inspect

# Function to get all available models in torchvision.models
def get_torchvision_models():
    model_names = []
    descriptions = []
    # List all members of torchvision.models
    for name, obj in inspect.getmembers(models):
        if inspect.isfunction(obj) or inspect.isclass(obj):
            # Assuming the naming convention is consistent and models are functions/classes
            model_names.append(name)
            # Generic description; customize this as needed
            descriptions.append("")
    
    # Create a DataFrame
    df = pd.DataFrame({
        'Model Name': model_names,
        'Description': descriptions
    })
    return df

# Get the DataFrame of models and descriptions
df_models = get_torchvision_models()

# %%
import pandas as pd

# Set the display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Display the df_models DataFrame
df_models
# Out:
#                      Model Name        Description
# 0                       AlexNet  torchvision.model
# 1               AlexNet_Weights  torchvision.model
# 2                      ConvNeXt  torchvision.model
# 3         ConvNeXt_Base_Weights  torchvision.model
# 4        ConvNeXt_Large_Weights  torchvision.model
# 5        ConvNeXt_Small_Weights  torchvision.model
# 6         ConvNeXt_Tiny_Weights  torchvision.model
# 7                      DenseNet  torchvision.model
# 8           DenseNet121_Weights  torchvision.model
# 9           DenseNet161_Weights  torchvision.model
# 10          DenseNet169_Weights  torchvision.model
# 11          DenseNet201_Weights  torchvision.model
# 12                 EfficientNet  torchvision.model
# 13      EfficientNet_B0_Weights  torchvision.model
# 14      EfficientNet_B1_Weights  torchvision.model
# 15      EfficientNet_B2_Weights  torchvision.model
# 16      EfficientNet_B3_Weights  torchvision.model
# 17      EfficientNet_B4_Weights  torchvision.model
# 18      EfficientNet_B5_Weights  torchvision.model
# 19      EfficientNet_B6_Weights  torchvision.model
# 20      EfficientNet_B7_Weights  torchvision.model
# 21    EfficientNet_V2_L_Weights  torchvision.model
# 22    EfficientNet_V2_M_Weights  torchvision.model
# 23    EfficientNet_V2_S_Weights  torchvision.model
# 24                    GoogLeNet  torchvision.model
# 25             GoogLeNetOutputs  torchvision.model
# 26            GoogLeNet_Weights  torchvision.model
# 27                   Inception3  torchvision.model
# 28             InceptionOutputs  torchvision.model
# 29         Inception_V3_Weights  torchvision.model
# 30                      MNASNet  torchvision.model
# 31           MNASNet0_5_Weights  torchvision.model
# 32          MNASNet0_75_Weights  torchvision.model
# 33           MNASNet1_0_Weights  torchvision.model
# 34           MNASNet1_3_Weights  torchvision.model
# 35                       MaxVit  torchvision.model
# 36             MaxVit_T_Weights  torchvision.model
# 37                  MobileNetV2  torchvision.model
# 38                  MobileNetV3  torchvision.model
# 39         MobileNet_V2_Weights  torchvision.model
# 40   MobileNet_V3_Large_Weights  torchvision.model
# 41   MobileNet_V3_Small_Weights  torchvision.model
# 42                       RegNet  torchvision.model
# 43        RegNet_X_16GF_Weights  torchvision.model
# 44       RegNet_X_1_6GF_Weights  torchvision.model
# 45        RegNet_X_32GF_Weights  torchvision.model
# 46       RegNet_X_3_2GF_Weights  torchvision.model
# 47       RegNet_X_400MF_Weights  torchvision.model
# 48       RegNet_X_800MF_Weights  torchvision.model
# 49         RegNet_X_8GF_Weights  torchvision.model
# 50       RegNet_Y_128GF_Weights  torchvision.model
# 51        RegNet_Y_16GF_Weights  torchvision.model
# 52       RegNet_Y_1_6GF_Weights  torchvision.model
# 53        RegNet_Y_32GF_Weights  torchvision.model
# 54       RegNet_Y_3_2GF_Weights  torchvision.model
# 55       RegNet_Y_400MF_Weights  torchvision.model
# 56       RegNet_Y_800MF_Weights  torchvision.model
# 57         RegNet_Y_8GF_Weights  torchvision.model
# 58     ResNeXt101_32X8D_Weights  torchvision.model
# 59     ResNeXt101_64X4D_Weights  torchvision.model
# 60      ResNeXt50_32X4D_Weights  torchvision.model
# 61                       ResNet  torchvision.model
# 62            ResNet101_Weights  torchvision.model
# 63            ResNet152_Weights  torchvision.model
# 64             ResNet18_Weights  torchvision.model
# 65             ResNet34_Weights  torchvision.model
# 66             ResNet50_Weights  torchvision.model
# 67                 ShuffleNetV2  torchvision.model
# 68   ShuffleNet_V2_X0_5_Weights  torchvision.model
# 69   ShuffleNet_V2_X1_0_Weights  torchvision.model
# 70   ShuffleNet_V2_X1_5_Weights  torchvision.model
# 71   ShuffleNet_V2_X2_0_Weights  torchvision.model
# 72                   SqueezeNet  torchvision.model
# 73        SqueezeNet1_0_Weights  torchvision.model
# 74        SqueezeNet1_1_Weights  torchvision.model
# 75              SwinTransformer  torchvision.model
# 76               Swin_B_Weights  torchvision.model
# 77               Swin_S_Weights  torchvision.model
# 78               Swin_T_Weights  torchvision.model
# 79            Swin_V2_B_Weights  torchvision.model
# 80            Swin_V2_S_Weights  torchvision.model
# 81            Swin_V2_T_Weights  torchvision.model
# 82                          VGG  torchvision.model
# 83             VGG11_BN_Weights  torchvision.model
# 84                VGG11_Weights  torchvision.model
# 85             VGG13_BN_Weights  torchvision.model
# 86                VGG13_Weights  torchvision.model
# 87             VGG16_BN_Weights  torchvision.model
# 88                VGG16_Weights  torchvision.model
# 89             VGG19_BN_Weights  torchvision.model
# 90                VGG19_Weights  torchvision.model
# 91             ViT_B_16_Weights  torchvision.model
# 92             ViT_B_32_Weights  torchvision.model
# 93             ViT_H_14_Weights  torchvision.model
# 94             ViT_L_16_Weights  torchvision.model
# 95             ViT_L_32_Weights  torchvision.model
# 96            VisionTransformer  torchvision.model
# 97                      Weights  torchvision.model
# 98                  WeightsEnum  torchvision.model
# 99     Wide_ResNet101_2_Weights  torchvision.model
# 100     Wide_ResNet50_2_Weights  torchvision.model
# 101           _GoogLeNetOutputs  torchvision.model
# 102           _InceptionOutputs  torchvision.model
# 103                     alexnet  torchvision.model
# 104               convnext_base  torchvision.model
# 105              convnext_large  torchvision.model
# 106              convnext_small  torchvision.model
# 107               convnext_tiny  torchvision.model
# 108                 densenet121  torchvision.model
# 109                 densenet161  torchvision.model
# 110                 densenet169  torchvision.model
# 111                 densenet201  torchvision.model
# 112             efficientnet_b0  torchvision.model
# 113             efficientnet_b1  torchvision.model
# 114             efficientnet_b2  torchvision.model
# 115             efficientnet_b3  torchvision.model
# 116             efficientnet_b4  torchvision.model
# 117             efficientnet_b5  torchvision.model
# 118             efficientnet_b6  torchvision.model
# 119             efficientnet_b7  torchvision.model
# 120           efficientnet_v2_l  torchvision.model
# 121           efficientnet_v2_m  torchvision.model
# 122           efficientnet_v2_s  torchvision.model
# 123                   get_model  torchvision.model
# 124           get_model_builder  torchvision.model
# 125           get_model_weights  torchvision.model
# 126                  get_weight  torchvision.model
# 127                   googlenet  torchvision.model
# 128                inception_v3  torchvision.model
# 129                 list_models  torchvision.model
# 130                    maxvit_t  torchvision.model
# 131                  mnasnet0_5  torchvision.model
# 132                 mnasnet0_75  torchvision.model
# 133                  mnasnet1_0  torchvision.model
# 134                  mnasnet1_3  torchvision.model
# 135                mobilenet_v2  torchvision.model
# 136          mobilenet_v3_large  torchvision.model
# 137          mobilenet_v3_small  torchvision.model
# 138               regnet_x_16gf  torchvision.model
# 139              regnet_x_1_6gf  torchvision.model
# 140               regnet_x_32gf  torchvision.model
# 141              regnet_x_3_2gf  torchvision.model
# 142              regnet_x_400mf  torchvision.model
# 143              regnet_x_800mf  torchvision.model
# 144                regnet_x_8gf  torchvision.model
# 145              regnet_y_128gf  torchvision.model
# 146               regnet_y_16gf  torchvision.model
# 147              regnet_y_1_6gf  torchvision.model
# 148               regnet_y_32gf  torchvision.model
# 149              regnet_y_3_2gf  torchvision.model
# 150              regnet_y_400mf  torchvision.model
# 151              regnet_y_800mf  torchvision.model
# 152                regnet_y_8gf  torchvision.model
# 153                   resnet101  torchvision.model
# 154                   resnet152  torchvision.model
# 155                    resnet18  torchvision.model
# 156                    resnet34  torchvision.model
# 157                    resnet50  torchvision.model
# 158            resnext101_32x8d  torchvision.model
# 159            resnext101_64x4d  torchvision.model
# 160             resnext50_32x4d  torchvision.model
# 161          shufflenet_v2_x0_5  torchvision.model
# 162          shufflenet_v2_x1_0  torchvision.model
# 163          shufflenet_v2_x1_5  torchvision.model
# 164          shufflenet_v2_x2_0  torchvision.model
# 165               squeezenet1_0  torchvision.model
# 166               squeezenet1_1  torchvision.model
# 167                      swin_b  torchvision.model
# 168                      swin_s  torchvision.model
# 169                      swin_t  torchvision.model
# 170                   swin_v2_b  torchvision.model
# 171                   swin_v2_s  torchvision.model
# 172                   swin_v2_t  torchvision.model
# 173                       vgg11  torchvision.model
# 174                    vgg11_bn  torchvision.model
# 175                       vgg13  torchvision.model
# 176                    vgg13_bn  torchvision.model
# 177                       vgg16  torchvision.model
# 178                    vgg16_bn  torchvision.model
# 179                       vgg19  torchvision.model
# 180                    vgg19_bn  torchvision.model
# 181                    vit_b_16  torchvision.model
# 182                    vit_b_32  torchvision.model
# 183                    vit_h_14  torchvision.model
# 184                    vit_l_16  torchvision.model
# 185                    vit_l_32  torchvision.model
# 186            wide_resnet101_2  torchvision.model
# 187             wide_resnet50_2  torchvision.model

# %%
pd.reset_option('^display.')

# %%
df_models.info()
# Out:
#                  Model Name        Description
# 0                   AlexNet  torchvision.model
# 1           AlexNet_Weights  torchvision.model
# 2                  ConvNeXt  torchvision.model
# 3     ConvNeXt_Base_Weights  torchvision.model
# 4    ConvNeXt_Large_Weights  torchvision.model
# ..                      ...                ...
# 183                vit_h_14  torchvision.model
# 184                vit_l_16  torchvision.model
# 185                vit_l_32  torchvision.model
# 186        wide_resnet101_2  torchvision.model
# 187         wide_resnet50_2  torchvision.model
#
# [188 rows x 2 columns]

# %% [markdown]
# # download imagenet-simple-labels.json

# %%
import os
if not os.path.exists('imagenet-simple-labels.json'):
   # !wget https://raw.githubusercontent.com/anishathalye/imagenet-simple-labels/master/imagenet-simple-labels.json

# %%
import torch
import torchvision.models as models

# Load pre-trained VGG16 model
vgg16 = models.vgg16(pretrained=True)
vgg16.eval()

# Load pre-trained ResNet50 model
resnet50 = models.resnet50(pretrained=True)
resnet50.eval()

# Load pre-trained EfficientNet model
efficientnet = models.efficientnet_b0(pretrained=True)
efficientnet.eval()

# %%
import torch
from torchvision import models, transforms
from PIL import Image
import requests
from io import BytesIO

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
url = 'https://github.com/pytorch/hub/raw/master/images/dog.jpg'
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# %%
img_t = transform(img)
batch_t = torch.unsqueeze(img_t, 0)  # Add batch dimension


print(img_t.shape, batch_t.shape)
# Out:
# torch.Size([3, 224, 224]) torch.Size([1, 3, 224, 224])

# %%
import torch
import torchvision.models as models

# Load pre-trained VGG16 model
vgg16 = models.vgg16(pretrained=True)
vgg16.eval()


with torch.no_grad():
    out = vgg16(batch_t)
    _, index = torch.max(out, 1)

    print(out.shape)
    print(index)
# Out:
# torch.Size([1, 1000])
# tensor([258])

# %%
import torch
import torchvision.models as models


resnet50 = models.resnet50(pretrained=True)
resnet50.eval()

with torch.no_grad():
    out = resnet50(batch_t)
    _, index = torch.max(out, 1)

    print(out.shape)
    print(index)
# Out:
# /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /Users/tuchsanai/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:02<00:00, 34.7MB/s]
# torch.Size([1, 1000])
# tensor([258])

# %%
import json

# Load the labels from the JSON file
with open('imagenet-simple-labels.json') as f:
    labels = json.load(f)

# Get the label for a specific index

label = labels[index]

print(f"Label for index {index}: {label}")
# Out:
# Label for index tensor([258]): Samoyed

# %% [markdown]
# ![image.png](attachment:image.png)
