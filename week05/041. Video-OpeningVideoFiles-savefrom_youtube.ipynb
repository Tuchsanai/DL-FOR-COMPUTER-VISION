# %%
import IPython
import sys

def clean_notebook():
    IPython.display.clear_output(wait=True)
    print("Notebook cleaned.")
# !pip install yt-dlp 
# Clean up the notebook
clean_notebook()
# Out:
# Notebook cleaned.

# %% [markdown]
# # Download video

# %%
from yt_dlp import YoutubeDL

YOUTUBE_URL = "https://youtu.be/GzWeEDIff0M?si=TXob5MKmzTRk6bxs"

ydl_opts = {
    "format": "best",
    "outtmpl":"butterbear.mp4"
    }
with YoutubeDL(ydl_opts) as ydl:
    ydl.download([YOUTUBE_URL])
# Out:
# [youtube] Extracting URL: https://youtu.be/GzWeEDIff0M?si=TXob5MKmzTRk6bxs
# [youtube] GzWeEDIff0M: Downloading webpage
# [youtube] GzWeEDIff0M: Downloading ios player API JSON
# [youtube] GzWeEDIff0M: Downloading mweb player API JSON
# [youtube] GzWeEDIff0M: Downloading m3u8 information
# [info] GzWeEDIff0M: Downloading 1 format(s): 18
# [download] Destination: butterbear.mp4
#
# download] 100% of  975.89KiB in 00:00:00 at 12.57MiB/s

# %% [markdown]
# # Display video from Notebook

# %%
import cv2
from IPython.display import display, Image, clear_output
import numpy as np

# Open the video file
cap = cv2.VideoCapture('./butterbear.mp4')

if not cap.isOpened():
    print("Cannot open video file")
    exit()

while cap.isOpened():
    ret, frame = cap.read()
    
    if not ret:
        print("Stream stopped.")
        break

    # Convert the frame to JPEG format for display in Jupyter
    _, buffer = cv2.imencode('.jpg', frame)
    img_bytes = buffer.tobytes()

    # Display the frame in Jupyter Notebook
    display(Image(data=img_bytes))
    clear_output(wait=True)  # Clear previous frame for smoother playback

  
    
cap.release()
print("Video stream ended.")
