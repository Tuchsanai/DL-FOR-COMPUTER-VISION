# %%
import IPython
import sys

def clean_notebook():
    IPython.display.clear_output(wait=True)
    print("Notebook cleaned.")

# Run the installation commands
# !pip install opendatasets
# !pip install ultralytics

# Clean up the notebook
clean_notebook()
# Out:
# Notebook cleaned.

# %% [markdown]
# ![image.png](attachment:1ac1cc12-578d-4d91-8081-6e34162d250f.png)

# %%
import opendatasets as od
od.download("https://www.kaggle.com/mahmudulhaqueshawon/catcat")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
#   tuchsanai
# Your Kaggle Key:
#   ········
# Dataset URL: https://www.kaggle.com/datasets/mahmudulhaqueshawon/catcat
# ...
# 100%|██████████| 62.9M/62.9M [00:04<00:00, 13.7MB/s]

# %%
from ultralytics import YOLO

#loading classification model
model = YOLO('yolo11n-cls.pt')

#train the model
# Train the model with the specified configuration
results = model.train(
    data="./catcat",  # Path to dataset YAML file
    epochs=50,         # Number of training epochs
    imgsz=640,          # Image size (resolution)
    batch=70,           # Batch size
    device=0,           # Specify GPU (0) or CPU ('cpu')
    lr0=0.005,           # Initial learning rate
    optimizer="Adam",   # Optimizer (e.g., 'SGD', 'Adam')
    workers=8,          # Number of dataloader workers
    seed=42,            # Random seed for reproducibility
    patience=20,        # Early stopping patience (number of epochs)
    weight_decay=0.0005,  # Weight decay for regularization
    momentum=0.937,     # Momentum for SGD
    name="exp_name",    # Name of the experiment folder
    verbose=True        # Print detailed training logs
)
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-80GB MIG 7g.80gb, 81051MiB)
# ...

# %% [markdown]
# # Inference

# %%
from IPython.display import Image

# %%
Image("./runs/classify/exp_name/results.png", width=600)

# %%
Image("./runs/classify/exp_name/confusion_matrix.png", width=800)

# %%
Image("./runs/classify/exp_name/val_batch0_pred.jpg", width=800)

# %%
results = model("./catcat/test/dogs/dog_173.jpg") #, save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /workspace/code/week07/catcat/test/dogs/dog_173.jpg: 640x640 dogs 0.81, cats 0.19, 4.8ms
# Speed: 22.3ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
results
