# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.nn as nn

# %%
t = np.arange(0, 20, 0.1)

#random data on x-axis
A1  = 5*np.random.rand()
f1  = 10*np.random.rand()

b1    = 20*np.random.rand()
ceta1 = 2*np.random.rand()*np.pi

signal1 =  A1*np.sin(f1*t+ceta1)+b1

#random data on x-axis
A2  = 12*np.random.rand()
f2  = 50*np.random.rand()

b2    = 20*np.random.rand()
ceta2 = 2*np.random.rand()*np.pi

signal2 =  A2*np.cos(f2*t+ceta2)+b2




y      =  signal1 + signal2 + 0.5*np.random.randn(len(t))


print(f"A1 = {A1}, f1 = {f1} , ceta1 = {ceta1} b1= {b1}")
print(f"A2 = {A2}, f1 = {f2} , ceta2 = {ceta2} b2= {b2}")
# Out:
# A1 = 2.113977281581361, f1 = 9.822252877365727 , ceta1 = 4.8488901518243095 b1= 12.864149534898445
# A2 = 5.861922280723345, f1 = 43.53111881846217 , ceta2 = 4.843634595801936 b2= 5.637541083837299

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.plot(t,y)
plt.legend(['y'])
plt.subplot(2,1,2)

plt.plot(t,signal1,t,signal2)
plt.legend(['signal1','signal2'])

# %%
y
# Out:
# array([0.51385505, 0.73860267, 0.61332355, 0.45182967, 0.51101263,
#        0.31511268, 0.53538967, 0.52809727, 0.40882086, 0.28379103,
#        0.59675687, 0.44366198, 0.33579071, 0.36860687, 0.40696448,
#        0.47208392, 0.4681935 , 0.71383296, 0.40316488, 0.71405356,
#        0.81905794, 0.64823001, 0.74422444, 0.61540339, 0.79485749,
#        0.97749691, 0.84353884, 0.92137235, 1.02747973, 1.0787426 ,
#        1.27080151, 1.0830745 , 1.26569055, 1.25228223, 1.28968885,
#        1.37112666, 1.28091891, 1.37838694, 1.26923488, 1.50483448,
#        1.20089353, 1.51672628, 1.35663514, 1.36560781, 1.23860447,
#        1.26639261, 1.35800468, 1.24858104, 1.28491062, 1.24986642,
#        1.29066996, 1.18170669, 1.05909343, 1.01955463, 0.96227154,
#        1.12215788, 1.06175615, 1.05723421, 0.88002006, 0.70463422,
#        0.84455447, 0.56077826, 0.7579261 , 0.8278526 , 0.61516834,
#        0.55289785, 0.54022664, 0.45838078, 0.5958296 , 0.60777273,
#        0.49280409, 0.45920367, 0.29536093, 0.39398017, 0.52299874,
#        0.52628912, 0.51852063, 0.47792888, 0.40627194, 0.38320627,
#        0.49820816, 0.6221937 , 0.62541691, 0.69819822, 0.7062747 ,
#        0.85792422, 0.72046389, 0.84197725, 0.7815477 , 0.84433304,
#        0.9955178 , 0.7908349 , 0.95228692, 1.04031661, 1.05255952,
#        0.97069192, 1.19110653, 1.2040133 , 1.30684568, 1.35620108,
#        1.23719679, 1.40541786, 1.34642878, 1.3885578 , 1.33972809,
#        1.20664248, 1.45888275, 1.35067976, 1.23353745, 1.36569376,
#        1.16741405, 1.19800939, 1.21348991, 1.20522277, 1.19753335,
#        1.0916742 , 0.86729586, 1.12087622, 1.16195341, 0.96335233,
#        0.76387361, 0.92138442, 0.7970008 , 0.78357934, 0.63173605,
#        0.76059019, 0.42406094, 0.61369526, 0.57685156, 0.59820647,
#        0.37403708, 0.51309589, 0.50219865, 0.53261242, 0.40745319,
#        0.49343372, 0.47656755, 0.29333136, 0.6640645 , 0.58361682,
#        0.3304719 , 0.61608647, 0.43790655, 0.65432667, 0.72753879,
#        0.71671311, 0.53824034, 0.65041814, 0.81534423, 0.90773636,
#        0.86205596, 0.91110099, 1.04957644, 1.06674587, 0.92023096,
#        1.0997153 , 1.18815071, 1.09701465, 1.10339435, 1.16774356,
#        1.31958118, 1.21632078, 1.21063426, 1.40177599, 1.41797381,
#        1.27794568, 1.26927653, 1.25273957, 1.37920486, 1.28089875,
#        1.33218405, 1.2660077 , 1.35418718, 1.13743809, 1.10182157,
#        1.33149026, 1.26943202, 1.19472326, 1.06372937, 0.99569919,
#        1.07937851, 0.911395  , 0.95044022, 0.76524026, 0.68704466,
#        0.60699785, 0.94992523, 0.64384278, 0.44177097, 0.57011778,
#        0.50318886, 0.60140797, 0.52127594, 0.3478504 , 0.55437773,
#        0.22473348, 0.43156174, 0.52527655, 0.35308686, 0.25417168])
