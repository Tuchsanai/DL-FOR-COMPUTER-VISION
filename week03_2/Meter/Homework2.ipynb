# %%
# !pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.22.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.22 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from scikit-image) (1.26.2)
# Requirement already satisfied: scipy>=1.8 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from scikit-image) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from scikit-image) (10.0.1)
# Collecting imageio>=2.27 (from scikit-image)
#   Downloading imageio-2.33.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2023.12.9-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /Users/tuchsanai/anaconda3/envs/torch/lib/python3.10/site-packages (from scikit-image) (23.1)
# Collecting lazy_loader>=0.3 (from scikit-image)
#   Downloading lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Downloading scikit_image-0.22.0-cp310-cp310-macosx_12_0_arm64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 27.7 MB/s eta 0:00:0000:0100:01
# Downloading imageio-2.33.1-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.3/313.3 kB 25.4 MB/s eta 0:00:00
# Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Downloading tifffile-2023.12.9-py3-none-any.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 kB 25.9 MB/s eta 0:00:00
# Installing collected packages: tifffile, lazy_loader, imageio, scikit-image
# Successfully installed imageio-2.33.1 lazy_loader-0.3 scikit-image-0.22.0 tifffile-2023.12.9

# %%
import cv2
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

# %% [markdown]
# ## download image from url

# %%
url ="./Data/626517.jpg"

img = io.imread(url)

plt.figure(figsize=(12,12))
plt.imshow(img)

# %%
import easyocr
reader = easyocr.Reader(['en'])

# %%
bounds = reader.readtext(img5)
bounds
# Out:
# [([[48, 0], [166, 0], [166, 62], [48, 62]], '4561', 0.29313910007476807)]

# %%
bounds[0][1]
# Out:
# '4561'
